# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_no_material_and_process.json`
#
# Prompt version: `PROMPT_10g`
#
# Run date: `20260618`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `jeremydouglass/p5.js-website/src/assets/learn/performance/code/reflow-dom-manipulation/sketch.js`
#
# **Label combination:**
#
# `material_and_process=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('jeremydouglass/p5.js-website/src/assets/learn/performance/code/reflow-dom-manipulation/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `ronavt/Calculator/sketch.js`
#
# **Label combination:**
#
# `material_and_process=[] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('ronavt/Calculator/sketch.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `tb-harris/runCharmanderRun/p5/empty-example/.ipynb_checkpoints/sketch-checkpoint.js`
#
# **Label combination:**
#
# `material_and_process=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('tb-harris/runCharmanderRun/p5/empty-example/.ipynb_checkpoints/sketch-checkpoint.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `LadyK/CC_midterm_LadyK/midterm_cc/sketch.js`
#
# **Label combination:**
#
# `material_and_process=[] | interaction=['no'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('LadyK/CC_midterm_LadyK/midterm_cc/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/dom/slider_tests/sketch.js`
#
# **Label combination:**
#
# `material_and_process=[] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/dom/slider_tests/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `doxanthropos/p5.js-website/src/assets/learn/performance/code/reflow-dom-manipulation/sketch.js`
#
# **Label combination:**
#
# `material_and_process=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('doxanthropos/p5.js-website/src/assets/learn/performance/code/reflow-dom-manipulation/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `doxanthropos/p5.js-website/dist/assets/learn/performance/code/reflow-dom-manipulation/sketch.js`
#
# **Label combination:**
#
# `material_and_process=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('doxanthropos/p5.js-website/dist/assets/learn/performance/code/reflow-dom-manipulation/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `kjav/p5.js-website/dist/assets/tutorials/performance/code/reflow-dom-manipulation/sketch.js`
#
# **Label combination:**
#
# `material_and_process=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('kjav/p5.js-website/dist/assets/tutorials/performance/code/reflow-dom-manipulation/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/dom/checkbox_test/sketch.js`
#
# **Label combination:**
#
# `material_and_process=[] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/dom/checkbox_test/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `pcsteppan/p5.js/test/manual-test-examples/dom/slider_tests/sketch.js`
#
# **Label combination:**
#
# `material_and_process=[] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('pcsteppan/p5.js/test/manual-test-examples/dom/slider_tests/sketch.js')

# %% [markdown]
# ### Notes for Sample 10
