# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_no_intrand_visual_static.json`
#
# Prompt version: `PROMPT_10g`
#
# Run date: `20260618`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `surajjorwekar/website/Tutorials/P5JS/p5.js/05/5.1_1_p5.js_functions/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('surajjorwekar/website/Tutorials/P5JS/p5.js/05/5.1_1_p5.js_functions/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `PrinceGrewal/website/Tutorials/P5JS/p5.js/09/9.01_p5.js_Transformation_Pt.1/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('PrinceGrewal/website/Tutorials/P5JS/p5.js/09/9.01_p5.js_Transformation_Pt.1/sketch.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `Pyato4ka/website/beginners/p5js/2.2_make_your_own/P5/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('Pyato4ka/website/beginners/p5js/2.2_make_your_own/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `msyem2014/website/CodingChallenges/CC_089_langtonsant/P5/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('msyem2014/website/CodingChallenges/CC_089_langtonsant/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `djhprojects/website/CodingChallenges/CC_089_langtonsant/P5/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('djhprojects/website/CodingChallenges/CC_089_langtonsant/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `willy-goat/website/CodingChallenges/CC_086_beesandbombs/P5/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('willy-goat/website/CodingChallenges/CC_086_beesandbombs/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `carran085/Rainbow-Code/CodingChallenges/CC_74_Clock/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('carran085/Rainbow-Code/CodingChallenges/CC_74_Clock/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `mohamedsekhri/website/CodingChallenges/CC_087_3D_Knots/P5/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('mohamedsekhri/website/CodingChallenges/CC_087_3D_Knots/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `Pyato4ka/website/CodingChallenges/CC_117_SevenSegmentDisplay/P5/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('Pyato4ka/website/CodingChallenges/CC_117_SevenSegmentDisplay/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js/5.1b_p5.js_functions/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js/5.1b_p5.js_functions/sketch.js')

# %% [markdown]
# ### Notes for Sample 10
