# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_interactive_static.json`
#
# Prompt version: `PROMPT_10g`
#
# Run date: `20260618`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `seattleacademy/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_text', 'processed_image'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_text",
#     "processed_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('seattleacademy/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `eve31/website/Courses/programming_with_text/session02/2-0607_regexTestMatchExec/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('eve31/website/Courses/programming_with_text/session02/2-0607_regexTestMatchExec/sketch.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `dsp-testing/A2Z-F15/week2/03_loadFile_Menu/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['processed_image', 'processed_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "processed_image",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('dsp-testing/A2Z-F15/week2/03_loadFile_Menu/sketch.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `Vaayaa/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['processed_text', 'synthesized_text', 'randomness'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Vaayaa/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `AfroDisco/website/Courses/intelligence_learning/session7/07_04_color_classifier/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['processed_text', 'synthesized_image'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "processed_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('AfroDisco/website/Courses/intelligence_learning/session7/07_04_color_classifier/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `mohamedsekhri/website/CodingChallenges/CC_070.1_similarity_score/P5/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('mohamedsekhri/website/CodingChallenges/CC_070.1_similarity_score/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `JesperVagn/website/Courses/A2Z/session01/1-05_StringObject/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('JesperVagn/website/Courses/A2Z/session01/1-05_StringObject/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `aldden/website/Tutorials/P5JS/p5.js/08/8.15_p5.js_drag_and_drop/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['processed_image'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "processed_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('aldden/website/Tutorials/P5JS/p5.js/08/8.15_p5.js_drag_and_drop/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `OnesAndZer0s/website/CodingChallenges/CC_055_Roses/P5/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['synthesized_image'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('OnesAndZer0s/website/CodingChallenges/CC_055_Roses/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `Vaayaa/website/Courses/A2Z/session01/1-05_StringObject/sketch.js`
#
# **Label combination:**
#
# `material_and_process=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "material_and_process": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Vaayaa/website/Courses/A2Z/session01/1-05_StringObject/sketch.js')

# %% [markdown]
# ### Notes for Sample 10
