# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_no_intrand_visual_static.json`
#
# Prompt version: `PROMPT_10e`
#
# Run date: `20260531`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `MadeCurler/website/CodingChallenges/CC_112_3D_Rendering/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('MadeCurler/website/CodingChallenges/CC_112_3D_Rendering/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `aldden/website/CodingChallenges/CC_013_ReactionDiffusion/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('aldden/website/CodingChallenges/CC_013_ReactionDiffusion/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `yusukesaitoh/website/CodingChallenges/CC_089_langtonsant/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('yusukesaitoh/website/CodingChallenges/CC_089_langtonsant/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `solomadcoder2k23/website/beginners/p5js/5.1-function-basics/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('solomadcoder2k23/website/beginners/p5js/5.1-function-basics/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `djhprojects/website/CodingChallenges/CC_087_3D_Knots/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('djhprojects/website/CodingChallenges/CC_087_3D_Knots/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `solomadcoder2k23/website/learning/nature-of-code/3.5-simple-harmonic-motion/approximate-time/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('solomadcoder2k23/website/learning/nature-of-code/3.5-simple-harmonic-motion/approximate-time/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `chrischi9/website/beginners/p5js/3.2-bouncing-ball/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('chrischi9/website/beginners/p5js/3.2-bouncing-ball/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `u40912216/Rainbow-Code/Tutorials/P5JS/p5.js/2.3_1_p5.js_JavaScript_with_objects/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('u40912216/Rainbow-Code/Tutorials/P5JS/p5.js/2.3_1_p5.js_JavaScript_with_objects/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `quatmo/p5.js/examples/risdf13/2_setup_mouse/2-1/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('quatmo/p5.js/examples/risdf13/2_setup_mouse/2-1/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `ElenaBoroda/website/CodingChallenges/CC_134_Heart_Curve_2/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('ElenaBoroda/website/CodingChallenges/CC_134_Heart_Curve_2/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 10
