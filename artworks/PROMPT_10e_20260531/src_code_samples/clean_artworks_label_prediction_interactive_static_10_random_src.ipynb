# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_interactive_static.json`
#
# Prompt version: `PROMPT_10e`
#
# Run date: `20260531`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `Scream145/Rainbow-Code/A2Z/session8/8-07_ConclusionHTTPPOST/website/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Scream145/Rainbow-Code/A2Z/session8/8-07_ConclusionHTTPPOST/website/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `TamannaJain2710/trex/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image', 'synthesized_text', 'randomness'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('TamannaJain2710/trex/sketch.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `alansalihi/Video-Lesson-Materials/code_p5.js/7.2_p5.js_Creating_HTML_elements_with_JavaScript /sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_text', 'synthesized_image'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('alansalihi/Video-Lesson-Materials/code_p5.js/7.2_p5.js_Creating_HTML_elements_with_JavaScript /sketch.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `Vaayaa/website/Tutorials/P5JS/p5.js/03/3.1_p5.js_Introduction_to_Conditional_Statements/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Vaayaa/website/Tutorials/P5JS/p5.js/03/3.1_p5.js_Introduction_to_Conditional_Statements/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `Vaayaa/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_text', 'processed_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Vaayaa/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `Scream145/Rainbow-Code/challenges/CC_37_diastic/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Scream145/Rainbow-Code/challenges/CC_37_diastic/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `yusukesaitoh/website/CodingChallenges/CC_070.1_similarity_score/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('yusukesaitoh/website/CodingChallenges/CC_070.1_similarity_score/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `idea456/website/CodingChallenges/CC_070.2_nearest_neighbors/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('idea456/website/CodingChallenges/CC_070.2_nearest_neighbors/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js/8.6_p5.js_api_query_user_input/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js/8.6_p5.js_api_query_user_input/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `seanwoodward/Rainbow-Code/p5.js/3.1_p5.js_Introduction_to_Conditional_Statements /sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('seanwoodward/Rainbow-Code/p5.js/3.1_p5.js_Introduction_to_Conditional_Statements /sketch.js')

# %% [markdown]
# ### Notes for Sample 10
