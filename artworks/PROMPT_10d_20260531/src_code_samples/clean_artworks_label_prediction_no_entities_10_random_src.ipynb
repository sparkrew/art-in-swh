# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_no_entities.json`
#
# Prompt version: `PROMPT_10d`
#
# Run date: `20260531`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `dsp-testing/A2Z-F15/week1/02_DOM/10_sliders/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('dsp-testing/A2Z-F15/week1/02_DOM/10_sliders/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `tb-harris/runCharmanderRun/p5/empty-example/.ipynb_checkpoints/sketch-checkpoint.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('tb-harris/runCharmanderRun/p5/empty-example/.ipynb_checkpoints/sketch-checkpoint.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `doxanthropos/p5.js-website/src/assets/learn/performance/code/reflow-dom-manipulation/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('doxanthropos/p5.js-website/src/assets/learn/performance/code/reflow-dom-manipulation/sketch.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `dsp-testing/A2Z-F15/week3/01_regexbasics/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('dsp-testing/A2Z-F15/week3/01_regexbasics/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `jeremydouglass/p5.js-website/src/assets/learn/performance/code/reflow-dom-manipulation/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('jeremydouglass/p5.js-website/src/assets/learn/performance/code/reflow-dom-manipulation/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `kjav/p5.js-website/src/assets/tutorials/performance/code/reflow-dom-manipulation/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('kjav/p5.js-website/src/assets/tutorials/performance/code/reflow-dom-manipulation/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `kartikey54/A2Z-F17/week1-dom/10_sliders/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('kartikey54/A2Z-F17/week1-dom/10_sliders/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `kartikey54/A2Z-F17/week2-regex/01_regexbasics/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('kartikey54/A2Z-F17/week2-regex/01_regexbasics/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `ronavt/Calculator/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('ronavt/Calculator/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `maydaypu/DMX-Examples/p5.webserial-dmx/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('maydaypu/DMX-Examples/p5.webserial-dmx/sketch.js')

# %% [markdown]
# ### Notes for Sample 10
