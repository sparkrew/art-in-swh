# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_interactive_static.json`
#
# Prompt version: `PROMPT_10d`
#
# Run date: `20260531`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `Vishal-cod/website-3/CodingChallenges/CC_156_Pi_Digits/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Vishal-cod/website-3/CodingChallenges/CC_156_Pi_Digits/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `MadeCurler/website/Courses/programming_with_text/session01/1-03_textInput/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_text', 'processed_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('MadeCurler/website/Courses/programming_with_text/session01/1-03_textInput/sketch.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `vatsalprajapati/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/The Courthouse/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image', 'synthesized_text', 'randomness'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('vatsalprajapati/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/The Courthouse/sketch.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `BenjamintGibbs/Rainbow-Code/A2Z/session1/1-04_loadingTextFile/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('BenjamintGibbs/Rainbow-Code/A2Z/session1/1-04_loadingTextFile/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `NextSyes/Rainbow-Code/Courses/A2Z/session02/2-08_regexSplit/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_text', 'processed_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('NextSyes/Rainbow-Code/Courses/A2Z/session02/2-08_regexSplit/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `surajjorwekar/website/Courses/programming_with_text/session03/3-01_rita_js/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('surajjorwekar/website/Courses/programming_with_text/session03/3-01_rita_js/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `djhprojects/website/Courses/programming_with_text/session02/2-0607_regexTestMatchExec/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_text', 'processed_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('djhprojects/website/Courses/programming_with_text/session02/2-0607_regexTestMatchExec/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `xlinx/website/CodingChallenges/CC_156_Pi_Digits/Node/public/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('xlinx/website/CodingChallenges/CC_156_Pi_Digits/Node/public/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `dsp-testing/A2Z-F15/week11/08_parse_madlibs/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('dsp-testing/A2Z-F15/week11/08_parse_madlibs/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `su-per-man/website/Courses/intelligence_learning/session7/07_01_color_classifier/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image', 'randomness'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('su-per-man/website/Courses/intelligence_learning/session7/07_01_color_classifier/sketch.js')

# %% [markdown]
# ### Notes for Sample 10
