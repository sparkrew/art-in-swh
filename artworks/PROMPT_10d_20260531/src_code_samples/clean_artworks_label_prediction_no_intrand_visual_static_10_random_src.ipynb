# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_no_intrand_visual_static.json`
#
# Prompt version: `PROMPT_10d`
#
# Run date: `20260531`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `mohamedsekhri/website/Tutorials/P5JS/p5.js/09/9.02_p5.js_Transformation_Pt.2/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('mohamedsekhri/website/Tutorials/P5JS/p5.js/09/9.02_p5.js_Transformation_Pt.2/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `PrinceGrewal/website/learning/nature-of-code/3.6-graphing-sine/sine-wave-graph-exercise/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('PrinceGrewal/website/learning/nature-of-code/3.6-graphing-sine/sine-wave-graph-exercise/sketch.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `djhprojects/website/CodingChallenges/CC_134_Heart_Curve_1/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('djhprojects/website/CodingChallenges/CC_134_Heart_Curve_1/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `cenkt/website/challenges/coding-in-the-cabana/003_hilbert_curve/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('cenkt/website/challenges/coding-in-the-cabana/003_hilbert_curve/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `NextSyes/Rainbow-Code/CodingChallenges/CC_81_1_Circle_Morphing_Part_1/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('NextSyes/Rainbow-Code/CodingChallenges/CC_81_1_Circle_Morphing_Part_1/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `chrischi9/website/learning/nature-of-code/3.6-graphing-sine/circular-wave-exercise/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('chrischi9/website/learning/nature-of-code/3.6-graphing-sine/circular-wave-exercise/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `fcarden/website/CodingChallenges/CC_081_2_Circle_Morphing_Part_2/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('fcarden/website/CodingChallenges/CC_081_2_Circle_Morphing_Part_2/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `lalan-kumar-alt/website-1/learning/nature-of-code/3.6-graphing-sine/playing-with-period/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('lalan-kumar-alt/website-1/learning/nature-of-code/3.6-graphing-sine/playing-with-period/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `carran085/Rainbow-Code/CodingChallenges/CC_74_Clock/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('carran085/Rainbow-Code/CodingChallenges/CC_74_Clock/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `yusukesaitoh/website/CodingChallenges/CC_135_GIF_Loop/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('yusukesaitoh/website/CodingChallenges/CC_135_GIF_Loop/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 10
