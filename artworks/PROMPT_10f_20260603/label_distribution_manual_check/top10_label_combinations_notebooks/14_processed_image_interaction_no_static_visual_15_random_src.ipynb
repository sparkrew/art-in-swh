# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 14
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `14`
#
# Label combination:
#
# `processed_image | interaction=no | static + visual`
#
# Count in clean JSON: `304`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `NilagiriShravani/fruit-catcher/sketch.js`
# 2. `GarimaKubde/project40/sketch.js`
# 3. `cafs/b0b1c70a715c4c5242d0c3ee89232049/sketch.js`
# 4. `Isabellabalencar/Isabellabalencar-Solucao-de-projeto-PRO-C41/sketch.js`
# 5. `VarshaaH/41/sketch.js`
# 6. `Guneet410/Project-41/sketch.js`
# 7. `EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js/8.10_p5.js_giphy_api/sketch.js`
# 8. `Maria-Luisa1599/projeto40/sketch.js`
# 9. `VyshanthS/Rpject-41/PRO-C41-template-main/sketch.js`
# 10. `ishita2008/fruit-collector/sketch.js`
# 11. `Izaan789/Project-fruit-catcher/sketch.js`
# 12. `HANISHA2008/fruit-collector-2/sketch.js`
# 13. `amangorach/q/project-template-fruit-catcher-3-main/project-template-fruit-catcher-3-main/sketch.js`
# 14. `AaronChee1/C40-pro/sketch.js`
# 15. `OnesAndZer0s/website/Tutorials/P5JS/p5.js/10/10.10_p5.js_giphy_api/sketch.js`
# 16. `MOHAKGINNYMITTAL/FRUIT-CATCHER-1-/sketch.js`
# 17. `AfroDisco/website/Tutorials/P5JS/p5.js/10/10.10_p5.js_giphy_api/sketch.js`
# 18. `Age-1234567890/c7856/sketch.js`
# 19. `idea456/website/Tutorials/P5JS/p5.js/10/10.10_p5.js_giphy_api/sketch.js`
# 20. `tezzutezzu/p5.js/test/manual-test-examples/async/loadImage/global/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `NilagiriShravani/fruit-catcher/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('NilagiriShravani/fruit-catcher/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `GarimaKubde/project40/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('GarimaKubde/project40/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `cafs/b0b1c70a715c4c5242d0c3ee89232049/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('cafs/b0b1c70a715c4c5242d0c3ee89232049/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `Isabellabalencar/Isabellabalencar-Solucao-de-projeto-PRO-C41/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Isabellabalencar/Isabellabalencar-Solucao-de-projeto-PRO-C41/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `VarshaaH/41/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('VarshaaH/41/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `Guneet410/Project-41/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Guneet410/Project-41/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js/8.10_p5.js_giphy_api/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js/8.10_p5.js_giphy_api/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `Maria-Luisa1599/projeto40/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Maria-Luisa1599/projeto40/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `VyshanthS/Rpject-41/PRO-C41-template-main/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('VyshanthS/Rpject-41/PRO-C41-template-main/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `ishita2008/fruit-collector/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ishita2008/fruit-collector/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `Izaan789/Project-fruit-catcher/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Izaan789/Project-fruit-catcher/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `HANISHA2008/fruit-collector-2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('HANISHA2008/fruit-collector-2/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `amangorach/q/project-template-fruit-catcher-3-main/project-template-fruit-catcher-3-main/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('amangorach/q/project-template-fruit-catcher-3-main/project-template-fruit-catcher-3-main/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `AaronChee1/C40-pro/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('AaronChee1/C40-pro/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `OnesAndZer0s/website/Tutorials/P5JS/p5.js/10/10.10_p5.js_giphy_api/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('OnesAndZer0s/website/Tutorials/P5JS/p5.js/10/10.10_p5.js_giphy_api/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `MOHAKGINNYMITTAL/FRUIT-CATCHER-1-/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('MOHAKGINNYMITTAL/FRUIT-CATCHER-1-/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `AfroDisco/website/Tutorials/P5JS/p5.js/10/10.10_p5.js_giphy_api/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('AfroDisco/website/Tutorials/P5JS/p5.js/10/10.10_p5.js_giphy_api/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `Age-1234567890/c7856/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Age-1234567890/c7856/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `idea456/website/Tutorials/P5JS/p5.js/10/10.10_p5.js_giphy_api/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('idea456/website/Tutorials/P5JS/p5.js/10/10.10_p5.js_giphy_api/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/async/loadImage/global/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/async/loadImage/global/sketch.js')
