# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 18
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `18`
#
# Label combination:
#
# `randomness + synthesized_text | interaction=yes | time_based + visual`
#
# Count in clean JSON: `250`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `tezzutezzu/p5.js/test/manual-test-examples/dom/input_button/sketch.js`
# 2. `abhijit-dhar/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
# 3. `Anninster/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
# 4. `jmwenda/itp-creative-js/Spring-2014/week3/13_wordscrambler/sketch.js`
# 5. `Dani-CA/archive/Dani-CA/proposte_concept/REV 4/codice/prototipo_1/examples/codice/sketch.js`
# 6. `mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
# 7. `Tekman03/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
# 8. `MadeCurler/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
# 9. `chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
# 10. `notshekhar/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
# 11. `quatmo/p5.js/examples/addons/p5.dom/input_button/sketch.js`
# 12. `surajjorwekar/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
# 13. `crecord/p5.js/examples/addons/p5.dom/input_button/sketch.js`
# 14. `rhedhs/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
# 15. `notshekhar/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
# 16. `Scream145/Rainbow-Code/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
# 17. `eve31/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
# 18. `TsunamiUmsterk/divisionGame/sketch.js`
# 19. `seanwoodward/Rainbow-Code/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
# 20. `lalan-kumar-alt/website-1/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/dom/input_button/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/dom/input_button/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `abhijit-dhar/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('abhijit-dhar/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `Anninster/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Anninster/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `jmwenda/itp-creative-js/Spring-2014/week3/13_wordscrambler/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('jmwenda/itp-creative-js/Spring-2014/week3/13_wordscrambler/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `Dani-CA/archive/Dani-CA/proposte_concept/REV 4/codice/prototipo_1/examples/codice/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Dani-CA/archive/Dani-CA/proposte_concept/REV 4/codice/prototipo_1/examples/codice/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `Tekman03/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Tekman03/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `MadeCurler/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('MadeCurler/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `notshekhar/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('notshekhar/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `quatmo/p5.js/examples/addons/p5.dom/input_button/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('quatmo/p5.js/examples/addons/p5.dom/input_button/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `surajjorwekar/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('surajjorwekar/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `crecord/p5.js/examples/addons/p5.dom/input_button/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('crecord/p5.js/examples/addons/p5.dom/input_button/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `rhedhs/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('rhedhs/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `notshekhar/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('notshekhar/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `Scream145/Rainbow-Code/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Scream145/Rainbow-Code/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `eve31/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('eve31/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `TsunamiUmsterk/divisionGame/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('TsunamiUmsterk/divisionGame/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `seanwoodward/Rainbow-Code/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('seanwoodward/Rainbow-Code/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `lalan-kumar-alt/website-1/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('lalan-kumar-alt/website-1/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js')
