# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 5
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `5`
#
# Label combination:
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# Count in clean JSON: `1091`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 403/403-1-34706237-1382801/sketch.js`
# 2. `BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js_video/10.2_p5.js_photoBooth/sketch.js`
# 3. `TheUnderscoreWizard/ProC37Redo/sketch.js`
# 4. `sophialadwiniec/CoralReefs/sketch.js`
# 5. `remeyama/website/Tutorials/P5JS/p5.js_video/11.2_p5.js_photoBooth/sketch.js`
# 6. `erichdebbarma/Pro-C29/sketch.js`
# 7. `rhedhs/website/Tutorials/P5JS/p5.js_video/11.4_p5.js_brightness_mirror/sketch.js`
# 8. `tanisha8108/monkey-go-happy/sketch.js`
# 9. `jahnavi919/tower-seige-1/sketch.js`
# 10. `EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js_video/10.2_p5.js_photoBooth/sketch.js`
# 11. `saurabhsindhu96/ml4a.github.io/examples/features-simple/sketch.js`
# 12. `labdhi29/project20/sketch.js`
# 13. `EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js_video/10.7_p5.js_slitscan/sketch.js`
# 14. `Tekman03/website/Tutorials/P5JS/p5.js_video/11.4_p5.js_brightness_mirror/sketch.js`
# 15. `dhruv13092005/Changing-The-Background/sketch.js`
# 16. `devansh3003/Project-29/sketch.js`
# 17. `msyem2014/website/Tutorials/P5JS/p5.js_video/11.1_p5.js_createCapture/sketch.js`
# 18. `yusukesaitoh/website/Tutorials/P5JS/p5.js_video/11.2_p5.js_photoBooth/sketch.js`
# 19. `carran085/Rainbow-Code/Tutorials/P5JS/p5.js_video/11.4_p5.js_brightness_mirror/sketch.js`
# 20. `karantiwari2/LET-S-RUN-JAXON/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 403/403-1-34706237-1382801/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 403/403-1-34706237-1382801/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js_video/10.2_p5.js_photoBooth/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js_video/10.2_p5.js_photoBooth/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `TheUnderscoreWizard/ProC37Redo/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('TheUnderscoreWizard/ProC37Redo/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `sophialadwiniec/CoralReefs/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('sophialadwiniec/CoralReefs/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `remeyama/website/Tutorials/P5JS/p5.js_video/11.2_p5.js_photoBooth/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('remeyama/website/Tutorials/P5JS/p5.js_video/11.2_p5.js_photoBooth/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `erichdebbarma/Pro-C29/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "processed_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('erichdebbarma/Pro-C29/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `rhedhs/website/Tutorials/P5JS/p5.js_video/11.4_p5.js_brightness_mirror/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('rhedhs/website/Tutorials/P5JS/p5.js_video/11.4_p5.js_brightness_mirror/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `tanisha8108/monkey-go-happy/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tanisha8108/monkey-go-happy/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `jahnavi919/tower-seige-1/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "processed_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('jahnavi919/tower-seige-1/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js_video/10.2_p5.js_photoBooth/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js_video/10.2_p5.js_photoBooth/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `saurabhsindhu96/ml4a.github.io/examples/features-simple/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('saurabhsindhu96/ml4a.github.io/examples/features-simple/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `labdhi29/project20/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('labdhi29/project20/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js_video/10.7_p5.js_slitscan/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js_video/10.7_p5.js_slitscan/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `Tekman03/website/Tutorials/P5JS/p5.js_video/11.4_p5.js_brightness_mirror/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Tekman03/website/Tutorials/P5JS/p5.js_video/11.4_p5.js_brightness_mirror/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `dhruv13092005/Changing-The-Background/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('dhruv13092005/Changing-The-Background/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `devansh3003/Project-29/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "processed_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('devansh3003/Project-29/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `msyem2014/website/Tutorials/P5JS/p5.js_video/11.1_p5.js_createCapture/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('msyem2014/website/Tutorials/P5JS/p5.js_video/11.1_p5.js_createCapture/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `yusukesaitoh/website/Tutorials/P5JS/p5.js_video/11.2_p5.js_photoBooth/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('yusukesaitoh/website/Tutorials/P5JS/p5.js_video/11.2_p5.js_photoBooth/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `carran085/Rainbow-Code/Tutorials/P5JS/p5.js_video/11.4_p5.js_brightness_mirror/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('carran085/Rainbow-Code/Tutorials/P5JS/p5.js_video/11.4_p5.js_brightness_mirror/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `karantiwari2/LET-S-RUN-JAXON/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('karantiwari2/LET-S-RUN-JAXON/sketch.js')
