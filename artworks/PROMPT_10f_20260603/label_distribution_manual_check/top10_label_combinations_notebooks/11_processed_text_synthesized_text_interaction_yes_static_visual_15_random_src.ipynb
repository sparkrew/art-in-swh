# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 11
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `11`
#
# Label combination:
#
# `processed_text + synthesized_text | interaction=yes | static + visual`
#
# Count in clean JSON: `353`
#
# Samples in this notebook: `11`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `remeyama/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 2. `AfroDisco/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 3. `oshoham/p5.js/test/manual-test-examples/async/loadJSON_callback/sketch.js`
# 4. `quatmo/p5.js/examples/async/loadJSON_callback/sketch.js`
# 5. `ThunderCode-Dev7/Basic-console-calculator/sketch.js`
# 6. `Joel-Gaming/Joel-Gaming.github.io/Local Storage/sketch.js`
# 7. `hcGamechamp/hcGamechamp.github.io/Highscore Demo/sketch.js`
# 8. `jcharry/ITP/echonestV2/sketch.js`
# 9. `NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 10. `wykhuh/shiffman-p5-tutorials/8.8-changed-input/sketch.js`
# 11. `italoadler/RiTa/web/examples/p5js/HaikuGrammar/code.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `remeyama/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('remeyama/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `AfroDisco/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('AfroDisco/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/async/loadJSON_callback/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/async/loadJSON_callback/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `quatmo/p5.js/examples/async/loadJSON_callback/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('quatmo/p5.js/examples/async/loadJSON_callback/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `ThunderCode-Dev7/Basic-console-calculator/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ThunderCode-Dev7/Basic-console-calculator/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `Joel-Gaming/Joel-Gaming.github.io/Local Storage/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Joel-Gaming/Joel-Gaming.github.io/Local Storage/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `hcGamechamp/hcGamechamp.github.io/Highscore Demo/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('hcGamechamp/hcGamechamp.github.io/Highscore Demo/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `jcharry/ITP/echonestV2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('jcharry/ITP/echonestV2/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `wykhuh/shiffman-p5-tutorials/8.8-changed-input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('wykhuh/shiffman-p5-tutorials/8.8-changed-input/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `italoadler/RiTa/web/examples/p5js/HaikuGrammar/code.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('italoadler/RiTa/web/examples/p5js/HaikuGrammar/code.js')
