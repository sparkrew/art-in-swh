# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 10
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `10`
#
# Label combination:
#
# `processed_image + synthesized_image | interaction=no | time_based + visual`
#
# Count in clean JSON: `363`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `harneesh/monkey-go-happy-2/sketch.js`
# 2. `kris7205/PRO-C-11-PROJECT-Work/sketch.js`
# 3. `pcsteppan/p5.js/test/manual-test-examples/webgl/material/texture/sketch.js`
# 4. `RynoGoedhals/Project-11/sketch.js`
# 5. `Kulsum29/adventure-1/sketch.js`
# 6. `tezzutezzu/p5.js/test/manual-test-examples/webgl/texture/multipleTextures/sketch.js`
# 7. `MudaDayo/20_21_AN1_clipWeb/clips/delhez_inwe/sketch.js`
# 8. `patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 302/302-2-67874820-1382801/sketch.js`
# 9. `queensaikia/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-302/Mansion heist/sketch.js`
# 10. `BabaDorin/assembly-browser/Grafica Inginereasca/Other related files/Laborator 4/sketch.js`
# 11. `jay-manday/p5-loadModel-errorCase/public/sketch.js`
# 12. `SumanPurkait-grb/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-302/Mansion heist/sketch.js`
# 13. `302060/boat/sketch.js`
# 14. `22112008/ProjectC10/sketch.js`
# 15. `samarsalvi/project---20/sketch.js`
# 16. `ShruthiDevendiran/C19-Project-Final/sketch.js`
# 17. `Vaibhaa/Cat-and-mouses/sketch.js`
# 18. `patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 302/302-0-78690143-1382801/sketch.js`
# 19. `SravanRadhesh/PRO-C18-MONKEY-GO-HAPPY---2/sketch.js`
# 20. `pavneetkaur1/Project-11---Travelling-in-Ship/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `harneesh/monkey-go-happy-2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('harneesh/monkey-go-happy-2/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `kris7205/PRO-C-11-PROJECT-Work/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('kris7205/PRO-C-11-PROJECT-Work/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `pcsteppan/p5.js/test/manual-test-examples/webgl/material/texture/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('pcsteppan/p5.js/test/manual-test-examples/webgl/material/texture/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `RynoGoedhals/Project-11/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('RynoGoedhals/Project-11/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `Kulsum29/adventure-1/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Kulsum29/adventure-1/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/webgl/texture/multipleTextures/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/webgl/texture/multipleTextures/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `MudaDayo/20_21_AN1_clipWeb/clips/delhez_inwe/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('MudaDayo/20_21_AN1_clipWeb/clips/delhez_inwe/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 302/302-2-67874820-1382801/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 302/302-2-67874820-1382801/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `queensaikia/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-302/Mansion heist/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('queensaikia/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-302/Mansion heist/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `BabaDorin/assembly-browser/Grafica Inginereasca/Other related files/Laborator 4/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BabaDorin/assembly-browser/Grafica Inginereasca/Other related files/Laborator 4/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `jay-manday/p5-loadModel-errorCase/public/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('jay-manday/p5-loadModel-errorCase/public/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `SumanPurkait-grb/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-302/Mansion heist/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SumanPurkait-grb/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-302/Mansion heist/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `302060/boat/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('302060/boat/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `22112008/ProjectC10/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('22112008/ProjectC10/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `samarsalvi/project---20/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('samarsalvi/project---20/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `ShruthiDevendiran/C19-Project-Final/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ShruthiDevendiran/C19-Project-Final/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `Vaibhaa/Cat-and-mouses/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Vaibhaa/Cat-and-mouses/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 302/302-0-78690143-1382801/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 302/302-0-78690143-1382801/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `SravanRadhesh/PRO-C18-MONKEY-GO-HAPPY---2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SravanRadhesh/PRO-C18-MONKEY-GO-HAPPY---2/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `pavneetkaur1/Project-11---Travelling-in-Ship/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('pavneetkaur1/Project-11---Travelling-in-Ship/sketch.js')
