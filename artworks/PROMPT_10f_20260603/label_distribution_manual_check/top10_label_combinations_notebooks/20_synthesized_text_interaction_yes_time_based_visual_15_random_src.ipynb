# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 20
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `20`
#
# Label combination:
#
# `synthesized_text | interaction=yes | time_based + visual`
#
# Count in clean JSON: `217`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `MadeCurler/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 2. `Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/7.11_p5.js_parent_child/sketch.js`
# 3. `GeekAhmeds/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 4. `yusukesaitoh/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 5. `chenhuaixian/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 6. `fcarden/website/Tutorials/P5JS/p5.js/08/8.14_2_p5.js_parent()_and_child()_again_with_variables/sketch.js`
# 7. `alansalihi/Video-Lesson-Materials/code_p5.js/7.7_p5.js_events_"changed"_and_"input" /sketch.js`
# 8. `peachplusplus/Video-Lesson-Materials/code_p5.js/7.7_p5.js_events_"changed"_and_"input" /sketch.js`
# 9. `notshekhar/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 10. `chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/7.11_p5.js_parent_child/sketch.js`
# 11. `aldden/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 12. `ionescugeorge/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
# 13. `Anninster/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 14. `gabriel-combe/Rainbow-Code/Tutorials/P5JS/p5.js/7.7_p5.js_events_changed_input/sketch.js`
# 15. `BenjamintGibbs/Rainbow-Code/p5.js/7.7_p5.js_events_changed_input/sketch.js`
# 16. `Harrybowling/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
# 17. `Harrybowling/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
# 18. `remeyama/website/Tutorials/P5JS/p5.js/08/8.14_2_p5.js_parent()_and_child()_again_with_variables/sketch.js`
# 19. `remeyama/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
# 20. `EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `MadeCurler/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('MadeCurler/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/7.11_p5.js_parent_child/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/7.11_p5.js_parent_child/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `GeekAhmeds/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('GeekAhmeds/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `yusukesaitoh/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('yusukesaitoh/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `chenhuaixian/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chenhuaixian/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `fcarden/website/Tutorials/P5JS/p5.js/08/8.14_2_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('fcarden/website/Tutorials/P5JS/p5.js/08/8.14_2_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `alansalihi/Video-Lesson-Materials/code_p5.js/7.7_p5.js_events_"changed"_and_"input" /sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('alansalihi/Video-Lesson-Materials/code_p5.js/7.7_p5.js_events_"changed"_and_"input" /sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `peachplusplus/Video-Lesson-Materials/code_p5.js/7.7_p5.js_events_"changed"_and_"input" /sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('peachplusplus/Video-Lesson-Materials/code_p5.js/7.7_p5.js_events_"changed"_and_"input" /sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `notshekhar/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('notshekhar/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/7.11_p5.js_parent_child/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/7.11_p5.js_parent_child/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `aldden/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('aldden/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `ionescugeorge/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ionescugeorge/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `Anninster/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Anninster/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `gabriel-combe/Rainbow-Code/Tutorials/P5JS/p5.js/7.7_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('gabriel-combe/Rainbow-Code/Tutorials/P5JS/p5.js/7.7_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `BenjamintGibbs/Rainbow-Code/p5.js/7.7_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BenjamintGibbs/Rainbow-Code/p5.js/7.7_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `Harrybowling/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Harrybowling/website/Tutorials/P5JS/p5.js/08/8.11_p5.js_callbacks_on_multiple_DOM_elements/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `Harrybowling/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Harrybowling/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `remeyama/website/Tutorials/P5JS/p5.js/08/8.14_2_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('remeyama/website/Tutorials/P5JS/p5.js/08/8.14_2_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `remeyama/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('remeyama/website/Tutorials/P5JS/p5.js/08/8.12_p5.js_parent_child/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('EsbernTK/Rainbow-Code/Tutorials/P5JS/p5.js/7.10_p5.js_callbacks_on_multiple_DOM_elements/sketch.js')
