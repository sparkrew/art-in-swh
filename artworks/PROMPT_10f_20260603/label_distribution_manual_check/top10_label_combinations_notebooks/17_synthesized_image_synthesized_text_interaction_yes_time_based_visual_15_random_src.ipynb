# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 17
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `17`
#
# Label combination:
#
# `synthesized_image + synthesized_text | interaction=yes | time_based + visual`
#
# Count in clean JSON: `261`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `quintvanzijl/Rainbow-Code/p5.js/9.2b_p5.js_setInterval/sketch.js`
# 2. `mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js`
# 3. `sayedhurhussain55/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/Torvalds House/sketch.js`
# 4. `Prisha29/Trex-Game/sketch.js`
# 5. `u40912216/Rainbow-Code/Tutorials/P5JS/p5.js/7.6_p5.js_The_basics_of_CSS/sketch.js`
# 6. `alansalihi/Video-Lesson-Materials/code_p5.js/7.2_p5.js_Creating_HTML_elements_with_JavaScript /sketch.js`
# 7. `seanwoodward/Rainbow-Code/p5.js/7.13.4_p5.js_parent()_and_child()_again_with_variables/sketch.js`
# 8. `JesperVagn/website/Tutorials/P5JS/p5.js/08/8.02_p5.js_Creating_HTML_elements_with_JavaScript/sketch.js`
# 9. `patrickdolloso/CM1005/W13 Functions/7.103/7.103/ex2_complete/sketch.js`
# 10. `sayedhurhussain55/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/Torvalds Office/sketch.js`
# 11. `BenjamintGibbs/Rainbow-Code/p5.js/9.2b_p5.js_setInterval/sketch.js`
# 12. `chrischi9/website/Tutorials/P5JS/p5.js/09/9.05_1_p5.js_setInterval/sketch.js`
# 13. `tututor/Rainbow-Code/Tutorials/P5JS/p5.js/7.13.4_p5.js_parent()_and_child()_again_with_variables/sketch.js`
# 14. `gabriel-combe/Rainbow-Code/Tutorials/P5JS/p5.js/7.6_p5.js_The_basics_of_CSS/sketch.js`
# 15. `chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/9.2b_p5.js_setInterval/sketch.js`
# 16. `ManishKumar102/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/Torvalds House/sketch.js`
# 17. `remeyama/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js`
# 18. `fcarden/website/Tutorials/P5JS/p5.js/08/8.02_p5.js_Creating_HTML_elements_with_JavaScript/sketch.js`
# 19. `MadeCurler/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js`
# 20. `crecord/p5.js/examples/keyboard/gamestyle.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `quintvanzijl/Rainbow-Code/p5.js/9.2b_p5.js_setInterval/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('quintvanzijl/Rainbow-Code/p5.js/9.2b_p5.js_setInterval/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `sayedhurhussain55/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/Torvalds House/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('sayedhurhussain55/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/Torvalds House/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `Prisha29/Trex-Game/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Prisha29/Trex-Game/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `u40912216/Rainbow-Code/Tutorials/P5JS/p5.js/7.6_p5.js_The_basics_of_CSS/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('u40912216/Rainbow-Code/Tutorials/P5JS/p5.js/7.6_p5.js_The_basics_of_CSS/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `alansalihi/Video-Lesson-Materials/code_p5.js/7.2_p5.js_Creating_HTML_elements_with_JavaScript /sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('alansalihi/Video-Lesson-Materials/code_p5.js/7.2_p5.js_Creating_HTML_elements_with_JavaScript /sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `seanwoodward/Rainbow-Code/p5.js/7.13.4_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('seanwoodward/Rainbow-Code/p5.js/7.13.4_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `JesperVagn/website/Tutorials/P5JS/p5.js/08/8.02_p5.js_Creating_HTML_elements_with_JavaScript/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('JesperVagn/website/Tutorials/P5JS/p5.js/08/8.02_p5.js_Creating_HTML_elements_with_JavaScript/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `patrickdolloso/CM1005/W13 Functions/7.103/7.103/ex2_complete/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/W13 Functions/7.103/7.103/ex2_complete/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `sayedhurhussain55/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/Torvalds Office/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('sayedhurhussain55/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/Torvalds Office/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `BenjamintGibbs/Rainbow-Code/p5.js/9.2b_p5.js_setInterval/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BenjamintGibbs/Rainbow-Code/p5.js/9.2b_p5.js_setInterval/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `chrischi9/website/Tutorials/P5JS/p5.js/09/9.05_1_p5.js_setInterval/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chrischi9/website/Tutorials/P5JS/p5.js/09/9.05_1_p5.js_setInterval/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `tututor/Rainbow-Code/Tutorials/P5JS/p5.js/7.13.4_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tututor/Rainbow-Code/Tutorials/P5JS/p5.js/7.13.4_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `gabriel-combe/Rainbow-Code/Tutorials/P5JS/p5.js/7.6_p5.js_The_basics_of_CSS/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('gabriel-combe/Rainbow-Code/Tutorials/P5JS/p5.js/7.6_p5.js_The_basics_of_CSS/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/9.2b_p5.js_setInterval/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/9.2b_p5.js_setInterval/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `ManishKumar102/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/Torvalds House/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ManishKumar102/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-303/Torvalds House/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `remeyama/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('remeyama/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `fcarden/website/Tutorials/P5JS/p5.js/08/8.02_p5.js_Creating_HTML_elements_with_JavaScript/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('fcarden/website/Tutorials/P5JS/p5.js/08/8.02_p5.js_Creating_HTML_elements_with_JavaScript/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `MadeCurler/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('MadeCurler/website/Tutorials/P5JS/p5.js/08/8.14_3_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `crecord/p5.js/examples/keyboard/gamestyle.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('crecord/p5.js/examples/keyboard/gamestyle.js')
