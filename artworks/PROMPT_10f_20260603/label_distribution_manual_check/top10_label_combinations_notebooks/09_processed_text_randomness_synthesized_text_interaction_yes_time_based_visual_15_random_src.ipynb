# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 9
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `9`
#
# Label combination:
#
# `processed_text + randomness + synthesized_text | interaction=yes | time_based + visual`
#
# Count in clean JSON: `379`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `surajjorwekar/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 2. `JesperVagn/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 3. `notshekhar/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 4. `Vaayaa/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 5. `GeekAhmeds/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 6. `ElenaBoroda/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 7. `readyletsgo/PGDV_5200_MS1_SP18/08_ritaStringCanvas/Rita.js/sketch.js`
# 8. `tezzutezzu/p5.js/test/manual-test-examples/async/loadJSON_callback/sketch.js`
# 9. `oshoham/p5.js/test/manual-test-examples/async/loadStrings_callback/sketch.js`
# 10. `MadeCurler/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 11. `Vishal-cod/website-3/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 12. `Harrybowling/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 13. `djhprojects/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 14. `remeyama/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 15. `zal96/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 16. `willy-goat/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 17. `AfroDisco/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 18. `nikitahuggins/networkedmedia/week5/01-apis/02_capitol_words/sketch.js`
# 19. `UngPkay/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
# 20. `chenhuaixian/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `surajjorwekar/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('surajjorwekar/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `JesperVagn/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('JesperVagn/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `notshekhar/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('notshekhar/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `Vaayaa/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Vaayaa/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `GeekAhmeds/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('GeekAhmeds/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `ElenaBoroda/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ElenaBoroda/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `readyletsgo/PGDV_5200_MS1_SP18/08_ritaStringCanvas/Rita.js/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('readyletsgo/PGDV_5200_MS1_SP18/08_ritaStringCanvas/Rita.js/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/async/loadJSON_callback/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/async/loadJSON_callback/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/async/loadStrings_callback/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/async/loadStrings_callback/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `MadeCurler/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('MadeCurler/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `Vishal-cod/website-3/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Vishal-cod/website-3/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `Harrybowling/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Harrybowling/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `djhprojects/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('djhprojects/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `remeyama/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('remeyama/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `zal96/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('zal96/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `willy-goat/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('willy-goat/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `AfroDisco/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('AfroDisco/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `nikitahuggins/networkedmedia/week5/01-apis/02_capitol_words/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('nikitahuggins/networkedmedia/week5/01-apis/02_capitol_words/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `UngPkay/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('UngPkay/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `chenhuaixian/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chenhuaixian/website/Tutorials/P5JS/p5.js/10/10.08_p5.js_Wordnik_API/sketch.js')
