# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 13
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `13`
#
# Label combination:
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# Count in clean JSON: `312`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `DavidRzF/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-301/So who knows Python/sketch.js`
# 2. `SumanPurkait-grb/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/Hopper's House/sketch.js`
# 3. `infinity0000007/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-301/Weaving the web/sketch.js`
# 4. `ManishKumar102/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Dressing Room/sketch.js`
# 5. `zoalst/p5.js/examples/addons/p5.dom/video_to_canvas/sketch.js`
# 6. `Vineesha93/C39-fruit-catcher-1/sketch.js`
# 7. `sharpenzhu/p5/p5-2/empty-example/sketch.js`
# 8. `Persues204/traveling-in-ship/sketch.js`
# 9. `queensaikia/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Dressing Room/sketch.js`
# 10. `BlazeRogers888/the-travelling-ship-retry-/sketch.js`
# 11. `infinity0000007/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Dressing Room/sketch.js`
# 12. `patrickdolloso/CM1005/Sleuth_Pro/501/501-3-59250914-1382801/sketch.js`
# 13. `infinity0000007/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Warehouse/sketch.js`
# 14. `SumanPurkait-grb/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/Department of Justice/sketch.js`
# 15. `localcrafts101/ATK302/p5/WK4/sketch.js`
# 16. `thomb212/compform_p5/week3_pixels/day6/sketch.js`
# 17. `SuddenFlame414/Project-40/sketch.js`
# 18. `sayedhurhussain55/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-301/The usual suspects/sketch.js`
# 19. `blurryfaze/tablaa/sketch.js`
# 20. `patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 101/101-2-76433370-1382801/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `DavidRzF/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-301/So who knows Python/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('DavidRzF/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-301/So who knows Python/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `SumanPurkait-grb/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/Hopper's House/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file("SumanPurkait-grb/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/Hopper's House/sketch.js")

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `infinity0000007/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-301/Weaving the web/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('infinity0000007/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-301/Weaving the web/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `ManishKumar102/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Dressing Room/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ManishKumar102/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Dressing Room/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `zoalst/p5.js/examples/addons/p5.dom/video_to_canvas/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('zoalst/p5.js/examples/addons/p5.dom/video_to_canvas/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `Vineesha93/C39-fruit-catcher-1/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Vineesha93/C39-fruit-catcher-1/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `sharpenzhu/p5/p5-2/empty-example/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('sharpenzhu/p5/p5-2/empty-example/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `Persues204/traveling-in-ship/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Persues204/traveling-in-ship/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `queensaikia/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Dressing Room/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('queensaikia/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Dressing Room/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `BlazeRogers888/the-travelling-ship-retry-/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BlazeRogers888/the-travelling-ship-retry-/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `infinity0000007/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Dressing Room/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('infinity0000007/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Dressing Room/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `patrickdolloso/CM1005/Sleuth_Pro/501/501-3-59250914-1382801/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/Sleuth_Pro/501/501-3-59250914-1382801/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `infinity0000007/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Warehouse/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('infinity0000007/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/The Warehouse/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `SumanPurkait-grb/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/Department of Justice/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SumanPurkait-grb/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-201/Department of Justice/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `localcrafts101/ATK302/p5/WK4/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('localcrafts101/ATK302/p5/WK4/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `thomb212/compform_p5/week3_pixels/day6/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('thomb212/compform_p5/week3_pixels/day6/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `SuddenFlame414/Project-40/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SuddenFlame414/Project-40/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `sayedhurhussain55/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-301/The usual suspects/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('sayedhurhussain55/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-301/The usual suspects/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `blurryfaze/tablaa/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('blurryfaze/tablaa/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 101/101-2-76433370-1382801/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/W2 Your development environment (cont)/1.2 Intro to Sleuth/Case 101/101-2-76433370-1382801/sketch.js')
