# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 6
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `6`
#
# Label combination:
#
# `randomness + synthesized_image | interaction=yes | time_based + visual`
#
# Count in clean JSON: `1028`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `hcGamechamp/hcGamechamp.github.io/Walker Array/sketch.js`
# 2. `DiegoVeri/Treasure-Hunter/sketch.js`
# 3. `doxanthropos/p5.js-website/dist/assets/p5_featured/Sarah_voronoi/sgp_background_sketch.js`
# 4. `Yoongi2022/Proyecto-17/sketch.js`
# 5. `ruthwik29/project18/sketch.js`
# 6. `SahithP/P18/sketch.js`
# 7. `armbrustsamuel/8-queens-challenge-p5/challenge/sketch.js`
# 8. `KirtanGehalod/Monkey-/sketch.js`
# 9. `djhprojects/website/Tutorials/P5JS/p5.js/07/7.4_p5js_Mouse_Interaction_with_Objects/sketch.js`
# 10. `surajjorwekar/website/Tutorials/P5JS/p5.js/07/7.5_2_p5js_Removing_Objects_from_Arrays/sketch.js`
# 11. `GeekAhmeds/website/Tutorials/P5JS/p5.js/07/7.4_p5js_Mouse_Interaction_with_Objects/sketch.js`
# 12. `AlexStommes/flowers/day2/sketch.js`
# 13. `remeyama/website/Tutorials/P5JS/p5.js/07/7.5_2_p5js_Removing_Objects_from_Arrays/sketch.js`
# 14. `MadeCurler/website/Tutorials/P5JS/p5.js/08/8.04_p5.js_Handling_DOM_events_with_callbacks/sketch.js`
# 15. `Jaisnehan/c18/sketch.js`
# 16. `NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/04/4.2_1_Nested_loops/sketch.js`
# 17. `cenkt/website/Tutorials/P5JS/p5.js/08/8.04_p5.js_Handling_DOM_events_with_callbacks/sketch.js`
# 18. `Aryanblaster/-PLUCKING-MANGOES/sketch.js`
# 19. `seanwoodward/Rainbow-Code/p5.js/9.6_p5.js_minimum_spanning_tree/sketch.js`
# 20. `hcGamechamp/hcGamechamp.github.io/Randomize Grid/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `hcGamechamp/hcGamechamp.github.io/Walker Array/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('hcGamechamp/hcGamechamp.github.io/Walker Array/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `DiegoVeri/Treasure-Hunter/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('DiegoVeri/Treasure-Hunter/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `doxanthropos/p5.js-website/dist/assets/p5_featured/Sarah_voronoi/sgp_background_sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('doxanthropos/p5.js-website/dist/assets/p5_featured/Sarah_voronoi/sgp_background_sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `Yoongi2022/Proyecto-17/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Yoongi2022/Proyecto-17/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `ruthwik29/project18/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ruthwik29/project18/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `SahithP/P18/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SahithP/P18/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `armbrustsamuel/8-queens-challenge-p5/challenge/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('armbrustsamuel/8-queens-challenge-p5/challenge/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `KirtanGehalod/Monkey-/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('KirtanGehalod/Monkey-/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `djhprojects/website/Tutorials/P5JS/p5.js/07/7.4_p5js_Mouse_Interaction_with_Objects/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('djhprojects/website/Tutorials/P5JS/p5.js/07/7.4_p5js_Mouse_Interaction_with_Objects/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `surajjorwekar/website/Tutorials/P5JS/p5.js/07/7.5_2_p5js_Removing_Objects_from_Arrays/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('surajjorwekar/website/Tutorials/P5JS/p5.js/07/7.5_2_p5js_Removing_Objects_from_Arrays/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `GeekAhmeds/website/Tutorials/P5JS/p5.js/07/7.4_p5js_Mouse_Interaction_with_Objects/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('GeekAhmeds/website/Tutorials/P5JS/p5.js/07/7.4_p5js_Mouse_Interaction_with_Objects/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `AlexStommes/flowers/day2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('AlexStommes/flowers/day2/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `remeyama/website/Tutorials/P5JS/p5.js/07/7.5_2_p5js_Removing_Objects_from_Arrays/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('remeyama/website/Tutorials/P5JS/p5.js/07/7.5_2_p5js_Removing_Objects_from_Arrays/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `MadeCurler/website/Tutorials/P5JS/p5.js/08/8.04_p5.js_Handling_DOM_events_with_callbacks/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('MadeCurler/website/Tutorials/P5JS/p5.js/08/8.04_p5.js_Handling_DOM_events_with_callbacks/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `Jaisnehan/c18/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Jaisnehan/c18/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/04/4.2_1_Nested_loops/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/04/4.2_1_Nested_loops/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `cenkt/website/Tutorials/P5JS/p5.js/08/8.04_p5.js_Handling_DOM_events_with_callbacks/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('cenkt/website/Tutorials/P5JS/p5.js/08/8.04_p5.js_Handling_DOM_events_with_callbacks/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `Aryanblaster/-PLUCKING-MANGOES/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Aryanblaster/-PLUCKING-MANGOES/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `seanwoodward/Rainbow-Code/p5.js/9.6_p5.js_minimum_spanning_tree/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('seanwoodward/Rainbow-Code/p5.js/9.6_p5.js_minimum_spanning_tree/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `hcGamechamp/hcGamechamp.github.io/Randomize Grid/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('hcGamechamp/hcGamechamp.github.io/Randomize Grid/sketch.js')
