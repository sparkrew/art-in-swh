# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 1
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `1`
#
# Label combination:
#
# `randomness + synthesized_image | interaction=no | time_based + visual`
#
# Count in clean JSON: `2096`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `notshekhar/website/Tutorials/P5JS/p5.js/10/10.04_p5.js_Loading_JSON_from_URL/sketch.js`
# 2. `cenkt/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js`
# 3. `chrischi9/website/Tutorials/P5JS/p5.js_video/11.3_p5.js_pixels/sketch.js`
# 4. `UngPkay/website/Tutorials/P5JS/p5.js/02/2.5_p5.js_random/sketch.js`
# 5. `NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/06/6.3_p5js_Constructor_Arguments_with_Classes_in_JavaScript/sketch.js`
# 6. `Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/6.4_p5.js_constructor_function/sketch.js`
# 7. `BenjamintGibbs/Rainbow-Code/p5.js/6.4_p5.js_constructor_function/sketch.js`
# 8. `readyletsgo/PGDV_5200_MS1_SP18/00-Coding-intro/03-Iteration-For-Loop/sketch.js`
# 9. `rhedhs/website/CodingChallenges/CC_108_barnsley_fern/P5/sketch.js`
# 10. `solomadcoder2k23/website/CodingChallenges/CC_108_barnsley_fern/P5/sketch.js`
# 11. `surajjorwekar/website/Tutorials/P5JS/p5.js/02/2.5_p5.js_random/sketch.js`
# 12. `hcGamechamp/hcGamechamp.github.io/Walker OOP/sketch.js`
# 13. `MadeCurler/website/Tutorials/P5JS/p5.js/04/4.2_0_Nested_loops/sketch.js`
# 14. `Prisha13/C-31_Hw/sketch.js`
# 15. `OnesAndZer0s/website/CodingChallenges/CC_108_barnsley_fern/P5/sketch.js`
# 16. `GeekAhmeds/website/Tutorials/P5JS/p5.js/04/4.2_0_Nested_loops/sketch.js`
# 17. `aldden/website/Tutorials/P5JS/p5.js/06/6.2_p5js_Classes_in_JavaScript/sketch.js`
# 18. `OnesAndZer0s/website/Tutorials/P5JS/p5.js/07/7.7_p5.js_checking_objects_intersection_2/sketch.js`
# 19. `NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/06/6.2_p5js_Classes_in_JavaScript/sketch.js`
# 20. `JeffreyCSMA/CSMA101-fall20/week2Variables1/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `notshekhar/website/Tutorials/P5JS/p5.js/10/10.04_p5.js_Loading_JSON_from_URL/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('notshekhar/website/Tutorials/P5JS/p5.js/10/10.04_p5.js_Loading_JSON_from_URL/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `cenkt/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('cenkt/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `chrischi9/website/Tutorials/P5JS/p5.js_video/11.3_p5.js_pixels/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chrischi9/website/Tutorials/P5JS/p5.js_video/11.3_p5.js_pixels/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `UngPkay/website/Tutorials/P5JS/p5.js/02/2.5_p5.js_random/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('UngPkay/website/Tutorials/P5JS/p5.js/02/2.5_p5.js_random/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/06/6.3_p5js_Constructor_Arguments_with_Classes_in_JavaScript/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/06/6.3_p5js_Constructor_Arguments_with_Classes_in_JavaScript/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/6.4_p5.js_constructor_function/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/6.4_p5.js_constructor_function/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `BenjamintGibbs/Rainbow-Code/p5.js/6.4_p5.js_constructor_function/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BenjamintGibbs/Rainbow-Code/p5.js/6.4_p5.js_constructor_function/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `readyletsgo/PGDV_5200_MS1_SP18/00-Coding-intro/03-Iteration-For-Loop/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('readyletsgo/PGDV_5200_MS1_SP18/00-Coding-intro/03-Iteration-For-Loop/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `rhedhs/website/CodingChallenges/CC_108_barnsley_fern/P5/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('rhedhs/website/CodingChallenges/CC_108_barnsley_fern/P5/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `solomadcoder2k23/website/CodingChallenges/CC_108_barnsley_fern/P5/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('solomadcoder2k23/website/CodingChallenges/CC_108_barnsley_fern/P5/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `surajjorwekar/website/Tutorials/P5JS/p5.js/02/2.5_p5.js_random/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('surajjorwekar/website/Tutorials/P5JS/p5.js/02/2.5_p5.js_random/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `hcGamechamp/hcGamechamp.github.io/Walker OOP/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('hcGamechamp/hcGamechamp.github.io/Walker OOP/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `MadeCurler/website/Tutorials/P5JS/p5.js/04/4.2_0_Nested_loops/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('MadeCurler/website/Tutorials/P5JS/p5.js/04/4.2_0_Nested_loops/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `Prisha13/C-31_Hw/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Prisha13/C-31_Hw/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `OnesAndZer0s/website/CodingChallenges/CC_108_barnsley_fern/P5/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('OnesAndZer0s/website/CodingChallenges/CC_108_barnsley_fern/P5/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `GeekAhmeds/website/Tutorials/P5JS/p5.js/04/4.2_0_Nested_loops/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('GeekAhmeds/website/Tutorials/P5JS/p5.js/04/4.2_0_Nested_loops/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `aldden/website/Tutorials/P5JS/p5.js/06/6.2_p5js_Classes_in_JavaScript/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('aldden/website/Tutorials/P5JS/p5.js/06/6.2_p5js_Classes_in_JavaScript/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `OnesAndZer0s/website/Tutorials/P5JS/p5.js/07/7.7_p5.js_checking_objects_intersection_2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('OnesAndZer0s/website/Tutorials/P5JS/p5.js/07/7.7_p5.js_checking_objects_intersection_2/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/06/6.2_p5js_Classes_in_JavaScript/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/06/6.2_p5js_Classes_in_JavaScript/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `JeffreyCSMA/CSMA101-fall20/week2Variables1/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('JeffreyCSMA/CSMA101-fall20/week2Variables1/sketch.js')
