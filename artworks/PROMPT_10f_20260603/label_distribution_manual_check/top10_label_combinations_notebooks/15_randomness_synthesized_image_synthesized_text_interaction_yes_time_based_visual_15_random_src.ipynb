# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 15
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `15`
#
# Label combination:
#
# `randomness + synthesized_image + synthesized_text | interaction=yes | time_based + visual`
#
# Count in clean JSON: `283`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `TAAjayi/website/Tutorials/P5JS/p5.js/08/8.06_p5.js_Other_Events_and_Inputs/sketch.js`
# 2. `kjav/p5.js-website/src/assets/tutorials/trigonometry/unitCircle/sketch.js`
# 3. `fcarden/website/Tutorials/P5JS/p5.js/08/8.06_p5.js_Other_Events_and_Inputs/sketch.js`
# 4. `mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js`
# 5. `ksrisayee12/project33/project33-main/sketch.js`
# 6. `GeekAhmeds/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js`
# 7. `claudiamiranda/gray-area-immersive-summer-2016/DOM_position_html/sketch.js`
# 8. `BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js/7.2_p5.js_Creating_HTML_elements_with_JavaScript/sketch.js`
# 9. `sinka27/Project-33/sketch.js`
# 10. `seattleacademy/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js`
# 11. `mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js`
# 12. `keerrtanaa/toppr-bunny/sketch.js`
# 13. `thiagosilvafoco/quebrei/sketch.js`
# 14. `TAAjayi/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js`
# 15. `idea456/website/Tutorials/P5JS/p5.js/08/8.06_p5.js_Other_Events_and_Inputs/sketch.js`
# 16. `Tekman03/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js`
# 17. `BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js/7.3_p5.js_Manipulating_DOM_elements_html_position/sketch.js`
# 18. `rhedhs/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js`
# 19. `Hareendra-S/hareendra-srini/sketch.js`
# 20. `notshekhar/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `TAAjayi/website/Tutorials/P5JS/p5.js/08/8.06_p5.js_Other_Events_and_Inputs/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('TAAjayi/website/Tutorials/P5JS/p5.js/08/8.06_p5.js_Other_Events_and_Inputs/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `kjav/p5.js-website/src/assets/tutorials/trigonometry/unitCircle/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('kjav/p5.js-website/src/assets/tutorials/trigonometry/unitCircle/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `fcarden/website/Tutorials/P5JS/p5.js/08/8.06_p5.js_Other_Events_and_Inputs/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('fcarden/website/Tutorials/P5JS/p5.js/08/8.06_p5.js_Other_Events_and_Inputs/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `ksrisayee12/project33/project33-main/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ksrisayee12/project33/project33-main/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `GeekAhmeds/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('GeekAhmeds/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `claudiamiranda/gray-area-immersive-summer-2016/DOM_position_html/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('claudiamiranda/gray-area-immersive-summer-2016/DOM_position_html/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js/7.2_p5.js_Creating_HTML_elements_with_JavaScript/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js/7.2_p5.js_Creating_HTML_elements_with_JavaScript/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `sinka27/Project-33/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('sinka27/Project-33/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `seattleacademy/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('seattleacademy/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('mohamedsekhri/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `keerrtanaa/toppr-bunny/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('keerrtanaa/toppr-bunny/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `thiagosilvafoco/quebrei/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('thiagosilvafoco/quebrei/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `TAAjayi/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('TAAjayi/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `idea456/website/Tutorials/P5JS/p5.js/08/8.06_p5.js_Other_Events_and_Inputs/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('idea456/website/Tutorials/P5JS/p5.js/08/8.06_p5.js_Other_Events_and_Inputs/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `Tekman03/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Tekman03/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js/7.3_p5.js_Manipulating_DOM_elements_html_position/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js/7.3_p5.js_Manipulating_DOM_elements_html_position/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `rhedhs/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('rhedhs/website/Tutorials/P5JS/p5.js/08/8.05_p5.js_Interfacing_with_the_DOM/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `Hareendra-S/hareendra-srini/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Hareendra-S/hareendra-srini/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `notshekhar/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('notshekhar/website/Tutorials/P5JS/p5.js/08/8.03_p5.js_Manipulating_DOM_elements_html_position/sketch.js')
