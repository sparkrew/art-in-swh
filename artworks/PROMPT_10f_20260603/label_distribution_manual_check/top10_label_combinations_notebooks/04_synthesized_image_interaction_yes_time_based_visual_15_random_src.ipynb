# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 4
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `4`
#
# Label combination:
#
# `synthesized_image | interaction=yes | time_based + visual`
#
# Count in clean JSON: `1264`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `abhijit-dhar/website/Courses/intelligence_learning/session3/linear_regression_ordinary_least_squares/sketch.js`
# 2. `chris8855/Rainbow-Code/Courses/intelligence_learning/session3/linear_regression_ordinary_least_squares/sketch.js`
# 3. `tanay2706/C_11_Unindented_code_2/sketch.js`
# 4. `Tekman03/website/Tutorials/P5JS/p5.js/08/8.10_p5.js_select_selectAll_with_CSS_selectors/sketch.js`
# 5. `chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/3.3_p5.js_Else_and_ElseIf_and_and_or/sketch.js`
# 6. `TAAjayi/website/Tutorials/P5JS/p5.js/03/3.3_p5.js_Else_and_ElseIf_and_and_or/sketch.js`
# 7. `JesperVagn/website/Q_and_A/Q_6_p5_background/sketch.js`
# 8. `aldden/website/Tutorials/P5JS/p5.js/02/2.1_Variables_in_p5.js_mouseX_mouseY/sketch.js`
# 9. `CurlyKidd/c10/sketch.js`
# 10. `u40912216/Rainbow-Code/Tutorials/P5JS/p5.js/2.1_Variables_in_p5.js_mouseX_mouseY/sketch.js`
# 11. `liampanero/Panero-CreativeCoding-F17/Assignments/W03_09_21_17_A/sketch.js`
# 12. `KemsingTuition/itp-creative-js/Spring-2014/week6/11_touch_events/sketch.js`
# 13. `xlinx/website/Q_and_A/Q_6_p5_background/sketch.js`
# 14. `oshoham/p5.js/test/manual-test-examples/webgl/camera/box/sketch.js`
# 15. `tezzutezzu/p5.js/test/manual-test-examples/webgl/material/specular_ambient/sketch.js`
# 16. `cenkt/website/Tutorials/P5JS/p5.js/09/9.20_p5.js_Polar_Coordinates/sketch.js`
# 17. `aryan0000-sc/mango/sketch.js`
# 18. `remeyama/website/Tutorials/P5JS/p5.js/02/2.1_Variables_in_p5.js_mouseX_mouseY/sketch.js`
# 19. `fcarden/website/Tutorials/P5JS/p5.js/03/3.4_0_p5.js_Boolean_variables/sketch.js`
# 20. `GeekAhmeds/website/Tutorials/P5JS/p5.js/08/8.10_p5.js_select_selectAll_with_CSS_selectors/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `abhijit-dhar/website/Courses/intelligence_learning/session3/linear_regression_ordinary_least_squares/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('abhijit-dhar/website/Courses/intelligence_learning/session3/linear_regression_ordinary_least_squares/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `chris8855/Rainbow-Code/Courses/intelligence_learning/session3/linear_regression_ordinary_least_squares/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chris8855/Rainbow-Code/Courses/intelligence_learning/session3/linear_regression_ordinary_least_squares/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `tanay2706/C_11_Unindented_code_2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tanay2706/C_11_Unindented_code_2/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `Tekman03/website/Tutorials/P5JS/p5.js/08/8.10_p5.js_select_selectAll_with_CSS_selectors/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Tekman03/website/Tutorials/P5JS/p5.js/08/8.10_p5.js_select_selectAll_with_CSS_selectors/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/3.3_p5.js_Else_and_ElseIf_and_and_or/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chris8855/Rainbow-Code/Tutorials/P5JS/p5.js/3.3_p5.js_Else_and_ElseIf_and_and_or/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `TAAjayi/website/Tutorials/P5JS/p5.js/03/3.3_p5.js_Else_and_ElseIf_and_and_or/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('TAAjayi/website/Tutorials/P5JS/p5.js/03/3.3_p5.js_Else_and_ElseIf_and_and_or/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `JesperVagn/website/Q_and_A/Q_6_p5_background/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('JesperVagn/website/Q_and_A/Q_6_p5_background/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `aldden/website/Tutorials/P5JS/p5.js/02/2.1_Variables_in_p5.js_mouseX_mouseY/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('aldden/website/Tutorials/P5JS/p5.js/02/2.1_Variables_in_p5.js_mouseX_mouseY/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `CurlyKidd/c10/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('CurlyKidd/c10/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `u40912216/Rainbow-Code/Tutorials/P5JS/p5.js/2.1_Variables_in_p5.js_mouseX_mouseY/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('u40912216/Rainbow-Code/Tutorials/P5JS/p5.js/2.1_Variables_in_p5.js_mouseX_mouseY/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `liampanero/Panero-CreativeCoding-F17/Assignments/W03_09_21_17_A/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('liampanero/Panero-CreativeCoding-F17/Assignments/W03_09_21_17_A/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `KemsingTuition/itp-creative-js/Spring-2014/week6/11_touch_events/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('KemsingTuition/itp-creative-js/Spring-2014/week6/11_touch_events/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `xlinx/website/Q_and_A/Q_6_p5_background/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('xlinx/website/Q_and_A/Q_6_p5_background/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/webgl/camera/box/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/webgl/camera/box/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/webgl/material/specular_ambient/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/webgl/material/specular_ambient/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `cenkt/website/Tutorials/P5JS/p5.js/09/9.20_p5.js_Polar_Coordinates/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('cenkt/website/Tutorials/P5JS/p5.js/09/9.20_p5.js_Polar_Coordinates/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `aryan0000-sc/mango/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('aryan0000-sc/mango/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `remeyama/website/Tutorials/P5JS/p5.js/02/2.1_Variables_in_p5.js_mouseX_mouseY/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('remeyama/website/Tutorials/P5JS/p5.js/02/2.1_Variables_in_p5.js_mouseX_mouseY/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `fcarden/website/Tutorials/P5JS/p5.js/03/3.4_0_p5.js_Boolean_variables/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('fcarden/website/Tutorials/P5JS/p5.js/03/3.4_0_p5.js_Boolean_variables/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `GeekAhmeds/website/Tutorials/P5JS/p5.js/08/8.10_p5.js_select_selectAll_with_CSS_selectors/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('GeekAhmeds/website/Tutorials/P5JS/p5.js/08/8.10_p5.js_select_selectAll_with_CSS_selectors/sketch.js')
