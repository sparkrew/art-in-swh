# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 12
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `12`
#
# Label combination:
#
# `randomness + synthesized_image | interaction=no | static + visual`
#
# Count in clean JSON: `336`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `Pyato4ka/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js`
# 2. `abhijit-dhar/website/Courses/intelligence_learning/session4/toy-neural-network-js/examples/xor/sketch.js`
# 3. `tnishida-class/p5works-Hanako-O/section5-q1/sketch.js`
# 4. `chris8855/Rainbow-Code/Courses/natureofcode/9.10_PoolSelection/sketch.js`
# 5. `xlinx/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js`
# 6. `djhprojects/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js`
# 7. `ytferoz98/cgso/sketch.js`
# 8. `tirzatirza14/Programming-Design-Systems/W3 Martian Poster No Overlap/sketch.js`
# 9. `rhedhs/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js`
# 10. `Pyato4ka/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js`
# 11. `TAAjayi/website/Courses/natureofcode/9.10_PoolSelection/sketch.js`
# 12. `quintvanzijl/Rainbow-Code/challenges/CC_35_TSP/CC_TSP_GA_inprogress/sketch.js`
# 13. `solomadcoder2k23/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js`
# 14. `idea456/website/Courses/intelligence_learning/session4/toy-neural-network-js/examples/xor/sketch.js`
# 15. `carran085/Rainbow-Code/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js`
# 16. `notshekhar/website/Courses/intelligence_learning/session4/toy-neural-network-js/examples/xor/sketch.js`
# 17. `OnesAndZer0s/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js`
# 18. `notshekhar/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js`
# 19. `ionescugeorge/website/Courses/natureofcode/10.18-toy_neural_network/examples/xor/sketch.js`
# 20. `doxanthropos/p5.js-website/dist/assets/learn/performance/code/distance-squared/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `Pyato4ka/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Pyato4ka/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `abhijit-dhar/website/Courses/intelligence_learning/session4/toy-neural-network-js/examples/xor/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('abhijit-dhar/website/Courses/intelligence_learning/session4/toy-neural-network-js/examples/xor/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `tnishida-class/p5works-Hanako-O/section5-q1/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tnishida-class/p5works-Hanako-O/section5-q1/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `chris8855/Rainbow-Code/Courses/natureofcode/9.10_PoolSelection/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chris8855/Rainbow-Code/Courses/natureofcode/9.10_PoolSelection/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `xlinx/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('xlinx/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `djhprojects/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('djhprojects/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `ytferoz98/cgso/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ytferoz98/cgso/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `tirzatirza14/Programming-Design-Systems/W3 Martian Poster No Overlap/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tirzatirza14/Programming-Design-Systems/W3 Martian Poster No Overlap/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `rhedhs/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('rhedhs/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `Pyato4ka/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Pyato4ka/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `TAAjayi/website/Courses/natureofcode/9.10_PoolSelection/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('TAAjayi/website/Courses/natureofcode/9.10_PoolSelection/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `quintvanzijl/Rainbow-Code/challenges/CC_35_TSP/CC_TSP_GA_inprogress/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('quintvanzijl/Rainbow-Code/challenges/CC_35_TSP/CC_TSP_GA_inprogress/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `solomadcoder2k23/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('solomadcoder2k23/website/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `idea456/website/Courses/intelligence_learning/session4/toy-neural-network-js/examples/xor/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('idea456/website/Courses/intelligence_learning/session4/toy-neural-network-js/examples/xor/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `carran085/Rainbow-Code/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('carran085/Rainbow-Code/Tutorials/P5JS/p5.js/09/9.15_p5.js_2D_Arrays/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `notshekhar/website/Courses/intelligence_learning/session4/toy-neural-network-js/examples/xor/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('notshekhar/website/Courses/intelligence_learning/session4/toy-neural-network-js/examples/xor/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `OnesAndZer0s/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('OnesAndZer0s/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `notshekhar/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('notshekhar/website/Courses/programming_with_text/session11/11-07_New_Tab_Override/sketch/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `ionescugeorge/website/Courses/natureofcode/10.18-toy_neural_network/examples/xor/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ionescugeorge/website/Courses/natureofcode/10.18-toy_neural_network/examples/xor/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `doxanthropos/p5.js-website/dist/assets/learn/performance/code/distance-squared/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('doxanthropos/p5.js-website/dist/assets/learn/performance/code/distance-squared/sketch.js')
