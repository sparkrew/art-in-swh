# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 7
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `7`
#
# Label combination:
#
# `synthesized_image | interaction=no | static + visual`
#
# Count in clean JSON: `997`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `yusukesaitoh/website/Tutorials/P5JS/p5.js/05/5.2_p5.js_function_parameters_and_arguments/sketch.js`
# 2. `gabriel-combe/Rainbow-Code/Tutorials/P5JS/p5.js/1.2_p5.js_Color/sketch.js`
# 3. `oshoham/p5.js/test/manual-test-examples/webgl/rectStroke/sketch.js`
# 4. `NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/04/4.1_1_p5.js_while_for/sketch.js`
# 5. `pcsteppan/p5.js/test/manual-test-examples/webgl/lights/ambientLight/sketch.js`
# 6. `aldden/website/Tutorials/P5JS/p5.js/01/1.4_p5.js_Color/sketch.js`
# 7. `xlinx/website/Tutorials/P5JS/p5.js/09/9.17_p5.js_Arguments/sketch.js`
# 8. `oshoham/p5.js/test/manual-test-examples/tutorials/DOM-extensions/8/sketch.js`
# 9. `aldden/website/Tutorials/P5JS/p5.js/04/4.1_1_p5.js_while_for/sketch.js`
# 10. `hcGamechamp/hcGamechamp.github.io/Chess Board/sketch.js`
# 11. `pravinvignesh/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-2/Quiz/TestingCode/sketch.js`
# 12. `SNGmagician/CC191-Work/InClassWork/02-DrawingCircles/sketch.js`
# 13. `peachplusplus/Video-Lesson-Materials/code_p5.js/5.2_p5.js_Function_parameters_and_arguments /sketch.js`
# 14. `BenjamintGibbs/Rainbow-Code/p5.js/1.2_p5.js_Color/sketch.js`
# 15. `Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/4.1b_p5.js_while_for/sketch.js`
# 16. `AfroDisco/website/Tutorials/P5JS/p5.js/01/1.4_p5.js_Color/sketch.js`
# 17. `abhijit-dhar/website/Tutorials/P5JS/p5.js/09/9.17_p5.js_Arguments/sketch.js`
# 18. `sienayu0111/iamnewtutu/sketch.js`
# 19. `Tekman03/website/Tutorials/P5JS/p5.js/04/4.1_0_p5.js_while/sketch.js`
# 20. `patrickdolloso/CM1005/W7 Conditionals and variable types/4.203/blinky robot start/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `yusukesaitoh/website/Tutorials/P5JS/p5.js/05/5.2_p5.js_function_parameters_and_arguments/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('yusukesaitoh/website/Tutorials/P5JS/p5.js/05/5.2_p5.js_function_parameters_and_arguments/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `gabriel-combe/Rainbow-Code/Tutorials/P5JS/p5.js/1.2_p5.js_Color/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('gabriel-combe/Rainbow-Code/Tutorials/P5JS/p5.js/1.2_p5.js_Color/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/webgl/rectStroke/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/webgl/rectStroke/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/04/4.1_1_p5.js_while_for/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('NextSyes/Rainbow-Code/Tutorials/P5JS/p5.js/04/4.1_1_p5.js_while_for/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `pcsteppan/p5.js/test/manual-test-examples/webgl/lights/ambientLight/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('pcsteppan/p5.js/test/manual-test-examples/webgl/lights/ambientLight/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `aldden/website/Tutorials/P5JS/p5.js/01/1.4_p5.js_Color/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('aldden/website/Tutorials/P5JS/p5.js/01/1.4_p5.js_Color/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `xlinx/website/Tutorials/P5JS/p5.js/09/9.17_p5.js_Arguments/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('xlinx/website/Tutorials/P5JS/p5.js/09/9.17_p5.js_Arguments/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/tutorials/DOM-extensions/8/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/tutorials/DOM-extensions/8/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `aldden/website/Tutorials/P5JS/p5.js/04/4.1_1_p5.js_while_for/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('aldden/website/Tutorials/P5JS/p5.js/04/4.1_1_p5.js_while_for/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `hcGamechamp/hcGamechamp.github.io/Chess Board/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('hcGamechamp/hcGamechamp.github.io/Chess Board/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `pravinvignesh/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-2/Quiz/TestingCode/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('pravinvignesh/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-2/Quiz/TestingCode/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `SNGmagician/CC191-Work/InClassWork/02-DrawingCircles/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SNGmagician/CC191-Work/InClassWork/02-DrawingCircles/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `peachplusplus/Video-Lesson-Materials/code_p5.js/5.2_p5.js_Function_parameters_and_arguments /sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('peachplusplus/Video-Lesson-Materials/code_p5.js/5.2_p5.js_Function_parameters_and_arguments /sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `BenjamintGibbs/Rainbow-Code/p5.js/1.2_p5.js_Color/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BenjamintGibbs/Rainbow-Code/p5.js/1.2_p5.js_Color/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/4.1b_p5.js_while_for/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/4.1b_p5.js_while_for/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `AfroDisco/website/Tutorials/P5JS/p5.js/01/1.4_p5.js_Color/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('AfroDisco/website/Tutorials/P5JS/p5.js/01/1.4_p5.js_Color/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `abhijit-dhar/website/Tutorials/P5JS/p5.js/09/9.17_p5.js_Arguments/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('abhijit-dhar/website/Tutorials/P5JS/p5.js/09/9.17_p5.js_Arguments/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `sienayu0111/iamnewtutu/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('sienayu0111/iamnewtutu/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `Tekman03/website/Tutorials/P5JS/p5.js/04/4.1_0_p5.js_while/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Tekman03/website/Tutorials/P5JS/p5.js/04/4.1_0_p5.js_while/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `patrickdolloso/CM1005/W7 Conditionals and variable types/4.203/blinky robot start/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/W7 Conditionals and variable types/4.203/blinky robot start/sketch.js')
