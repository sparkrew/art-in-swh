# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 3
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `3`
#
# Label combination:
#
# `synthesized_image | interaction=no | time_based + visual`
#
# Count in clean JSON: `1543`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `AfroDisco/website/Tutorials/P5JS/p5.js/09/9.05_0_p5.js_setInterval/sketch.js`
# 2. `fcarden/website/Tutorials/P5JS/p5.js/05/5.1_1_p5.js_functions/sketch.js`
# 3. `Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/2.2_Variables_in_p5.js_user_defined/sketch.js`
# 4. `msyem2014/website/Tutorials/P5JS/p5.js/09/9.03_p5.js_Transformation_Pt.3/sketch.js`
# 5. `quatmo/p5.js/examples/risdf13/10_transforms/10-3/sketch.js`
# 6. `su-per-man/website/Tutorials/P5JS/p5.js/09/9.03_p5.js_Transformation_Pt.3/sketch.js`
# 7. `tezzutezzu/p5.js/test/manual-test-examples/webgl/interaction/orbitControl/sketch.js`
# 8. `Vishal-cod/website-3/Tutorials/P5JS/p5.js/09/9.06_p5.js_Closure/sketch.js`
# 9. `fcarden/website/Tutorials/P5JS/p5.js/09/9.03_p5.js_Transformation_Pt.3/sketch.js`
# 10. `kyoheria/code2/quiz/num6/sketch.js`
# 11. `cesar-neri/p5js-sketches/dotted_spiral/sketch.js`
# 12. `GeekAhmeds/website/Tutorials/P5JS/p5.js/02/2.3_0_p5.js_JavaScript_without_objects/sketch.js`
# 13. `abhijit-dhar/website/Tutorials/P5JS/p5.js/09/9.01_p5.js_Transformation_Pt.1/sketch.js`
# 14. `Anninster/website/Tutorials/P5JS/p5.js/02/2.3_1_p5.js_JavaScript_with_objects/sketch.js`
# 15. `ManishKumar102/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-302/Art heist/sketch.js`
# 16. `oshoham/p5.js/test/manual-test-examples/p5.Renderer2D/arc/scalingCorrection/sketch.js`
# 17. `MadeCurler/website/Tutorials/P5JS/p5.js/02/2.3_1_p5.js_JavaScript_with_objects/sketch.js`
# 18. `chrischi9/website/Tutorials/P5JS/p5.js/09/9.05_0_p5.js_setInterval/sketch.js`
# 19. `PrinceGrewal/website/CodingChallenges/CC_089_langtonsant/P5/sketch.js`
# 20. `readyletsgo/PGDV_5200_MS1_SP18/14-html-css-p5/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `AfroDisco/website/Tutorials/P5JS/p5.js/09/9.05_0_p5.js_setInterval/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('AfroDisco/website/Tutorials/P5JS/p5.js/09/9.05_0_p5.js_setInterval/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `fcarden/website/Tutorials/P5JS/p5.js/05/5.1_1_p5.js_functions/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('fcarden/website/Tutorials/P5JS/p5.js/05/5.1_1_p5.js_functions/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/2.2_Variables_in_p5.js_user_defined/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js/2.2_Variables_in_p5.js_user_defined/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `msyem2014/website/Tutorials/P5JS/p5.js/09/9.03_p5.js_Transformation_Pt.3/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('msyem2014/website/Tutorials/P5JS/p5.js/09/9.03_p5.js_Transformation_Pt.3/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `quatmo/p5.js/examples/risdf13/10_transforms/10-3/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('quatmo/p5.js/examples/risdf13/10_transforms/10-3/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `su-per-man/website/Tutorials/P5JS/p5.js/09/9.03_p5.js_Transformation_Pt.3/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('su-per-man/website/Tutorials/P5JS/p5.js/09/9.03_p5.js_Transformation_Pt.3/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/webgl/interaction/orbitControl/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/webgl/interaction/orbitControl/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `Vishal-cod/website-3/Tutorials/P5JS/p5.js/09/9.06_p5.js_Closure/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Vishal-cod/website-3/Tutorials/P5JS/p5.js/09/9.06_p5.js_Closure/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `fcarden/website/Tutorials/P5JS/p5.js/09/9.03_p5.js_Transformation_Pt.3/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('fcarden/website/Tutorials/P5JS/p5.js/09/9.03_p5.js_Transformation_Pt.3/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `kyoheria/code2/quiz/num6/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('kyoheria/code2/quiz/num6/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `cesar-neri/p5js-sketches/dotted_spiral/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('cesar-neri/p5js-sketches/dotted_spiral/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `GeekAhmeds/website/Tutorials/P5JS/p5.js/02/2.3_0_p5.js_JavaScript_without_objects/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('GeekAhmeds/website/Tutorials/P5JS/p5.js/02/2.3_0_p5.js_JavaScript_without_objects/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `abhijit-dhar/website/Tutorials/P5JS/p5.js/09/9.01_p5.js_Transformation_Pt.1/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('abhijit-dhar/website/Tutorials/P5JS/p5.js/09/9.01_p5.js_Transformation_Pt.1/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `Anninster/website/Tutorials/P5JS/p5.js/02/2.3_1_p5.js_JavaScript_with_objects/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Anninster/website/Tutorials/P5JS/p5.js/02/2.3_1_p5.js_JavaScript_with_objects/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `ManishKumar102/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-302/Art heist/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ManishKumar102/Online-Courses-Learning/Coursera/Introduction to Computer Programming/Week-1/Assignment/Case-302/Art heist/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/p5.Renderer2D/arc/scalingCorrection/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/p5.Renderer2D/arc/scalingCorrection/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `MadeCurler/website/Tutorials/P5JS/p5.js/02/2.3_1_p5.js_JavaScript_with_objects/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('MadeCurler/website/Tutorials/P5JS/p5.js/02/2.3_1_p5.js_JavaScript_with_objects/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `chrischi9/website/Tutorials/P5JS/p5.js/09/9.05_0_p5.js_setInterval/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chrischi9/website/Tutorials/P5JS/p5.js/09/9.05_0_p5.js_setInterval/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `PrinceGrewal/website/CodingChallenges/CC_089_langtonsant/P5/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('PrinceGrewal/website/CodingChallenges/CC_089_langtonsant/P5/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `readyletsgo/PGDV_5200_MS1_SP18/14-html-css-p5/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('readyletsgo/PGDV_5200_MS1_SP18/14-html-css-p5/sketch.js')
