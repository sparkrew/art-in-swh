# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 19
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `19`
#
# Label combination:
#
# `processed_text + synthesized_text | interaction=no | static + visual`
#
# Count in clean JSON: `231`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `msyem2014/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js`
# 2. `ionescugeorge/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
# 3. `UngPkay/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js`
# 4. `su-per-man/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js`
# 5. `remeyama/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
# 6. `BenjamintGibbs/Rainbow-Code/p5.js/8.3_p5.js_what_is_JSON_pt2/sketch.js`
# 7. `oshoham/p5.js/test/manual-test-examples/async/loadJSON_preload/sketch.js`
# 8. `Anninster/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
# 9. `Scream145/Rainbow-Code/p5.js/8.3_p5.js_what_is_JSON_pt2/sketch.js`
# 10. `tezzutezzu/p5.js/test/manual-test-examples/p5.Font/textAsWords/sketch.js`
# 11. `willy-goat/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js`
# 12. `pcsteppan/p5.js/test/manual-test-examples/async/loadJSON_preload/sketch.js`
# 13. `tezzutezzu/p5.js/test/manual-test-examples/p5.Font/callback/sketch.js`
# 14. `chenhuaixian/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
# 15. `PrinceGrewal/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
# 16. `abhijit-dhar/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
# 17. `quatmo/p5.js/examples/async/loadJSON_preload/sketch.js`
# 18. `quintvanzijl/Rainbow-Code/p5.js/8.3_p5.js_what_is_JSON_pt2/sketch.js`
# 19. `KemsingTuition/itp-creative-js/week5/01_p5_examples/07_external_API_nytimes/sketch.js`
# 20. `nikitahuggins/networkedmedia/week5/01-apis/01_weather_p5_dom/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `msyem2014/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('msyem2014/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `ionescugeorge/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ionescugeorge/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `UngPkay/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('UngPkay/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `su-per-man/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('su-per-man/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `remeyama/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('remeyama/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `BenjamintGibbs/Rainbow-Code/p5.js/8.3_p5.js_what_is_JSON_pt2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BenjamintGibbs/Rainbow-Code/p5.js/8.3_p5.js_what_is_JSON_pt2/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/async/loadJSON_preload/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/async/loadJSON_preload/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `Anninster/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Anninster/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `Scream145/Rainbow-Code/p5.js/8.3_p5.js_what_is_JSON_pt2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Scream145/Rainbow-Code/p5.js/8.3_p5.js_what_is_JSON_pt2/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/p5.Font/textAsWords/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/p5.Font/textAsWords/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `willy-goat/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('willy-goat/website/Tutorials/P5JS/p5.js/10/10.09_p5.js_New_York_Times_API/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `pcsteppan/p5.js/test/manual-test-examples/async/loadJSON_preload/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('pcsteppan/p5.js/test/manual-test-examples/async/loadJSON_preload/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/p5.Font/callback/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/p5.Font/callback/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `chenhuaixian/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chenhuaixian/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `PrinceGrewal/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('PrinceGrewal/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `abhijit-dhar/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('abhijit-dhar/website/Tutorials/P5JS/p5.js/10/10.03_p5.js_what_is_JSON_pt2/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `quatmo/p5.js/examples/async/loadJSON_preload/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('quatmo/p5.js/examples/async/loadJSON_preload/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `quintvanzijl/Rainbow-Code/p5.js/8.3_p5.js_what_is_JSON_pt2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('quintvanzijl/Rainbow-Code/p5.js/8.3_p5.js_what_is_JSON_pt2/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `KemsingTuition/itp-creative-js/week5/01_p5_examples/07_external_API_nytimes/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('KemsingTuition/itp-creative-js/week5/01_p5_examples/07_external_API_nytimes/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `nikitahuggins/networkedmedia/week5/01-apis/01_weather_p5_dom/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('nikitahuggins/networkedmedia/week5/01-apis/01_weather_p5_dom/sketch.js')
