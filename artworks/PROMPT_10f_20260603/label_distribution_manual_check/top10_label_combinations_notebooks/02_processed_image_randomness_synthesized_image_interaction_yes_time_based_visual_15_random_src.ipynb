# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 2
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `2`
#
# Label combination:
#
# `processed_image + randomness + synthesized_image | interaction=yes | time_based + visual`
#
# Count in clean JSON: `1861`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `NeilS139/P46/PRO-C14-stage5-main/sketch.js`
# 2. `VARD1234/TREX/sketch.js`
# 3. `PedroMarvel/star-wars/sketch.js`
# 4. `Jorge013/projeto12-jorge/sketch.js`
# 5. `Debparnamukherjee/juxaon-2/sketch.js`
# 6. `Bravo67000/proj18/sketch.js`
# 7. `beatrizstaub/gut/sketch.js`
# 8. `Vaeda/Trex/sketch.js`
# 9. `DarkNinja7/Pro---14/sketch.js`
# 10. `Newrock537/1st-program/sketch.js`
# 11. `InaaraHabib/PROJETO-14/sketch.js`
# 12. `coolperson0917/Collecting-Treasure-/Collection-tresure-1-template-main/sketch.js`
# 13. `luxiR/Class-Project-42/sketch.js`
# 14. `KartikYadav9953/Treasure/sketch.js`
# 15. `Coderaffan/Project-16/Folder 16-1/Project-Template-C16-main/sketch.js`
# 16. `garima3191/rabbit/sketch.js`
# 17. `AtulyaSharma17/Plucking-Mangoes/sketch.js`
# 18. `Nikil273/NinjaFruit/sketch.js`
# 19. `majogomezf/GLOBOS-2/sketch.js`
# 20. `mehar218/trex-/trex/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `NeilS139/P46/PRO-C14-stage5-main/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('NeilS139/P46/PRO-C14-stage5-main/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `VARD1234/TREX/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('VARD1234/TREX/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `PedroMarvel/star-wars/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('PedroMarvel/star-wars/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `Jorge013/projeto12-jorge/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Jorge013/projeto12-jorge/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `Debparnamukherjee/juxaon-2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Debparnamukherjee/juxaon-2/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `Bravo67000/proj18/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Bravo67000/proj18/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `beatrizstaub/gut/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('beatrizstaub/gut/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `Vaeda/Trex/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Vaeda/Trex/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `DarkNinja7/Pro---14/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('DarkNinja7/Pro---14/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `Newrock537/1st-program/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Newrock537/1st-program/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `InaaraHabib/PROJETO-14/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('InaaraHabib/PROJETO-14/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `coolperson0917/Collecting-Treasure-/Collection-tresure-1-template-main/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('coolperson0917/Collecting-Treasure-/Collection-tresure-1-template-main/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `luxiR/Class-Project-42/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('luxiR/Class-Project-42/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `KartikYadav9953/Treasure/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('KartikYadav9953/Treasure/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `Coderaffan/Project-16/Folder 16-1/Project-Template-C16-main/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Coderaffan/Project-16/Folder 16-1/Project-Template-C16-main/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `garima3191/rabbit/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('garima3191/rabbit/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `AtulyaSharma17/Plucking-Mangoes/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "processed_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('AtulyaSharma17/Plucking-Mangoes/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `Nikil273/NinjaFruit/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Nikil273/NinjaFruit/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `majogomezf/GLOBOS-2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('majogomezf/GLOBOS-2/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `mehar218/trex-/trex/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('mehar218/trex-/trex/sketch.js')
