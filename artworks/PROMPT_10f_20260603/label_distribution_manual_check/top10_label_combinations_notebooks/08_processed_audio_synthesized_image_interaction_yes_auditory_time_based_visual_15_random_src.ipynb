# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 8
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `8`
#
# Label combination:
#
# `processed_audio + synthesized_image | interaction=yes | auditory + time_based + visual`
#
# Count in clean JSON: `597`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/autoCorrelation/sketch.js`
# 2. `quentinzeroo/p5.js-sound/examples/waveform/sketch.js`
# 3. `crecord/p5.js/examples/addons/p5.sound/micFFT/sketch.js`
# 4. `robertesler/p5.js-sound/examples/record/sketch.js`
# 5. `Adidev2714/JumpingBOX/sketch.js`
# 6. `oshoham/p5.js/test/manual-test-examples/dom/audio_button_slider/sketch.js`
# 7. `tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/FFT_frequency_spectrum/sketch.js`
# 8. `zoalst/p5.js/examples/addons/p5.sound/FFT_freqRange/sketch.js`
# 9. `yogspace/p5.js-sound/examples/peakDetect_basic/sketch.js`
# 10. `Ishika1932008/balls-and-blocks/sketch.js`
# 11. `lucabecci/Voice-Amplitude/sketch.js`
# 12. `crecord/p5.js/examples/addons/p5.sound/FFT_waveform/sketch.js`
# 13. `tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/micLevel/sketch.js`
# 14. `quatmo/p5.js/examples/addons/p5.sound/loadSound_preload/sketch.js`
# 15. `jardimlab/p5.js-sound/examples/micFFT/sketch.js`
# 16. `queenuslinus/p5.js-sound/examples/micFFT/sketch.js`
# 17. `mrbrettsmith/prog4tw/week12/exerc/sketch.js`
# 18. `tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/loadSound_preload/sketch.js`
# 19. `oshoham/p5.js/test/manual-test-examples/addons/p5.sound/waveform/sketch.js`
# 20. `hacklabes/HackNights_Intro_2016_January/09-animation-moving-around-patterns/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/autoCorrelation/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/autoCorrelation/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `quentinzeroo/p5.js-sound/examples/waveform/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('quentinzeroo/p5.js-sound/examples/waveform/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `crecord/p5.js/examples/addons/p5.sound/micFFT/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('crecord/p5.js/examples/addons/p5.sound/micFFT/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `robertesler/p5.js-sound/examples/record/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('robertesler/p5.js-sound/examples/record/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `Adidev2714/JumpingBOX/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Adidev2714/JumpingBOX/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/dom/audio_button_slider/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/dom/audio_button_slider/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/FFT_frequency_spectrum/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/FFT_frequency_spectrum/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `zoalst/p5.js/examples/addons/p5.sound/FFT_freqRange/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('zoalst/p5.js/examples/addons/p5.sound/FFT_freqRange/sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `yogspace/p5.js-sound/examples/peakDetect_basic/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('yogspace/p5.js-sound/examples/peakDetect_basic/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `Ishika1932008/balls-and-blocks/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Ishika1932008/balls-and-blocks/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `lucabecci/Voice-Amplitude/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('lucabecci/Voice-Amplitude/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `crecord/p5.js/examples/addons/p5.sound/FFT_waveform/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('crecord/p5.js/examples/addons/p5.sound/FFT_waveform/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/micLevel/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/micLevel/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `quatmo/p5.js/examples/addons/p5.sound/loadSound_preload/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('quatmo/p5.js/examples/addons/p5.sound/loadSound_preload/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `jardimlab/p5.js-sound/examples/micFFT/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('jardimlab/p5.js-sound/examples/micFFT/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `queenuslinus/p5.js-sound/examples/micFFT/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('queenuslinus/p5.js-sound/examples/micFFT/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `mrbrettsmith/prog4tw/week12/exerc/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('mrbrettsmith/prog4tw/week12/exerc/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/loadSound_preload/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tezzutezzu/p5.js/test/manual-test-examples/addons/p5.sound/loadSound_preload/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/addons/p5.sound/waveform/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/addons/p5.sound/waveform/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `hacklabes/HackNights_Intro_2016_January/09-animation-moving-around-patterns/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('hacklabes/HackNights_Intro_2016_January/09-animation-moving-around-patterns/sketch.js')
