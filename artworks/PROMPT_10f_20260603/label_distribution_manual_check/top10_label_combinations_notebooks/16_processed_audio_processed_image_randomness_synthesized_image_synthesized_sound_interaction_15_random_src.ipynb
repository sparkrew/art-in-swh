# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Manual check — Top label combination 16
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Rank: `16`
#
# Label combination:
#
# `processed_audio + processed_image + randomness + synthesized_image + synthesized_sound | interaction=yes | auditory + time_based + visual`
#
# Count in clean JSON: `281`
#
# Samples in this notebook: `20`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`

# %% [markdown]
# ## Sample paths
#
# 1. `SohanD7/Project-38/sketch.js`
# 2. `Mandeep2010/project-42/sketch.js`
# 3. `keshavg1407/Fruit-Ninja-Game/sketch.js`
# 4. `ArshadJamal2431/Project-38/sketch.js`
# 5. `oodhav/project-39/sketch.js`
# 6. `Devraj52/Silicon/sketch.js`
# 7. `Shyama2006/Kangaroo2/sketch.js`
# 8. `Krrishscode/ProjectC-16./sketch.js`
# 9. `Pushkarneravetla/project-39-kangaroo-jumping-2/sketch.js`
# 10. `bhavishya-git-bot/colour-full-trex/sketch.js`
# 11. `SuperBeast101/CuttingFruitsGame/sketch.js`
# 12. `Vayema/INFINITE-GAME-RUNNER/sketch.js`
# 13. `jefortis/ProV2Proyecto38OK/sketch.js`
# 14. `SurajKumarSingh69/PRO-C48-SHOOTING-RANGE-II/KANGAROO-IN-JUNGLE-II-main/project-template-KANGAROO-IN-JUNGLE-II-main/sketch.js`
# 15. `abhinavkwj/ghostRunner/sketch.js`
# 16. `Rajveer-Kapoor/Trex/sketch.js`
# 17. `bhavnaWHJ/dakshGame/sketch.js`
# 18. `idkidkidk-coder/trex-but-with-dumb-images/sketch.js`
# 19. `Suraj20081/pro-38/sketch.js`
# 20. `Anne1916/Trex_V2_C39/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `SohanD7/Project-38/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SohanD7/Project-38/sketch.js')

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `Mandeep2010/project-42/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Mandeep2010/project-42/sketch.js')

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `keshavg1407/Fruit-Ninja-Game/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('keshavg1407/Fruit-Ninja-Game/sketch.js')

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `ArshadJamal2431/Project-38/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ArshadJamal2431/Project-38/sketch.js')

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `oodhav/project-39/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('oodhav/project-39/sketch.js')

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `Devraj52/Silicon/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "processed_audio",
#     "synthesized_image",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Devraj52/Silicon/sketch.js')

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `Shyama2006/Kangaroo2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Shyama2006/Kangaroo2/sketch.js')

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `Krrishscode/ProjectC-16./sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Krrishscode/ProjectC-16./sketch.js')

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `Pushkarneravetla/project-39-kangaroo-jumping-2/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Pushkarneravetla/project-39-kangaroo-jumping-2/sketch.js')

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `bhavishya-git-bot/colour-full-trex/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('bhavishya-git-bot/colour-full-trex/sketch.js')

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `SuperBeast101/CuttingFruitsGame/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SuperBeast101/CuttingFruitsGame/sketch.js')

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `Vayema/INFINITE-GAME-RUNNER/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Vayema/INFINITE-GAME-RUNNER/sketch.js')

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `jefortis/ProV2Proyecto38OK/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('jefortis/ProV2Proyecto38OK/sketch.js')

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `SurajKumarSingh69/PRO-C48-SHOOTING-RANGE-II/KANGAROO-IN-JUNGLE-II-main/project-template-KANGAROO-IN-JUNGLE-II-main/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SurajKumarSingh69/PRO-C48-SHOOTING-RANGE-II/KANGAROO-IN-JUNGLE-II-main/project-template-KANGAROO-IN-JUNGLE-II-main/sketch.js')

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `abhinavkwj/ghostRunner/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('abhinavkwj/ghostRunner/sketch.js')

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `Rajveer-Kapoor/Trex/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Rajveer-Kapoor/Trex/sketch.js')

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `bhavnaWHJ/dakshGame/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('bhavnaWHJ/dakshGame/sketch.js')

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `idkidkidk-coder/trex-but-with-dumb-images/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('idkidkidk-coder/trex-but-with-dumb-images/sketch.js')

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `Suraj20081/pro-38/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Suraj20081/pro-38/sketch.js')

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `Anne1916/Trex_V2_C39/sketch.js`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio",
#     "synthesized_sound",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Anne1916/Trex_V2_C39/sketch.js')
