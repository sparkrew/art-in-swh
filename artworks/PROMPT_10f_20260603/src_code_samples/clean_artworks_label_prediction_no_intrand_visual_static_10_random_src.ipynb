# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_no_intrand_visual_static.json`
#
# Prompt version: `PROMPT_10f`
#
# Run date: `20260603`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `oshoham/p5.js/test/manual-test-examples/webgl/material/edgestroke/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('oshoham/p5.js/test/manual-test-examples/webgl/material/edgestroke/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `idea456/website/challenges/coding-in-the-cabana/002_collatz_conjecture/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('idea456/website/challenges/coding-in-the-cabana/002_collatz_conjecture/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `PrinceGrewal/website/challenges/coding-in-the-cabana/003_hilbert_curve/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('PrinceGrewal/website/challenges/coding-in-the-cabana/003_hilbert_curve/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `OnesAndZer0s/website/Tutorials/P5JS/p5.js/03/3.2_p5.js_The_Bouncing_Ball/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('OnesAndZer0s/website/Tutorials/P5JS/p5.js/03/3.2_p5.js_The_Bouncing_Ball/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `su-per-man/website/CodingChallenges/CC_134_Heart_Curve_2/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('su-per-man/website/CodingChallenges/CC_134_Heart_Curve_2/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `ajn400/ajn100/algorithm/p5_l/basicLogicOrNothing/nestedLine/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('ajn400/ajn100/algorithm/p5_l/basicLogicOrNothing/nestedLine/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `doxanthropos/p5.js-website/src/assets/learn/performance/code/fps-demo/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('doxanthropos/p5.js-website/src/assets/learn/performance/code/fps-demo/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `mohamedsekhri/website/CodingChallenges/CC_025_SphereGeometry/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('mohamedsekhri/website/CodingChallenges/CC_025_SphereGeometry/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `eve31/website/CodingChallenges/CC_159_simple_pendulum_simulation/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('eve31/website/CodingChallenges/CC_159_simple_pendulum_simulation/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `Pyato4ka/website/challenges/coding-in-the-cabana/003_hilbert_curve/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image'] | interaction=['no'] | outcome=['visual', 'time_based']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```

# %%
print_code_file('Pyato4ka/website/challenges/coding-in-the-cabana/003_hilbert_curve/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 10
