# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_no_entities.json`
#
# Prompt version: `PROMPT_10f`
#
# Run date: `20260603`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `jeremydouglass/p5.js-website/src/assets/learn/performance/code/reflow-dom-manipulation/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('jeremydouglass/p5.js-website/src/assets/learn/performance/code/reflow-dom-manipulation/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `MadeCurler/website/Tutorials/P5JS/p5.js/08/8.14_1_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('MadeCurler/website/Tutorials/P5JS/p5.js/08/8.14_1_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `kartikey54/A2Z-F17/week2-regex/01_regexbasics/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('kartikey54/A2Z-F17/week2-regex/01_regexbasics/sketch.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `BenjamintGibbs/Rainbow-Code/p5.js/7.13.2_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('BenjamintGibbs/Rainbow-Code/p5.js/7.13.2_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `Dani-CA/archive/Dani-CA/proposte_concept/REV 3/Sketch/p5_arduino/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Dani-CA/archive/Dani-CA/proposte_concept/REV 3/Sketch/p5_arduino/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `ronavt/Calculator/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('ronavt/Calculator/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `Biswajyoti-Kalita/A2Z-F17/week2-regex/01_regexbasics/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Biswajyoti-Kalita/A2Z-F17/week2-regex/01_regexbasics/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `dsp-testing/A2Z-F15/week3/01_regexbasics/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "static"
#   ]
# }
# ```

# %%
print_code_file('dsp-testing/A2Z-F15/week3/01_regexbasics/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `seanwoodward/Rainbow-Code/p5.js/7.13.2_p5.js_parent()_and_child()_again_with_variables/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['no'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('seanwoodward/Rainbow-Code/p5.js/7.13.2_p5.js_parent()_and_child()_again_with_variables/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `dsp-testing/A2Z-F15/week2/07_textarea/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('dsp-testing/A2Z-F15/week2/07_textarea/sketch.js')

# %% [markdown]
# ### Notes for Sample 10
