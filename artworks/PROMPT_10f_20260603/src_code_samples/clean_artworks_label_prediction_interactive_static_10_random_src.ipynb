# %%
from pathlib import Path
from IPython.display import Markdown, display

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Source code samples
#
# JSON file: `clean_artworks_label_prediction_interactive_static.json`
#
# Prompt version: `PROMPT_10f`
#
# Run date: `20260603`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `maydaypu/DMX-Examples/p5.webserial-dmx/sketch.js`
#
# **Label combination:**
#
# `entities=[] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('maydaypu/DMX-Examples/p5.webserial-dmx/sketch.js')

# %% [markdown]
# ### Notes for Sample 1

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `willy-goat/website/CodingChallenges/CC_156_Pi_Digits/p5-multi/p5/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('willy-goat/website/CodingChallenges/CC_156_Pi_Digits/p5-multi/p5/sketch.js')

# %% [markdown]
# ### Notes for Sample 2

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `Vaayaa/website/Courses/A2Z/session09/9-03_FirebaseRetrievingData/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Vaayaa/website/Courses/A2Z/session09/9-03_FirebaseRetrievingData/sketch.js')

# %% [markdown]
# ### Notes for Sample 3

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `Vaayaa/website/Courses/A2Z/session07/7-03_CFGwithRiTaJS/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Vaayaa/website/Courses/A2Z/session07/7-03_CFGwithRiTaJS/sketch.js')

# %% [markdown]
# ### Notes for Sample 4

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `Scream145/Rainbow-Code/A2Z/session2/2-08_regexSplit/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Scream145/Rainbow-Code/A2Z/session2/2-08_regexSplit/sketch.js')

# %% [markdown]
# ### Notes for Sample 5

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `chenhuaixian/website/CodingChallenges/CC_037_diastic/P5/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('chenhuaixian/website/CodingChallenges/CC_037_diastic/P5/sketch.js')

# %% [markdown]
# ### Notes for Sample 6

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `yusukesaitoh/website/Courses/programming_with_text/session09/9-03_FirebaseRetrievingData/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('yusukesaitoh/website/Courses/programming_with_text/session09/9-03_FirebaseRetrievingData/sketch.js')

# %% [markdown]
# ### Notes for Sample 7

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js/7.6_p5.js_The_basics_of_CSS/sketch.js`
#
# **Label combination:**
#
# `entities=['synthesized_image', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('BigBelts/Rainbow-Code/Tutorials/P5JS/p5.js/7.6_p5.js_The_basics_of_CSS/sketch.js')

# %% [markdown]
# ### Notes for Sample 8

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `chris8855/Rainbow-Code/CodingChallenges/CC_37_diastic/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('chris8855/Rainbow-Code/CodingChallenges/CC_37_diastic/sketch.js')

# %% [markdown]
# ### Notes for Sample 9

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `Vaayaa/website/Courses/A2Z/session03/3-01_rita_js/sketch.js`
#
# **Label combination:**
#
# `entities=['processed_text', 'synthesized_text'] | interaction=['yes'] | outcome=['visual', 'static']`
#
# **Complete labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```

# %%
print_code_file('Vaayaa/website/Courses/A2Z/session03/3-01_rita_js/sketch.js')

# %% [markdown]
# ### Notes for Sample 10
