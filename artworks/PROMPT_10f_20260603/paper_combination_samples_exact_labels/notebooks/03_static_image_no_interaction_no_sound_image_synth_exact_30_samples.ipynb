# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Static image, no interaction, no sound, image synth
#
# Exactly: static visual image, interaction = no, no sound, synthesized image. Entities can be synthesized_image alone, or synthesized_image with randomness, processed_image, or both.
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Matching files after filtering: `253`
#
# Samples in this notebook: `30`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`
#
# Excluded path terms: `Tutorials, Coursera, CodingChallenges, Rainbow-Code, Courses, p5.js, week`

# %% [markdown]
# ## Sample paths
#
# 1. `hacklabes/HackNights_Intro_2016_January/04-functions-transform-explained/sketch.js`
# 2. `tirzatirza14/Programming-Design-Systems/W1 Ice Cream Icons/sketch.js`
# 3. `SNGmagician/CC191-Work/InClassWork/04-1/03-VariableScope/sketch.js`
# 4. `PRANAYGOUR/sv-pwegnaehg/sketch.js`
# 5. `FukBrachetti/dsii-2017-archive/davideonestini/making-visible/coding/earthquake-01/sketch.js`
# 6. `gapgag55/BrowserGames/Polar/Polar.js`
# 7. `AnirudhRamanan06/Project41/sketch.js`
# 8. `SNGmagician/CC191-Work/InClassWork/04-1/02-Variables/sketch.js`
# 9. `foxa706/p5_ta_wkshp/00_shapes/sketch.js`
# 10. `HanochShetty/BULLETS-AND-WALLS/sketch.js`
# 11. `msyem2014/website/more/archive/p5js/1.4-color/P5/sketch.js`
# 12. `patrickdolloso/CM1005/W10 For loops and arrays cont/GP_parts_1_to_3/GP_parts_1_to_3/2b/sketch.js`
# 13. `computacao-grafica-2019-1/boneco-de-olinda-kennedy-lucas-anselmo/sketch.js`
# 14. `reynolj2/JohnnyKewel/sketch.js`
# 15. `MrVapeur/p5js-experiment-server/sketch.js`
# 16. `hcGamechamp/hcGamechamp.github.io/Chess Board/sketch.js`
# 17. `olganedelcu/Projectuc3m_Arte_Tecnologia/sketch.js`
# 18. `readyletsgo/PGDV_5200_MS1_SP18/00_p5Template/sketch.js`
# 19. `chaturawhitehat20/class20/sketch.js`
# 20. `patrickdolloso/CM1005/W6 Variables, objects, interation cont/3.5/gp2b/2b/sketch.js`
# 21. `Priyadarshni3004/project-c20/sketch.js`
# 22. `Ansh657/my-game/sketch.js`
# 23. `jacobrivkin/flynnforester.github.io/projects/p5jsdemo/assets/sketch03/sketch.js`
# 24. `Saanvi4115/CLASS-20/sketch.js`
# 25. `JeReyes04/JeReyes04.github.io/js/p5/p5-zip/empty-example/sketch.js`
# 26. `SNGmagician/CC191-Work/InClassWork/03-2/03-Translate/sketch.js`
# 27. `Hritwik29/bullets-and-walls/sketch.js`
# 28. `readyletsgo/PGDV_5200_MS1_SP18/00-Coding-intro/02-Variables/sketch.js`
# 29. `divyavala/sample/sketch.js`
# 30. `rockriderST100/C11/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `hacklabes/HackNights_Intro_2016_January/04-functions-transform-explained/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('hacklabes/HackNights_Intro_2016_January/04-functions-transform-explained/sketch.js')
# Out:
# ```javascript
# //This is an empty template
#
# function setup() {
# 	var myCanvas = createCanvas(500, 500);
# 	myCanvas.parent('myCanvas');
# 	frameRate(24);
#
# }
#
# function draw() {
# 	//backgroud(RED,GREEN,BLUE)
#   	background(255,255,255); //background color WHITE
# 	drawGrid(0,0,0,1,255);
# 	drawGrid(100,100,35, 0.5,255);
#
# }
#
#
# function drawGrid(posX, posY, angle, vScale, color){
# 	var size = 10; //grid size
# 	var stepX = width/size; //step for X
# 	var stepY = height/size;  //step for Y
#
#
#
#
# 	push(); //push save the syles and the coordinates state
# 		translate(posX,posY);
# 		rotate(radians(angle));
# 		scale(vScale);
# 		fill(255-color);
# 	rect(0, 0,55,145);
# 	fill(color);
# 	ellipse(0, 0, 100,50 );
# 		var x = 0;
# 		strokeWeight(2);
# 		while(x <= width){
# 			line(x,0,x, height);
# 			x = x + stepX;
# 		}
# 		var y = 0;
# 		while(y <= height){
# 			line(0,y, width, y);
# 			y = y + stepY;
# 		}
# 	pop(); // brings back the syle and the coodinates state
# ...

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `tirzatirza14/Programming-Design-Systems/W1 Ice Cream Icons/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tirzatirza14/Programming-Design-Systems/W1 Ice Cream Icons/sketch.js')
# Out:
# ```javascript
# // Ice Cream Icons
# // Make icons for ice cream with just ellipses, triangles, and rectagles
#
# function setup() {
#   createCanvas(500, 300);
#   background(255);
# }
#
# function draw() {
#   iceCreamOne();
#   iceCreamTwo();
#   iceCreamThree();
# }
#
# function iceCreamOne() {
#   //the background circle
#   push();
#   fill(0);
#   ellipse(80, 135, 150, 150);
#   pop();
#
#   //one big scoop of ice cream
#   push();
#   fill(255);
#   noStroke();
#   ellipse(80, 100, 50, 50);
#   pop();
#
#   //smaller ice cream scoops on the sides
#   for (var i = 80; i <= 80; i++) {
#     smallCircles(i, 102);
#   }
#
#   //the cone
#   push();
#   noStroke();
#   fill(255);
#   triangle(55, 100, 105, 100, 80, 200);
#   pop();
#
#   //white border between the ice cream and the cone
#   push();
#   noStroke();
#   fill(0);
#   rect(40, 110, 80, 3);
#   pop();
# }
#
# function iceCreamTwo() {
#   //the background circle
#   push();
#   fill(0);
#   ellipse(240, 138, 150, 150);
# ...

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `SNGmagician/CC191-Work/InClassWork/04-1/03-VariableScope/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SNGmagician/CC191-Work/InClassWork/04-1/03-VariableScope/sketch.js')
# Out:
# ```javascript
# // to create variable --> "var"
#
# var globalVar;
#
# // Global Vars go outside Fuctions
#
#
#
# function setup() {
#   createCanvas(800, 400);
#
# // Local Vars go INSIDE fuctions and cannot me used in other fuctions outside the defined fuction
#
#
# }
#
#
# function draw() {
#   var myFirstVar;
#
#   background(200);
#
#   noFill();
#
#   myFirstVar = 70;
#   translate(400,200);
#   ellipse(0, 0, myFirstVar, myFirstVar);
#
#   mySecondVar = myFirstVar + 60;
#   ellipse(0, 0, mySecondVar, mySecondVar);
#
# }
#
# ```

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `PRANAYGOUR/sv-pwegnaehg/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('PRANAYGOUR/sv-pwegnaehg/sketch.js')
# Out:
# ```javascript
# var oxygenMuhs1 , oxygenMuhs1Img;
# var oxygenMuhs2 , oxygenMuhs2Img;
# var oxygenMuhs3 , oxygenMuhs3Img;
#
# function preload(){
#   //loading images for oxygen
#
#   oxygenMuhs1Img = loadImage("oxygenMuhs1.png");
#   oxygenMuhs2Img = loadImage("oxygenMuhs2.png");
#   oxygenMuhs3Img = loadImage("oxygenMuhs3.png");
#
# }
# function setup(){
# createCanvas(3000,3000)
#   // creating sprite image for oxygen available in chennai hospital no.1
# oxygenMuhs1 = createSprite(600, 400,150,150);
# oxygenMuhs1.addImage(oxygenMuhs1Img);
#
# // creating sprite image for oxygen available in chennai hospital no.2
# oxygenMuhs2 = createSprite(600, 1100,150,150);
# oxygenMuhs2.addImage(oxygenMuhs2Img);
#
#
# // creating sprite image for oxygen available in chennai hospital no.3
# oxygenMuhs3 = createSprite(600, 1800,150,150);
# oxygenMuhs3.addImage(oxygenMuhs3Img);
#
# }
#
# function draw(){
#   background("purple")
#   drawSprites();
# }
# ```

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `FukBrachetti/dsii-2017-archive/davideonestini/making-visible/coding/earthquake-01/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('FukBrachetti/dsii-2017-archive/davideonestini/making-visible/coding/earthquake-01/sketch.js')
# Out:
# ```javascript
# var mapimg;
#
# var clat = 0;
# var clon = 0;
#
# // Shanghai 31.2304° N, 121.4737° E
# // San Marino 44.6166° N, 11.4166° E
# var lat = 44.6166;
# var lon = 11.4166;
#
# var zoom = 1;
# var earthquakes;
#
# function preload() {
#   mapimg = loadImage('https://api.mapbox.com/styles/v1/mapbox/light-v9/static/0,0,1,0,0/1024x1024?access_token=pk.eyJ1IjoiZGF2aWRlb25lc3RpbmkiLCJhIjoiY2oyODNoYXl2MDA0ZDJxc2FuazgxYWIxNSJ9.7loO4alT4U_2wniZ-xflNA');
#   earthquakes = loadStrings('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv');
# }
#
# function mercX(lon) {
#   lon = radians(lon);
#   var a = (256 / PI) * pow(2, zoom);
#   var b = lon + PI;
#   return a * b;
# }
#
# function mercY(lat) {
#   lat = radians(lat);
#   var a = (256 / PI) * pow(2, zoom);
#   var b = tan(PI / 4 + lat / 2);
#   var c = PI - log(b);
#   return a * c ;
# }
#
# function setup() {
#   createCanvas(1024, 1024);
#   translate(width/2,height/2);
#   imageMode(CENTER);
# ...

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `gapgag55/BrowserGames/Polar/Polar.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('gapgag55/BrowserGames/Polar/Polar.js')
# Out:
# ```javascript
#
# function setup(){
#
#   createCanvas(400, 400);
#   background(51);
#
# }
# function draw(){
#
#   let n = 5;
#   let d = 7;
#   let k = n/d;
#
#   translate(width/2, height/2);
#   stroke(255);
#   strokeWeight(1);
#
#   beginShape();
#   noFill();
#
#   for(let i = 0; i <= TWO_PI * d; i += 0.01){
#     let  r = 100 * cos(k * i);
#     let x = r * cos(i);
#     let y = r * sin(i);
#
#     vertex(x, y);
#   }
#
#   endShape(CLOSE);
#
#
# }
#
# ```

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `AnirudhRamanan06/Project41/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('AnirudhRamanan06/Project41/sketch.js')
# Out:
# ```javascript
# const Engine = Matter.Engine;
# const World= Matter.World;
# const Bodies = Matter.Bodies;
# const Constraint = Matter.Constraint;
#
# var engine, world;
# var umbrella,drop;
# var thunderboltGroup;
# var thunderboltImage;
# var walkingManImage;
# var thunderbolt1Image,thunderbolt2Image,thunderbolt3Image,thunderbolt4Image;
# var walkingImage1,walkingImage2,walkingImage3,walkingImage4,walkingImage5,walkingImage6,walkingImage7,walkingImage8;
#
# function preload(){
#    // thunderBoltImages
#     thunderbolt1Image=loadImage("images/thunderbolt/thunderbolt1.png");
#     thunderbolt2Image=loadImage("images/thunderbolt/thunderbolt2.png");
#     thunderbolt3Image=loadImage("images/thunderbolt/thunderbolt3.png");
#     thunderbolt4Image=loadImage("images/thunderbolt/thunderbolt4.png");
#     //Walking with umbrella images
#     walkingImage1=loadImage("images/Walking Frame/walking_1.png");
#     walkingImage2=loadImage("images/Walking Frame/walking_2.png");
# ...

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `SNGmagician/CC191-Work/InClassWork/04-1/02-Variables/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SNGmagician/CC191-Work/InClassWork/04-1/02-Variables/sketch.js')
# Out:
# ```javascript
# // to create variable --> "var"
#
# var myFirstVar;
#
#
# function setup() {
# createCanvas(800, 400);
# background(200);
#
# noFill();
#
# myFirstVar = 70;
# translate(400,200);
# ellipse(0, 0, myFirstVar, myFirstVar);
#
# mySecondVar = myFirstVar - 60;
# ellipse(0, 0, mySecondVar, mySecondVar);
#
#
# }
#
#
#
# function draw() {
#
# }
#
# ```

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `foxa706/p5_ta_wkshp/00_shapes/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('foxa706/p5_ta_wkshp/00_shapes/sketch.js')
# Out:
# ```javascript
# function setup() {
#   createCanvas(300, 700);
#
# }
#
# function draw() {
#
#   arc(width/2, height/2, width/4, height/4, PI, PI/2)
#   ellipse(50, 50, 50, 50);
#   line(0,0,300, 700);
#   ellipse(150, 150, 100, 100);
#   point(width/2, height/2);
#   quad(150, 100, 200, 150, 100, 400, 150, 400);
#   rect(200, 200, 50, 100);
#   rect(210, 210, 50, 100);
#   triangle(50, 500, 100, 250, 150, 500);
#
# }
#
# ```

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `HanochShetty/BULLETS-AND-WALLS/sketch.js`
#
# **Label combination:**
#
# `randomness + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `randomness + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('HanochShetty/BULLETS-AND-WALLS/sketch.js')
# Out:
# ```javascript
#
# var wall, thickness;
# var bullet,speed, weight;
#
# function setup() {
#   createCanvas(1600, 400);
#
#   speed=random(223,321)
#   weight=random(30,52)
#
#
#   thickness=random(22,83)
#
#
#
#
#
#     bullet=createSprite(50, 200, 50,5);
#     bullet.velocityX = speed;
#     bullet.shapeColor=color(255);
#
#
#
#
#     wall=createSprite(1200, 200, thickness, height/2);
#
#     wall.shapeColor=color(230,230,230);
#   //wall.shapeColor=color(80,80,80)
# }
#
#
# function draw() {
#   background(0);
#   //bullet.sprite.collide(wall.sprite,calculateDeformation)
#   if(hasCollided(bullet, wall))
#   {
#   	bullet.velocityX=0;
#   	var damage=0.5 * weight * speed* speed/(thickness *thickness *thickness);
#
#
# 	if(damage>10)
# 	{
# 		wall.shapeColor=color(255,0,0);
#
# 	}
#
#
#
# 	if(damage<10)
# 	{
# 		wall.shapeColor=color(0,255,0);
# 	}
#
#   }
#
#
#   drawSprites();
#
# }
#
#
# function hasCollided(lbullet, lwall)
# {
# 	bulletRightEdge=lbullet.x +lbullet.width;
# ...

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `msyem2014/website/more/archive/p5js/1.4-color/P5/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('msyem2014/website/more/archive/p5js/1.4-color/P5/sketch.js')
# Out:
# ```javascript
# /*
# code from video: https://youtu.be/9mucjcrhFcM?list=PLRqwX-V7Uu6Zy51Q-x9tMWIv9cueOFTFA
# code can be seen from 9:47 second onward
# */
#
# function setup() {
#   createCanvas(600, 400);
# }
#
# function draw() {
#   //background(255);
#   background(150, 150, 200);
#   ellipseMode(CENTER);
#   rectMode(CENTER);
#
#   // Body
#   fill(255, 0, 0);
#   rect(240, 145, 20, 100);
#
#   // Head
#   fill(0, 0, 255);
#   ellipse(240, 115, 60, 60);
#
#   // Eyes
#   fill(0, 255, 0);
#   ellipse(221, 115, 16, 32);
#   ellipse(259, 115, 16, 32);
#
#   // Legs
#   line(230, 195, 220, 205);
#   line(250, 195, 260, 205);
# }
#
# ```

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `patrickdolloso/CM1005/W10 For loops and arrays cont/GP_parts_1_to_3/GP_parts_1_to_3/2b/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/W10 For loops and arrays cont/GP_parts_1_to_3/GP_parts_1_to_3/2b/sketch.js')
# Out:
# ```javascript
# /*
#
# The Game Project
#
# 2b - using variables
#
# */
#
# var floorPos_y;
#
# var gameChar_x;
# var gameChar_y;
#
# var treePos_x;
# var treePos_y;
#
# var canyon;
# var collectable;
#
# var mountain;
# var cloud;
#
#
# function setup()
# {
# 	createCanvas(1024, 576);
# 	floorPos_y = 432; //NB. we are now using a variable for the floor position
#
# 	//NB. We are now using the built in variables height and width
# 	gameChar_x = width/2;
# 	gameChar_y = floorPos_y;
#
# 	treePos_x = width/2;
# 	treePos_y = height/2;
# }
#
# function draw()
# {
# 	background(100, 155, 255); //fill the sky blue
#
# 	noStroke();
# 	fill(0, 155, 0);
# 	rect(0, floorPos_y, height, width - floorPos_y); //draw some green ground
#
# }
#
# function mousePressed()
# {
#
#
# }
#
# ```

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `computacao-grafica-2019-1/boneco-de-olinda-kennedy-lucas-anselmo/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('computacao-grafica-2019-1/boneco-de-olinda-kennedy-lucas-anselmo/sketch.js')
# Out:
# ```javascript
# function setup() {
# 	createCanvas(400, 270);
# 	background(255);
#
# 	//Desenha Cabeça!
# 	push();
# 	translate(195, 60);
# 	rect(-25, -50, 50, 50);
# 	fill(0);
# 	circle(0,0,4);
# 	pop();
#
# 	//Desenha Tronco!
# 	push();
# 	translate(195, 10);
# 	rect(-40, 60, 80, 100);
# 	fill(0);
# 	circle(0,0,4);
# 	pop();
#
# 	//Desenha Braço D!
# 	push();
# 	translate(145, 87);
# 	rect(-80, -17, 80, 35);
# 	fill(0);
# 	circle(0,0,4);
# 	pop();
#
# 	//Desenha Braço E!
# 	push();
# 	translate(245, 87);
# 	rect(0, -17, 80, 35);
# 	fill(0);
# 	circle(0,0,4);
# 	pop();
#
# 	//Desenha Perna D!
# 	push();
# 	translate(172, 180);
# 	rect(-17, 0, 35, 80);
# 	fill(0);
# 	circle(0,0,4);
# 	pop();
#
# 	//Desenha Perna E!
# 	push();
# 	translate(217, 180);
# 	rect(-17, 0, 35, 80);
# 	fill(0);
# 	circle(0,0,4);
# 	pop();
# }
#
# function draw() {
#
# }
# ```

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `reynolj2/JohnnyKewel/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('reynolj2/JohnnyKewel/sketch.js')
# Out:
# ```javascript
# function setup() {
#   createCanvas(800,800);
#   background(200);
# }
#
# function draw() {
#
#   //shirt
#   fill(235,0,25);
#   strokeJoin(ROUND);
#   strokeWeight(2);
#   beginShape();
#   vertex(358,225); //top left
#   vertex(345,400); //bottom left
#   vertex(455,400); //bottom right
#   vertex(442,225); //top right
#   endShape();
#
#   //body underneath shirt
#   fill(255,205,148);
#   beginShape();
#   vertex(373,230);
#   quadraticVertex(370,260,400,260);
#   vertex(400,260);
#   quadraticVertex(430,260,427,230);
#   endShape();
#
#   //head
#   ellipseMode(CENTER);
#   fill(150,20,90);
#   arc(455,90,80,50,PI+QUARTER_PI,QUARTER_PI); //hat
#   fill(255,205,148);
#   ellipse(400,150,150,180); //whole head
#
#   //hat
#   fill(150,20,90);
#   arc(400,120,140,120,179,360); // upper hat
#   angleMode(DEGREES);
#   fill(255,205,148);
#   arc(400,112,48,50,179,360); //hole in hat
#   fill(150,20,90);
#   ellipse(428,116,10,8);
#   noStroke();
# ...

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `MrVapeur/p5js-experiment-server/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('MrVapeur/p5js-experiment-server/sketch.js')
# Out:
# ```javascript
# var h = window.innerHeight;
# var w = window.innerWidth;
# var border = 100;
#
# function setup() {
#     canvas=createCanvas(windowWidth, windowHeight);
# }
#
# function draw() {
#     background(255,128,128);
#     // A rectangle
#     fill(200, 200, 200);
#     noStroke();
#     rect(border, border, w-(2*border), h-(2*border));
#     // uses global variables for width and height
# }
#
# ```

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `hcGamechamp/hcGamechamp.github.io/Chess Board/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('hcGamechamp/hcGamechamp.github.io/Chess Board/sketch.js')
# Out:
# ```javascript
# // Chess Board
# // Josh
# // Sept 19, 2022
# //
# // Extra for Experts:
# // - describe what you did to take this project "above and beyond"
#
#
# function setup() {
#   createCanvas(windowWidth, windowHeight);
# }
#
# function draw() {
#   background(220);
#   drawchessboard();
# }
# function drawchessboard() {
#   let cellWidth = width/8;
#   let cellHeight = height/8;
#   if (cellWidth > cellHeight) {
#     cellWidth = cellHeight;
#   }
#   else {
#     cellHeight = cellWidth;
#   }
#
#   let iswhite = true;
#   for (let y = 0; y < 8; y++) {
#     for (let x = 0; x < 8; x++) {
#       if (iswhite) {
#         fill("white");
#       }
#       else {
#         fill("black");
#       }
#       rect(x*cellWidth, y*cellHeight, cellWidth, cellHeight);
#       iswhite = !iswhite;
#     }
#     iswhite = !iswhite;
#   }
# }
#
# ```

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `olganedelcu/Projectuc3m_Arte_Tecnologia/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('olganedelcu/Projectuc3m_Arte_Tecnologia/sketch.js')
# Out:
# ```javascript
# /**
# * Olguta Constantina Nedelcu
# * Arte y Tec: Projecto final, 01/01/21
# * Consiste en una imagen que pretende representar un poema flart
# */
#
# let img;
# function setup() {
#   createCanvas(400, 400);
#   strokeWeight(5);
#   background(100);
#
# }
#
#
# function draw() {
#   background(255);
#   //Outside Frame
#   rect(-1, -1, 400, 400);
#   img = loadImage('/ornitorrinco 1.jpg');
#   image(img,10,10,50,50);
#
#   //Fill in the blue
#   fill(106,55,255);
#   rect(0,280,80,400);
#   noFill();
#
#   //Fill in the red
#   fill(255,53,34);
#   rect(50,0,400,280);
#   noFill();
#
#     //Fill in the yellow
#   fill(255,250,34);
#   rect(1,0,80,100);
#   rect(280,280,280,400);
#   noFill();
#
#   line(90,0,80,400);
#   line(0,280,400,280);
#
#   //Heavy stroke
#   strokeWeight(8);
#   line(0,150,80,150);
#   line(20,120,80,150);
#   line(340,280,340,400);
#   strokeWeight(3);
#
#   //group of line
#   line(340,950,400,350);
#   line(340,360,400,360);
# ...

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `readyletsgo/PGDV_5200_MS1_SP18/00_p5Template/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('readyletsgo/PGDV_5200_MS1_SP18/00_p5Template/sketch.js')
# Out:
# ```javascript
#
#
#
# function setup() {
#  	createCanvas(800,600);
#
#  	background(200);
#   	fill(255,45,241);
#   	strokeWeight(10);
#
#
# 	var yPos = 50;
# 	var yDistance = 120;
#
# 	// yPos is 50
#   	rect(100,yPos, 200,100);
#   	yPos = yPos + yDistance;
#   	// now, yPos is 200
#
#   	rect(100,yPos, 200,100);
#
#   	yPos = yPos + yDistance;
#   	// now, yPos is 350
#   	rect(100,yPos, 200,100);
#
# }
#
# function draw() {
#
#
# }
# ```

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `chaturawhitehat20/class20/sketch.js`
#
# **Label combination:**
#
# `randomness + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `randomness + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('chaturawhitehat20/class20/sketch.js')
# Out:
# ```javascript
#
#
# var car,wall;
#
#
# var speed, weight;
#
#
# function setup() {
#   createCanvas(1600, 400);
#
#
# 	speed=random(55,90)
# 	weight=random(400,1500)
#
#
# 	car=createSprite(50, 200, 50,50);
#
# 	car.velocityX = speed;
#
# 	car.shapeColor=color(255);
#
#
#
#   	wall=createSprite(1500,200, 60, height/2)
#   	wall.shapeColor=color(80,80,80)
# }
#
#
# function draw() {
#   background(0);
#
#   if(wall.x-car.x < (car.width+wall.width)/2)
#   {
#   	car.velocityX=0;
#   	var deformation=0.5 * weight * speed* speed/22500;
# 	if(deformation>180)
# 	{
# 		car.shapeColor=color(255,0,0);
# 	}
#
# 	if(deformation<180 && deformation>100)
# 	{
# 		car.shapeColor=color(230,230,0);
# 	}
#
# 	if(deformation<100)
# 	{
# 		car.shapeColor=color(0,255,0);
# 	}
#   }
#
#   drawSprites();
#
# }
#
#
#
# ```

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `patrickdolloso/CM1005/W6 Variables, objects, interation cont/3.5/gp2b/2b/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/W6 Variables, objects, interation cont/3.5/gp2b/2b/sketch.js')
# Out:
# ```javascript
# /*
#
# The Game Project
#
# 2b - using variables
#
# */
#
# var floorPos_y;
#
# var gameChar_x;
# var gameChar_y;
#
# var treePos_x;
# var treePos_y;
#
# var canyon;
# var collectable;
#
# var mountain;
# var cloud;
#
#
# function setup()
# {
# 	createCanvas(1024, 576);
# 	floorPos_y = 432; //NB. we are now using a variable for the floor position
#
# 	//NB. We are now using the built in variables height and width
# 	gameChar_x = width/2;
# 	gameChar_y = floorPos_y;
#
# 	treePos_x = width/2;
# 	treePos_y = height/2;
# }
#
# function draw()
# {
# 	background(100, 155, 255); //fill the sky blue
#
# 	noStroke();
# 	fill(0, 155, 0);
# 	rect(0, floorPos_y, height, width - floorPos_y); //draw some green ground
#
# }
#
# function mousePressed()
# {
#
#
# }
#
# ```

# %% [markdown]
# ## Sample 21
#
# **File path:**
#
# `Priyadarshni3004/project-c20/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Priyadarshni3004/project-c20/sketch.js')
# Out:
# ```javascript
# var tom,bgImage
# var tomImg1,tomImg2,tomImg3;
# var mouse,mouseImg1,mouseImg2,mouseImg3;
#
# function preload() {
#     //load the images here
#         bgImage= loadImage("Images/garden.png");
#     tomImg1= loadAnimation("images/cat1.png");
#      tomImg2=loadAnimation("images/cat2.png","images/cat3.png");
#      tomImg3= loadAnimation("images/cat4.png");
#
#      mouseImg1= loadImage("Images/mouse1.png");
#      mouseImg2=loadImage("Images/mouse2.png,Images/ouse3.png");
#      mouseImg3=loadImage("Images/mouse4.png");
# }
#
# function setup(){
#     createCanvas(1000,800);
#     //create tom and jerry sprites her
#     tom=createSprite(400, 200, 50,50);
# 	tom.addImage(cat1.png)
# 	tom.scale=0.2
#
#     mouse=createSprite(500,100,50,50);
#     mouse.addImage(mouse1.png)
#     mouse.scale=0.2
#
# }
#
# function draw() {
#
#     background(bgImage);
#     //Write condition here to evalute if tom and jerry collide
#
#     if(cat.x-mouse.x<(cat.width-mouse.width)/2){
# ...

# %% [markdown]
# ## Sample 22
#
# **File path:**
#
# `Ansh657/my-game/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Ansh657/my-game/sketch.js')
# Out:
# ```javascript
# var backImage,backgr;
# var player, player_running;
# var ground,ground_img,bulletimg;
#
# var FoodGroup, bananaImage,invisibleground;
# var obstaclesGroup, obstacle_img,enemyGroup;
#
# var END =0;
# var PLAY =1;
# var gameState = PLAY;
#
# var gameOver;
# var score=0;
# var attempts=3;
#
# function preload(){
# bulletimg=loadAnimation("b1.png","b2.png","b3.png","b4.png","b5.png","b6.png","b7.jpeg","b8.png","b9.png")
#   mario_running = loadAnimation("m1.png","m2.png","m3.png","m4.png","m5.png","m6.png");
# mario_die=loadAnimation("die.png","die.png");
# bgimage=loadImage("bg1.jpeg")
# enemyimg = loadAnimation("e1.png","e1.png","e2.png","e2.png","e3.png","e3.png","e4.png","e4.png","e5.png","e5.png")
# lifeimg=loadImage("life.png ")
# blackheartimg=loadImage("blackheart.png ")
# star1img=loadImage("star1.png")
# star2img=loadImage("star2.png")
#
# }
#
# function setup() {
#   createCanvas(800,400);
#      enemyGroup= new Group()
#
#
#
# ...

# %% [markdown]
# ## Sample 23
#
# **File path:**
#
# `jacobrivkin/flynnforester.github.io/projects/p5jsdemo/assets/sketch03/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('jacobrivkin/flynnforester.github.io/projects/p5jsdemo/assets/sketch03/sketch.js')
# Out:
# ```javascript
# let ypos = 10;
# let ystep = 100;
# let xpos = 30;
# let xstep = 100;
#
#
# function setup() {
#   createCanvas(windowWidth, windowHeight);
# }
#
# function draw() {
#   background("lightgrey");
#
#   for (let j = 0; j < 25; j++) {
#     for (let i = 0; i < 12; i++) {
#       noStroke();
#       rotate(45);
#       fill("grey");
#         rect(xpos+20+(xstep*i), ypos+(ystep*j), 40, 60, 20);
#       fill("darkgreen");
#         rect(xpos+5+(xstep*i), ypos+(ystep*j), 40, 60, 20);
#       fill("green");
#         rect(xpos+(xstep*i), ypos+(ystep*j), 40, 60, 20);
#     }
#   }
# }
# ```

# %% [markdown]
# ## Sample 24
#
# **File path:**
#
# `Saanvi4115/CLASS-20/sketch.js`
#
# **Label combination:**
#
# `randomness + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `randomness + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Saanvi4115/CLASS-20/sketch.js')
# Out:
# ```javascript
#
#
# var car,wall;
# var speed, weight;
#
#
# function setup() {
#   createCanvas(1600, 400);
#
# 	speed=random(55,90)
# 	weight=random(400,1500)
#
# 	car=createSprite(50, 200, 50,50);
# 	car.velocityX = speed;
# 	car.shapeColor=color(255);
#
#   	wall=createSprite(1500,200, 60, height/2)
#   	wall.shapeColor=color(80,80,80)
# }
#
#
# function draw() {
#   background(0);
#
#   if(wall.x-car.x < (car.width+wall.width)/2)
#   {
#   	car.velocityX=0;
#   	var deformation=0.5 * weight * speed* speed/22500;
# 	if(deformation>180)
# 	{
# 		car.shapeColor=color(255,0,0);
# 	}
#
# 	if(deformation<180 && deformation>100)
# 	{
# 		car.shapeColor=color(230,230,0);
# 	}
#
# 	if(deformation<100)
# 	{
# 		car.shapeColor=color(0,255,0);
# 	}
#   }
#
#   drawSprites();
#
# }
#
#
#
# ```

# %% [markdown]
# ## Sample 25
#
# **File path:**
#
# `JeReyes04/JeReyes04.github.io/js/p5/p5-zip/empty-example/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('JeReyes04/JeReyes04.github.io/js/p5/p5-zip/empty-example/sketch.js')
# Out:
# ```javascript
# var img;
# function preload() {
#   img = loadImage("./albumcoverpng");
# }
# function setup() {
#     createCanvas(400,400);
#     image(img, 0, 0);
# }
# function setup() {
#
# }
#
# function draw() {
#     rect(100, 100, 100, 100);
#     rect(150, 150, 100, 100);
#     line(200,100,250,150);
#     line(100,200,150,250);
#     line(100,100,150,100)
# }
# ```

# %% [markdown]
# ## Sample 26
#
# **File path:**
#
# `SNGmagician/CC191-Work/InClassWork/03-2/03-Translate/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SNGmagician/CC191-Work/InClassWork/03-2/03-Translate/sketch.js')
# Out:
# ```javascript
# function setup() {
#   createCanvas(500, 500);
#   background(50, 100, 255);
#
# }
#
# function draw() {
#
# //Ellipse 1 Yellow w/ red fill  Upper-left
#
#   fill(255, 255, 0);
#   stroke(255, 50, 10);
#   strokeWeight(8);
#
#   ellipse(0, 0, 140, 200);
#
#
#   translate(250,250);
#   fill(255, 50, 10);//Ellipse 2 Red, w/ yellow fill. Mid-screen
#   stroke(255, 255, 0);
#   strokeWeight(8);
#
#   ellipse(0, 0, 140, 200);
#
# /*  (Block-Comment)
#  Ellipse 3 Yellow w/ Blue fill  Lower-Right
# */
#   translate(50,50);
#   fill(50, 100, 255);
#   stroke(255, 50, 10);
#   strokeWeight(8);
#   ellipse(0, 0, 140, 200);
# }
#
# ```

# %% [markdown]
# ## Sample 27
#
# **File path:**
#
# `Hritwik29/bullets-and-walls/sketch.js`
#
# **Label combination:**
#
# `randomness + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `randomness + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Hritwik29/bullets-and-walls/sketch.js')
# Out:
# ```javascript
#
# var wall, thickness;
# var bullet,speed, weight;
#
# function setup() {
#   createCanvas(1600, 400);
#
#   speed=random(223,321)
#   weight=random(30,52)
#
#
#   thickness=random(22,83)
#
#
#
#
#
#     bullet=createSprite(50, 200, 50,5);
#     bullet.velocityX = speed;
#     bullet.shapeColor=color(255);
#
#
#
#
#     wall=createSprite(1200, 200, thickness, height/2);
#
#     wall.shapeColor=color(230,230,230);
#   //wall.shapeColor=color(80,80,80)
# }
#
#
# function draw() {
#   background(0);
#   //bullet.sprite.collide(wall.sprite,calculateDeformation)
#   if(hasCollided(bullet, wall))
#   {
#   	bullet.velocityX=0;
#   	var damage=0.5 * weight * speed* speed/(thickness *thickness *thickness);
#
#
# 	if(damage>10)
# 	{
# 		wall.shapeColor=color(255,0,0);
#
# 	}
#
#
#
# 	if(damage<10)
# 	{
# 		wall.shapeColor=color(0,255,0);
# 	}
#
#   }
#
#
#   drawSprites();
#
# }
#
#
# function hasCollided(lbullet, lwall)
# {
# 	bulletRightEdge=lbullet.x +lbullet.width;
# ...

# %% [markdown]
# ## Sample 28
#
# **File path:**
#
# `readyletsgo/PGDV_5200_MS1_SP18/00-Coding-intro/02-Variables/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('readyletsgo/PGDV_5200_MS1_SP18/00-Coding-intro/02-Variables/sketch.js')
# Out:
# ```javascript
# // Variables are used for storing values.
# //In this example, change the values of variables to affect the composition.
# // in this example all drawing happens only in setup(), so it is only drawn once.
# function setup() {
#
#   createCanvas(720, 400);
#   background(0);
#   stroke(153);
#   strokeWeight(4);
#
#   // change these variables to see how the composition is affected
#   var a = 120;
#   var b = 120;
#   var c = 130;
#
#   // line works like this:
#   // line(x1, y1, x2, y2);
#   line(a, b, a+c, b);
#   line(a, b+10, a+c, b+10);
#   line(a, b+20, a+c, b+20);
#   line(a, b+30, a+c, b+30);
#
# }
# ```

# %% [markdown]
# ## Sample 29
#
# **File path:**
#
# `divyavala/sample/sketch.js`
#
# **Label combination:**
#
# `synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('divyavala/sample/sketch.js')
# Out:
# ```javascript
# function setup() {
#   createCanvas(400, 400);
#
#
# }
#
# function draw() {
#   background(220);
# fill("lightblue")
#   rect(200,200,100,100)
# }
# ```

# %% [markdown]
# ## Sample 30
#
# **File path:**
#
# `rockriderST100/C11/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('rockriderST100/C11/sketch.js')
# Out:
# ```javascript
# var seaImage
# var sea
# var ship_image,ship
#
# function preload(){
# seaImage=loadImage("sea.png")
# ship_Image=loadAnimation("ship-1.png","ship-2.png")
# }
#
# function setup(){
#   createCanvas(400,400);
#   sea=createSprite(400,200)
#   sea.addImage(seaImage)
#   sea.velocityX=-3
#   ship=createSprite(200,300)
#   ship.addAnimation("moving",ship_Image)
# }
#
# function draw() {
#   background("blue");
#
#
#   if(sea.x<0){
#     sea.x=400
#   }
#   sea.scale=0.3
#   ship.scale=0.2
#  drawSprites()
# }
# ```
