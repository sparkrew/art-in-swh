# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Entities = processed_image + synthesized_image, any interaction, any outcome
#
# Entities must be exactly [processed_image, synthesized_image]. Interaction and outcome can be anything.
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Matching files after filtering: `669`
#
# Samples in this notebook: `30`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`
#
# Excluded path terms: `Tutorials, Coursera, CodingChallenges, Rainbow-Code, Courses, p5.js, week`

# %% [markdown]
# ## Sample paths
#
# 1. `sohanbhat23/run-project/run project/sketch.js`
# 2. `SeanRakowski1/Class43_v2/sketch.js`
# 3. `Iguana08/Project11/sketch.js`
# 4. `AKistheLionistheking/C16hw/sketch.js`
# 5. `shouryasingh2007/tom-/sketch.js`
# 6. `BlazeRogers888/the-travelling-ship-retry-/sketch.js`
# 7. `PSLSindhuri/MonkeyGame/sketch.js`
# 8. `harshvardhany87/Monkey-Go-Happy--2/sketch.js`
# 9. `saurabhsindhu96/ml4a.github.io/examples/classification-simple/sketch.js`
# 10. `lemonnuggets/fourier-epicycles/getCoords-from-sketch/sketch.js`
# 11. `navneet-sawhney/TS1/sketch.js`
# 12. `vyankateshsmoti/CAT-enemys-Mouse/sketch.js`
# 13. `Niranjant123/C-16PROJECT/sketch.js`
# 14. `Aks1097/ElephantGame-1/sketch.js`
# 15. `rockriderST100/C11/sketch.js`
# 16. `David-droid-bot/Project-38/sketch.js`
# 17. `pedroaugustovieira/projeto-10/Projeto-10-Viajando-Num-Navio-main/sketch.js`
# 18. `jetaaaaaa/tower-seige-1/sketch.js`
# 19. `Lauraqf/C11-Proyecto-LLQF/sketch.js`
# 20. `DivyanshWHJ/C10-project/sketch.js`
# 21. `tabassum-a-hub/project-31/project-30/TS2-master/sketch.js`
# 22. `vishishta-b/tom-and-jerry-final/sketch.js`
# 23. `OhLouis/OhLouis.github.io/p5/meme/pepe.js`
# 24. `Khiende-May-Parker/Project-19/sketch.js`
# 25. `mateotellez/Clase-20/TomyJerry-main/sketch.js`
# 26. `liiightt/Machine-Learning-Object-Detection/Machine Learning Object Detection with P5js Sketch/sketch.js`
# 27. `ApoorvSaksham/Project/sketch.js`
# 28. `SuddenFlame414/Project-40/sketch.js`
# 29. `iamghebs/teaching-dd17/static/websites/g04/0ecosystem/script.js`
# 30. `amonieb/project-48/SHOOTING-RANGE-II-template-main/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `sohanbhat23/run-project/run project/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('sohanbhat23/run-project/run project/sketch.js')
# Out:
# ```javascript
# var path,boy, leftBoundary,rightBoundary;
# var pathImg,boyImg;
# var i;
#
# function preload(){
#   pathImg = loadImage("path.png");
#   boyImg = loadAnimation("Runner-1.png","Runner-2.png");
# }
#
# function setup(){
#
#   createCanvas(400,400);
#
# // Moving background
# path=createSprite(200,200);
# path.addImage(pathImg);
# path.velocityY = 4;
# path.scale=1.2;
#
# //creating boy running
# boy = createSprite(180,340,30,30);
# boy.scale=0.08;
# boy.addAnimation("JakeRunning",boyImg);
#
#
# leftBoundary=createSprite(0,0,100,800);
#
# // leftBoundary.invisible = false;
# // leftBoundary.visible = true;
# // leftBoundary.invisible = true;
# leftBoundary.visible = false;
#
#
# rightBoundary=createSprite(410,0,100,800);
# rightBoundary.visible = false;
# }
#
# function draw() {
#   background(0);
#   path.velocityY = 4;
#
#   boy.x = World.mouseX;
#
#   edges= createEdgeSprites();
#   boy.collide(edges[3]);
#   boy.collide(leftBoundary);
# ...

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `SeanRakowski1/Class43_v2/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SeanRakowski1/Class43_v2/sketch.js')
# Out:
# ```javascript
# var player,playerWalking,playerAttack,playerIdle,badGuy,badGuyAttack;
# var bg,bgImage;
# var block,blockIMG;
# var gameState = "play";
#
# function preload(){
#   bgImage = loadImage("bg.jpg");
#   //playerWalking = loadAnimation("goodguywalk/goodguywalk1.jpg","goodguywalk/goodguywalk2.jpg","goodguywalk/goodguywalk3.jpg","goodguywalk/goodguywalk4.jpg"
#   //,"goodguywalk/goodguywalk5.jpg","goodguywalk/goodguywalk6.jpg","goodguywalk/goodguywalk7.jpg","goodguywalk/goodguywalk8.jpg","goodguywalk/goodguywalk9.jpg,goodguywalk10.jpg");
#   //playerWalking = loadAnimation("goodguywalk1.jpg","goodguywalk2.jpg");
# }
#
#
# function setup(){
#   createCanvas(displayWidth,displayHeight-111);
#   bg = createSprite(displayWidth/2,displayHeight/2,displayWidth,displayHeight);
#   bg.addImage(bgImage);
#   bg.scale = 5;
#
#   player = createSprite(200,200,20,20);
#   //player.addAnimation("Walking",playerWalking);
#   block = createSprite(200,250,50,50);
# }
#
#
#
# ...

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `Iguana08/Project11/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Iguana08/Project11/sketch.js')
# Out:
# ```javascript
# var path,boy, leftBoundary,rightBoundary;
# var pathImg,boyImg;
# var i;
#
# function preload(){
#   pathImg = loadImage("path.png");
#   boyImg = loadAnimation("Runner-1.png","Runner-2.png");
# }
#
# function setup(){
#
#   createCanvas(400,400);
#
# // Moving background
# path=createSprite(200,200);
# path.addImage(pathImg);
# path.velocityY = 4;
# path.scale=1.2;
#
# //creating boy running
# boy = createSprite(180,340,30,30);
# boy.scale=0.08;
# boy.addAnimation("JakeRunning",boyImg);
#
#
# leftBoundary=createSprite(0,0,100,800);
#
# // leftBoundary.invisible = false;
# // leftBoundary.visible = true;
# // leftBoundary.invisible = true;
#  leftBoundary.visible = false;
#
#
# rightBoundary=createSprite(410,0,100,800);
# rightBoundary.visible = false;
# }
#
# function draw() {
#   background(0);
#   path.velocityY = 4;
#
#   boy.x = World.mouseX;
#
#   edges= createEdgeSprites();
#   boy.collide(edges[3]);
#   boy.collide(leftBoundary);
# ...

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `AKistheLionistheking/C16hw/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('AKistheLionistheking/C16hw/sketch.js')
# Out:
# ```javascript
# var PLAY = 1;
# var END = 0;
# var gameState = PLAY;
# var bow , arrow,  background, redB, pinkB, greenB ,blueB ,arrowGroup;
# var bowImage, arrowImage, green_balloonImage, red_balloonImage, pink_balloonImage ,blue_balloonImage, backgroundImage;
#
# var score =0;
# function preload(){
#
#   backgroundImage = loadImage("background0.png");
#
#   arrowImage = loadImage("arrow0.png");
#   bowImage = loadImage("bow0.png");
#   red_balloonImage = loadImage("red_balloon0.png");
#   green_balloonImage = loadImage("green_balloon0.png");
#   pink_balloonImage = loadImage("pink_balloon0.png");
#   blue_balloonImage = loadImage("blue_balloon0.png");
#
# }
#
#
#
# function setup() {
#   createCanvas(400, 400);
#
#   //creating background
#   scene = createSprite(0,0,400,400);
#   scene.addImage(backgroundImage);
#   scene.scale = 2.5
#
#   // creating bow to shoot arrow
#   bow = createSprite(380,220,20,50);
#   bow.addImage(bowImage);
#   bow.scale = 1;
#
#    score = 0
# ...

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `shouryasingh2007/tom-/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('shouryasingh2007/tom-/sketch.js')
# Out:
# ```javascript
#
# function preload() {
#     //load the images here
#     tomimg1=loadImage(tomOne.png);
#     tomimg3=loadAnimation(tomThree.png);
#     tomimg2=loadImage(tomTwo.png);
#
#     jerryimg1=loadImage(jerryOne.png);
#     jerryimg3=loadAnimation(jerryThree.png);
#     jerryimg2=loadImage(jerryTwo.png);
# }
#
# function setup(){
#     createCanvas(1000,800);
#     //create tom and jerry sprites here
#      tom=createSprite(200,200,20,20);
#      tom.addImage(tomimg1);
#
#      jerry=createSprite(100,200,20,20);
#      jerry.addImage(jerryimg1);
#
#
# }
#
# function draw() {
#
#     background(255);
#     //Write condition here to evalute if tom and jerry collide
#     if(tom.x-jerry.x===jerry.width/2+tom.width/2){
#        jerry.addImage(jerryimg2);
#        tom.addImage(tomimg2);
#     }
#
#     drawSprites();
# }
#
#
# function keyPressed(){
#
#   //For moving and changing animation write code here
# if(keyCode===lEFT_ARROW){
#     tom.velocityX=-5;
# ...

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `BlazeRogers888/the-travelling-ship-retry-/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('BlazeRogers888/the-travelling-ship-retry-/sketch.js')
# Out:
# ```javascript
# var sea,ship;
# var seaImg,shipImg;
#
# function preload(){
#   seaImg = loadImage("sea.png");
#   shipImg1=loadAnimation("sea.png")
# //Choose the correct option by uncommenting the right line to load the animation for ship.
#   //shipImg1 = loadAnimation("ship-1.png","ship-1.png","ship-2.png","ship-1.png");
#   //shipImg1 = loadAnimation("ship-1","ship-1","ship-2","ship-1");
#   //shipImg1 = loadAnimation("1.png","2.png","3.png","4.png");
#
# }
#
# function setup(){
#   createCanvas(400,400);
#   background("blue");
#
#   // Moving background
#   sea=createSprite(400,200);
#   sea.addImage(seaImg);
#   sea.scale=0.3;
#
#
#   ship = createSprite(130,200,30,30);
#   ship.addAnimation("movingShip",shipImg1);
#   ship.scale =0.25;
#
# }
#
# function draw() {
#   background(0);
#
# //Uncomment the correct line to make the background move to create a forward moving effect for the boat.
#   //sea.velocityY = -3;
#   //sea.x = -3;
#   //sea.velocityX = -3;
# ...

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `PSLSindhuri/MonkeyGame/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('PSLSindhuri/MonkeyGame/sketch.js')
# Out:
# ```javascript
#
# var monkey , monkey_running
# var banana ,bananaImage, obstacle, obstacleImage
# var FoodGroup, obstacleGroup
# var score
#
# function preload(){
#
#
#   monkey_running =            loadAnimation("monkey_0.png","monkey_1.png","monkey_2.png","monkey_3.png","monkey_4.png","monkey_5.png","monkey_6.png","monkey_7.png","monkey_8.png")
#
#   bananaImage = loadImage("banana.png");
#   obstaceImage = loadImage("obstacle.png");
#
# }
#
#
#
# function setup() {
#   // createCanvas(600, 600);
#
#
#
#   var survivalTime=0;
#
#   //creating monkey
#    monkey=createSprite(80,315,20,20);
#    monkey.addAnimation("moving", monkey_running);
#   // monkey.addImage(bananaImage)
#    monkey.scale=0.1
#
#   ground = createSprite(400,350,900,10);
#   ground.velocityX=-4;
#   ground.x=ground.width/2;
#   console.log(ground.x)
#
#   FoodGroup = new Group();
#   obstaclesGroup = new Group();
#
#   score = 0;
#
#
# }
#
#
# function draw() {
#
#   background(255);
#
#
#   if(ground.x<0) {
# ...

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `harshvardhany87/Monkey-Go-Happy--2/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('harshvardhany87/Monkey-Go-Happy--2/sketch.js')
# Out:
# ```javascript
# var bananaimage,obstacleimage,backimage,score,obstaclegroup,bananagroup,monkey,monkeyimage
#
# function preload(){
#
#   backimage = loadImage("jungle.png");
#
#   monkeyimage = loadAnimation("Monkey_01.png","Monkey_02.png","Monkey_03.png","Monkey_04.png","Monkey_05.png","Monkey_06.png","Monkey_07.png","Monkey_08.png","Monkey_09.png","Monkey_10.png");
#
#
#
#   obstacleImage = loadImage("stone.png");
#
#   bananaImage = loadImage("banana.png");
#
#
# }
#
# function setup() {
#
#   createCanvas(800, 400);
#
#   score = 0;
#
#   back = createSprite(400,150,400,200);
#   back.addImage("B",backimage);
#   back.scale = 2;
#   back.x = back.width/2;
#   back.velocityX = -1.5;
#
#
#   monkey = createSprite(50,300,10,10);
#   monkey.addAnimation("M",monkeyimage);
#   monkey.scale = 0.11;
#
#   Ground = createSprite(200,315,400,5);
#   Ground.velocityX = -1.5;
#   Ground.x = Ground.width/2;
#   Ground.visible = false;
#
#
#
# }
#
# function draw() {
#
#   background("white");
# ...

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `saurabhsindhu96/ml4a.github.io/examples/classification-simple/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('saurabhsindhu96/ml4a.github.io/examples/classification-simple/sketch.js')
# Out:
# ```javascript
# // how many classes
# let numClasses = 3;
#
# let featureExtractor;
# let classifier;
# let video;
# let loss;
# let numImages;
# let label;
# let buttons;
#
# function setup() {
#   noCanvas();
#
#   label = 0;
#   numImages = Array(numClasses).fill(0);
#
#   video = createCapture(VIDEO);
#   video.parent('videoContainer');
#
#   featureExtractor = ml5.featureExtractor('MobileNet', modelReady);
#   featureExtractor.numClasses = numClasses;
#   classifier = featureExtractor.classification(video);
#
#   createButtons();
# }
#
# function modelReady() {
#   select('#loading').html('Base Model (MobileNet) loaded!');
# }
#
# function addImage(label) {
#   classifier.addImage(label);
# }
#
# function classify() {
#   console.log("CLASSIFY!")
#   classifier.classify(gotResults);
# }
#
# function createButtons() {
#   buttons = [];
#   for (var i=0; i<numClasses; i++) {
#     var button = createButton('class '+i);
#     button.parent('buttons');
#     button.id('class'+i);
# ...

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `lemonnuggets/fourier-epicycles/getCoords-from-sketch/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('lemonnuggets/fourier-epicycles/getCoords-from-sketch/sketch.js')
# Out:
# ```javascript
# let bg;
# let coords = [];
# let hist = [];
#
# function preload(){
#     bg = loadImage('assets/bg.jpg');
#     savedData = loadJSON('assets/savedData.json');
# }
#
# function mousePressed(){
#     if(mouseButton == LEFT){
#         coords.push({x: mouseX - width / 2, y: mouseY - height / 2});
#         print(coords);
#         hist = [];
#     }
# }
#
# function keyPressed(){
#     if(key == 'u' || key == 'U'){
#         hist.push(coords.pop());
#     }else if(key == 'r' || key == 'R'){
#         if(hist.length > 0){
#             coords.push(hist.pop());
#         }
#     }else if(key == 's' || key == 'S'){
#         saveJSON({coords}, 'savedData.json');
#     }
# }
#
# function setup() {
#     createCanvas(bg.width, bg.height);
#     let oldCoords = savedData.coords;
#     oldCoords.forEach(coord => {
#         coords.push(coord);
#     })
# }
#
# function draw() {
#     background(bg);
#
#     noFill();
#     stroke(255);
#     if(coords.length > 0){
# ...

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `navneet-sawhney/TS1/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "processed_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('navneet-sawhney/TS1/sketch.js')
# Out:
# ```javascript
# const Engine = Matter.Engine;
# const World = Matter.World;
# const Bodies = Matter.Bodies;
# const Constraint = Matter.Constraint;
#
# var engine, world;
# var holder,ball,ground;
# var stand1,stand2;
# var ball;
# var slingShot;
# var polygon_img;
# function preload(){
#   polygon_img=loadImage("polygon.png");
# }
# function setup() {
#   createCanvas(900,400);
#   engine = Engine.create();
#   world = engine.world;
#   Engine.run(engine);
#   ground = new Ground();
#   stand1 = new Stand(390,300,250,10);
#   stand2 = new Stand(700,200,200,10);
#
#   //level one
#   block1 = new Block(300,275,30,40);
#   console.log(block1);
#   block2 = new Block(330,275,30,40);
#   block3 = new Block(360,275,30,40);
#   block4 = new Block(390,275,30,40);
#   block5 = new Block(420,275,30,40);
#   block6 = new Block(450,275,30,40);
#   block7 = new Block(480,275,30,40);
#   //level two
#   block8 = new Block(330,235,30,40);
#   block9 = new Block(360,235,30,40);
# ...

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `vyankateshsmoti/CAT-enemys-Mouse/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('vyankateshsmoti/CAT-enemys-Mouse/sketch.js')
# Out:
# ```javascript
# var cat;
# var cat_Img,runningCat_Img,stopCat_Img;
#
# var mouse;
# var mouse_Img,mouse_Img1,mouse_Img3;
#
# var bk,bk_Img;
#
# function preload() {
#     //load the images here
#     cat_Img = loadImage("images/cat1.png");
#     runningCat_Img = loadAnimation("images/cat2.png","images/cat3.png");
#     //runningCat_Img1 = loadImage("images/cat3.png");
#     stopCat_Img = loadImage("images/cat4.png");
#     mouse_Img = loadImage("images/mouse1.png");
#     mouse_Img1 = loadAnimation("images/mouse2.png","images/mouse3.png");
#     //mouse_Img2 = loadImage("images/mouse3.png");
#     mouse_Img2 = loadImage("images/mouse4.png");
#     bk_Img = loadImage("images/garden.png");
# }
#
# function setup(){
#     createCanvas(600,600);
#     bk = createSprite(300,300,500,500);
#      bk.addImage("images/garden.png",bk_Img);
#
#     cat = createSprite(500,500,20,20);
#     cat.addImage("images/cat1.png",cat_Img);
#     cat.scale = 0.1;
#     console.log(cat.y);
#
# ...

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `Niranjant123/C-16PROJECT/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Niranjant123/C-16PROJECT/sketch.js')
# Out:
# ```javascript
#
# var monkey , monkey_running
# var banana ,bananaImage, obstacle, obstacleImage
# var FoodGroup, obstacleGroup
# var score
#
# function preload(){
#
#
#   monkey_running =            loadAnimation("monkey_0.png","monkey_1.png","monkey_2.png","monkey_3.png","monkey_4.png","monkey_5.png","monkey_6.png","monkey_7.png","monkey_8.png")
#
#   bananaImage = loadImage("banana.png");
#   obstaceImage = loadImage("obstacle.png");
#
# }
#
#
#
# function setup() {
#   // createCanvas(600, 600);
#
#
#
#   var survivalTime=0;
#
#   //creating monkey
#    monkey=createSprite(80,315,20,20);
#    monkey.addAnimation("moving", monkey_running);
#   // monkey.addImage(bananaImage)
#    monkey.scale=0.1
#
#   ground = createSprite(400,350,900,10);
#   ground.velocityX=-4;
#   ground.x=ground.width/2;
#   console.log(ground.x)
#
#   FoodGroup = new Group();
#   obstaclesGroup = new Group();
#
#   score = 0;
#
#
# }
#
#
# function draw() {
#
#   background(255);
#
#
#   if(ground.x<0) {
# ...

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `Aks1097/ElephantGame-1/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Aks1097/ElephantGame-1/sketch.js')
# Out:
# ```javascript
#
#
# var elephant, elephant_running, elephant_collided;
#
#
#
# var obstacle;
# var backgroundImg, background;
# var jumpSound, collidedSound;
#
# function preload(){
#
#   backgroundImg = loadImage("assets/Forest_bg.jpg")
#
#   elephant_running = loadAnimation("assets/Elephant_1.png","assets/Elephant_2.png","assets/Elephant_3.png");
#   elephant_collided = loadAnimation("assets/Elephant_4.png");
#
#   obstacle = loadImage("assets/Obstacle.png");
# }
#
# function setup() {
#   createCanvas(windowWidth, windowHeight);
#
#   elephant = createSprite(50,height-70,20,50);
#
#
#   elephant.addAnimation("running", elephant_running);
#   elephant.addAnimation("collided", elephant_collided);
#   elephant.setCollider('circle',0,0,350)
#   //elephant.scale = 0.08
#   // elephant.debug=true
#   // background=createSprite(200,200,windowWidth,windowHeight);
#   // background.addImage(backgroundImg);
#   // background.scale=2.5;
#   // invisibleGround.visible =false
#
# }
#
# ...

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `rockriderST100/C11/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('rockriderST100/C11/sketch.js')
# Out:
# ```javascript
# var seaImage
# var sea
# var ship_image,ship
#
# function preload(){
# seaImage=loadImage("sea.png")
# ship_Image=loadAnimation("ship-1.png","ship-2.png")
# }
#
# function setup(){
#   createCanvas(400,400);
#   sea=createSprite(400,200)
#   sea.addImage(seaImage)
#   sea.velocityX=-3
#   ship=createSprite(200,300)
#   ship.addAnimation("moving",ship_Image)
# }
#
# function draw() {
#   background("blue");
#
#
#   if(sea.x<0){
#     sea.x=400
#   }
#   sea.scale=0.3
#   ship.scale=0.2
#  drawSprites()
# }
# ```

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `David-droid-bot/Project-38/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('David-droid-bot/Project-38/sketch.js')
# Out:
# ```javascript
# var BananaImage,obstacleGroup,obstacleImage,background1,score,bananaGroup;
# var foodGroup,backImage,ground,monkey,player_running;
#
# function preload(){
#   backImage=loadImage("jungle.png");
#  player_running=loadAnimation("Monkey_01.png","Monkey_02.png","Monkey_03.png","Monkey_04.png","Monkey_05.png","Monkey_06.png","Monkey_07.png","Monkey_08.png","Monkey_09.png","Monkey_10.png");
#
#   bananaImage=loadImage("banana.png");
#   obstacleImage=loadImage("stone.png");
# }
#
# function setup() {
#   createCanvas(displayWidth-20,displayHeight-30);
#   background1=createSprite(0,0,800,400);
#   background1.addImage(backImage);
#   background1.scale=3;
#   background1.x=background1.width/2;
#   background1.velocity=-2;
#   score=0;
#   ground=createSprite(400,350,800,10);
#   ground.x=ground.width / 2;
#
#   monkey=createSprite(100,340,20,50);
#   monkey.addAnimation("monkey",player_running);
#   monkey.scale=0.18;
#   ground.visible=false;
#   BananaGroup=new Group();
#
# ...

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `pedroaugustovieira/projeto-10/Projeto-10-Viajando-Num-Navio-main/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('pedroaugustovieira/projeto-10/Projeto-10-Viajando-Num-Navio-main/sketch.js')
# Out:
# ```javascript
# var sea,ship;
# var seaImg,shipImg;
#
# function preload(){
#   seaImg = loadImage("sea.png");
#   shipImg1 = loadAnimation("ship-1.png","ship-1.png",
#                             "ship-2.png","ship-1.png");
# }
#
# function setup(){
#   createCanvas(400,400);
#   background("blue");
#
#   // Plano de fundo móvel
#   sea=createSprite(400,200);
#   sea.addImage(seaImg);
#   sea.velocityX = -5;
#   sea.scale=0.3;
#
#
#   ship = createSprite(130,200,30,30);
#   ship.addAnimation("movingShip",shipImg1);
#   ship.scale =0.25;
#
# }
#
# function draw() {
#   background(0);
#   sea.velocityX = -3;
#
#
#   //código para redefinir o plano de fundo
#   if(sea.x < 0){
#     sea.x = sea.width/8;
#   }
#
#   drawSprites();
# }
#
# ```

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `jetaaaaaa/tower-seige-1/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('jetaaaaaa/tower-seige-1/sketch.js')
# Out:
# ```javascript
# const Engine = Matter.Engine;
# const World = Matter.World;
# const Bodies = Matter.Bodies;
# const Constraint = Matter.Constraint;
#
# var engine, world;
# var ball,ground;
# var stand1,stand2;
# var slingShot;
# var rock_img;
#
# function preload(){
#   rock_img=loadImage("rock.png");
# }
# function setup() {
#
#   createCanvas(900,400);
#   engine = Engine.create();
#   world = engine.world;
#   Engine.run(engine);
#
#   ground = new Ground();
#   stand1 = new Stand(390,300,250,10);
#   stand2 = new Stand(700,200,200,10);
#
#   //level one
#   block1 = new Block(300,275,30,40);
#   block2 = new Block(330,275,30,40);
#   block3 = new Block(360,275,30,40);
#   block4 = new Block(390,275,30,40);
#   block5 = new Block(420,275,30,40);
#   block6 = new Block(450,275,30,40);
#   block7 = new Block(480,275,30,40);
#   //level two
#   block8 = new Block(330,235,30,40);
#   block9 = new Block(360,235,30,40);
#   block10 = new Block(390,235,30,40);
# ...

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `Lauraqf/C11-Proyecto-LLQF/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Lauraqf/C11-Proyecto-LLQF/sketch.js')
# Out:
# ```javascript
# var path,boy, leftBoundary,rightBoundary;
# var pathImg,boyImg;
# var i;
#
# function preload(){
#   pathImg = loadImage("path.png");
#   boyImg = loadAnimation("Runner-1.png","Runner-2.png");
# }
#
# function setup(){
#
#   createCanvas(400,400);
#
# // Mover el fondo
# path=createSprite(200,200);
# path.addImage(pathImg);
# path.velocityY = 4;
# path.scale=1.2;
#
# //crear sprite de niño corriendo
# boy = createSprite(180,340,30,30);
# boy.scale=0.08;
# boy.addAnimation("JakeRunning",boyImg);
#
#
# leftBoundary=createSprite(0,0,100,800);
#
# leftBoundary.visible = false;
#
#
# rightBoundary=createSprite(410,0,100,800);
# rightBoundary.visible = false;
# }
#
# function draw() {
#   background(0);
#   path.velocityY = 4;
#
#   boy.x = World.mouseX;
#
#   edges= createEdgeSprites();
#   boy.collide(edges[3]);
#   boy.collide(leftBoundary);
#   boy.collide(rightBoundary);
#
#   //código para reiniciar el fondo
#
#   if(path.y > 400 ){
#     path.y = height/2;
#   }
#
# ...

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `DivyanshWHJ/C10-project/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('DivyanshWHJ/C10-project/sketch.js')
# Out:
# ```javascript
# var sea,ship;
# var seaImg,shipImg;
#
# function preload(){
#   //uncomment the code to add animation to ship
#
#   shipImg1 = loadAnimation("ship-1.png");
#   //shipImg1 = loadAnimation("ship-1.png");
#   //shipImg1 = loadAnimation("ship-1");
#   shipImg1 = loadAnimation("ship-1.png","ship-2.png","ship-1.png","ship-2.png");
#   //shipImg1 = loadAnimation("ship-1","ship-2","ship-1","ship-2");
#
#   seaImg = loadImage("sea.png");
# }
#
# function setup(){
#   createCanvas(400,400);
#   background("blue");
#
#   // Moving background
#   sea=createSprite(400,200);
#   sea.addImage(seaImg);
#   sea.velocityX = -5;
#   sea.scale=0.3;
#
#
#   ship = createSprite(130,200,30,30);
#   ship.addAnimation("movingShip",shipImg1);
#   ship.scale =0.25;
#
# }
#
# function draw() {
#   background(0);
#   sea.velocityX = -3;
#
#   //uncomment code to reset the background
#   if(sea.x < 0){
#     //sea.x = 0;
#     //sea.x = sea.width;
#     sea.x = sea.width/8;
# ...

# %% [markdown]
# ## Sample 21
#
# **File path:**
#
# `tabassum-a-hub/project-31/project-30/TS2-master/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('tabassum-a-hub/project-31/project-30/TS2-master/sketch.js')
# Out:
# ```javascript
# const Engine = Matter.Engine;
# const World = Matter.World;
# const Bodies = Matter.Bodies;
# const Constraint = Matter.Constraint;
#
# var engine, world;
# var holder,polygon,ground;
# var stand1,stand2;
# var polygon;
# var slingShot;
# var polygon_img;
# function preload(){
#   polygon_img=loadImage("polygon.png");
# }
# function setup() {
#   createCanvas(900,400);
#   engine = Engine.create();
#   world = engine.world;
#   Engine.run(engine);
#   ground = new Ground();
#   stand1 = new Stand(390,300,250,10);
#   stand2 = new Stand(700,200,200,10);
#
#   //level one
#   block1 = new Block(300,275,30,40);
#   block2 = new Block(330,275,30,40);
#   block3 = new Block(360,275,30,40);
#   block4 = new Block(390,275,30,40);
#   block5 = new Block(420,275,30,40);
#   block6 = new Block(450,275,30,40);
#   block7 = new Block(480,275,30,40);
#   //level two
#   block8 = new Block(330,235,30,40);
#   block9 = new Block(360,235,30,40);
# ...

# %% [markdown]
# ## Sample 22
#
# **File path:**
#
# `vishishta-b/tom-and-jerry-final/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('vishishta-b/tom-and-jerry-final/sketch.js')
# Out:
# ```javascript
# var cat ,garden;
# var background1;
#
# function preload() {
#     //load the images here
#     cat = loadImage("cat1.png");
#     catRunning = loadAnimation("cat2.png","cat3.png");
#     catSad = loadImage("cat4.png");
#     garden = loadImage("garden.png");
#     mouseStanding = loadImage("mouse1.png");
#     mouseTeasing = loadAnimation("mouse3.png");
# }
#
# function setup(){
#     createCanvas(1000,800);
#    // background("blue");
#     //create tom and jerry sprites here
#    background1 = createSprite(500,400,10,50);
#    background1.addImage(garden);
#   // background1.scale = 0.5;
#
#   cat1 = createSprite(700,660)
#   cat1.addImage(cat);
#   cat1.scale = 0.1;
#
#   mouse1 = createSprite(100,660)
#   mouse1.addImage(mouseStanding);
#   mouse1.scale = 0.1;
#
# }
# function draw() {
#
#     background(255);
#     //Write condition here to evalute if tom and jerry collide
#
# if(keyDown("LEFT_ARROW")){
#
# cat1.velocityX = -5;
# ...

# %% [markdown]
# ## Sample 23
#
# **File path:**
#
# `OhLouis/OhLouis.github.io/p5/meme/pepe.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('OhLouis/OhLouis.github.io/p5/meme/pepe.js')
# Out:
# ```javascript
# let img; // Declare variable 'img'.
# let img2; // Declare variable 'img'.
# var col= 300;
# var c= 50;
# var d= 30;
# function setup() {
#   createCanvas(windowWidth, windowHeight);
#   img = loadImage('images/nervous_pepe.png'); // Load the PEPE
#   img2 = loadImage('images/rare_nervous_pepe.png'); // Load the RARE PEPE
# }
# function draw() {
#
# //background color should change with mouseX
#   col,c,d = mouseX/3;
# background (col,c,d);
#
# if(mouseIsPressed){
# image(img2, 0,130);
# }
# else {
#
#   // Displays the image at its actual size at point (0,10)
#   image(img, 0, 130);
# }
#   //left eye
#   push();
#   fill(0);
#   //pupils should move side to side
#   ellipse(map(mouseX,0, width, 200, 300),380, 30, 30);
#   //ellipse(300, 260, 30, 30);
#   pop();
#
#   //right eye
#   push();
#   fill(0);
#   //pupils should move side to side
#   ellipse(map(mouseX, 0, width, 400, 498),380, 30, 30);
#   //ellipse(500, 260, 30, 30);
#   pop();
# }
#
# ```

# %% [markdown]
# ## Sample 24
#
# **File path:**
#
# `Khiende-May-Parker/Project-19/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_image",
#     "processed_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Khiende-May-Parker/Project-19/sketch.js')
# Out:
# ```javascript
#
# var monkey , monkey_running
# var banana ,bananaImage, obstacle, obstacleImage
# var FoodGroup, obstacleGroup
# var score
#
# function preload(){
#
#
#   monkey_running =            loadAnimation("monkey_0.png","monkey_1.png","monkey_2.png","monkey_3.png","monkey_4.png","monkey_5.png","monkey_6.png","monkey_7.png","monkey_8.png")
#
#   bananaImage = loadImage("banana.png");
#   obstaceImage = loadImage("obstacle.png");
#
# }
#
#
#
# function setup() {
#   // createCanvas(600, 600);
#
#
#
#   var survivalTime=0;
#
#   //creating monkey
#    monkey=createSprite(80,315,20,20);
#    monkey.addAnimation("moving", monkey_running);
#   // monkey.addImage(bananaImage)
#    monkey.scale=0.1
#
#   ground = createSprite(400,350,900,10);
#   ground.velocityX=-4;
#   ground.x=ground.width/2;
#   console.log(ground.x)
#
#   FoodGroup = new Group();
#   obstaclesGroup = new Group();
#
#   score = 0;
#
#
# }
#
#
# function draw() {
#
#   background(255);
#
# ...

# %% [markdown]
# ## Sample 25
#
# **File path:**
#
# `mateotellez/Clase-20/TomyJerry-main/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('mateotellez/Clase-20/TomyJerry-main/sketch.js')
# Out:
# ```javascript
# var canvas,bg;
# var together;
# var tom, tomImg1,tomImg2;
# var jerry, jerryImg1,jerryImg2;
#
# function preload() {
#     bg = loadImage("images/garden.png");
#     tomImg1= loadAnimation("images/tomOne.png");
#     tomImg2=loadAnimation("images/tomTwo.png","images/tomThree.png");
#     tomImg3= loadAnimation("images/tomFour.png");
#     jerryImg1=loadAnimation("images/jerryOne.png");
#     jerryImg2= loadAnimation("images/jerryTwo.png","images/jerryThree.png");
#     jerryImg3=loadAnimation("images/jerryFour.png");
#
# }
#
# function setup(){
#     canvas = createCanvas(1000,800);
#
#     tom = createSprite(870, 600);
#     tom.addAnimation("tomSleeping", tomImg1);
#     tom.scale = 0.2;
#
#     jerry = createSprite(200, 600);
#     jerry.addAnimation("jerryStanding", jerryImg1);
#     jerry.scale = 0.15;
#
# }
#
# function draw() {
#
#     background(bg);
#
#     if(tom.x - jerry.x < (tom.width - jerry.width)/2)
#     {
#         tom.velocityX=0;
# ...

# %% [markdown]
# ## Sample 26
#
# **File path:**
#
# `liiightt/Machine-Learning-Object-Detection/Machine Learning Object Detection with P5js Sketch/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('liiightt/Machine-Learning-Object-Detection/Machine Learning Object Detection with P5js Sketch/sketch.js')
# Out:
# ```javascript
# // Classification with Machine Learning
# // Can Machine learning and AI make us safer?
# // By Idorenyin Eno
#
#
# // Video - Create a variable for Video
# var video;
# // Label - Create a variable for Label
# var label = ''
# var sLabel = ''
# // Classifier - Create variable for Classifier
# var theClassifier;
#
#
# // Use P5s preoload function to call ML5s image classifier against a neural network
# function preload() {
#   theClassifier = ml5.imageClassifier('https://teachablemachine.withgoogle.com/models/2zapyKin/' + 'model.json');
# }
#
# function setup() {
#   createCanvas(640, 480);
#   video = createCapture(VIDEO);
#   video.hide();
#   classifyTheVideo(); // Classify data
# }
#
# // Classify video input
# function classifyTheVideo() {
#   theClassifier.classify(video, giveData);
# }
#
# function draw() {
#   background(255);
#
#   image(video, 0, 0); // Draw video on canvas
#
#   // Create label on canvas
#   textSize(28);
#   fill(255);
# ...

# %% [markdown]
# ## Sample 27
#
# **File path:**
#
# `ApoorvSaksham/Project/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ApoorvSaksham/Project/sketch.js')
# Out:
# ```javascript
# var bg, bgImage;
# var cat, catImage;
# var mouse, mouseImage;
# var catAnim, mouseAnim;
# var catEndImg, mouseEndImg;
#
# var gameState;
# PLAY = 1;
# END = 0;
# function preload() {
#     //load the images here
#     bgImage = loadImage("images/garden.png");
#     catImage =loadAnimation("images/cat1.png");
#     mouseImage =loadAnimation("images/mouse1.png");
#     catAnim = loadAnimation("images/cat2.png","images/cat3.png");
#     mouseAnim = loadAnimation("images/mouse2.png","images/mouse3.png");
#     catEndImg = loadAnimation("images/cat4.png");
#     mouseEndImg = loadAnimation("images/mouse4.png");
# }
#
# function setup(){
#     createCanvas(1000,800);
#     //Creating the background
#     bg = createSprite(500,400,1000,800);
#     bg.addImage("bgPic",bgImage);
#
#     cat = createSprite(720,600,20,20);
#     cat.addAnimation("catAnim",catImage);
#     cat.scale = 0.13;
#
#
#     mouse = createSprite(130,610,20,20);
# ...

# %% [markdown]
# ## Sample 28
#
# **File path:**
#
# `SuddenFlame414/Project-40/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('SuddenFlame414/Project-40/sketch.js')
# Out:
# ```javascript
# var database;
# var back_img;
# var gameState =0;
# var playerCount = 0;
# var allPlayers;
#
# var player, form,game;
# var player1,player2;
# var players;
# var fruits;
# var fruitGroup;
# var fruit1_img, fruit2_img, fruit3_img, fruit4_img, fruit5_img;
# var player_img;
#
#
# function preload(){
#   back_img = loadImage("images/jungle.jpg");
#   player_img = loadImage("images/basket2.png");
#   fruit1_img = loadImage("images/apple2.png");
#   fruit2_img = loadImage("images/banana2.png");
#   fruit3_img = loadImage("images/melon2.png");
#   fruit4_img = loadImage("images/orange2.png");
#   fruit5_img = loadImage("images/pineapple2.png");
#   fruitGroup = new Group();
# }
# function setup() {
#   createCanvas(1000, 600);
#   database = firebase.database();
#   game = new Game();
#   game.getState();
#   game.start();
#
# }
#
# function draw() {
#   background(back_img);
#
#    if (playerCount === 2) {
#      game.update(1);
#    }
#    if (gameState === 1) {
# ...

# %% [markdown]
# ## Sample 29
#
# **File path:**
#
# `iamghebs/teaching-dd17/static/websites/g04/0ecosystem/script.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('iamghebs/teaching-dd17/static/websites/g04/0ecosystem/script.js')
# Out:
# ```javascript
#
# let infoIcon;
# let infoContainer;
# let infoBox;
# let infoButton;
#
# function preload() {
#   infoIcon = select("#infoIcon")
#   infoContainer = select("#infoContainer");
#   infoBox = select("#infoBox");
#   infoButton = select("#infoButton");
#
#   infoIcon.mousePressed(enlargeInfo);
#   infoButton.mousePressed(reduceInfo);
#
#   if (getItem("firstEcosystemLoad")==false) {
#     infoBox.addClass("closedInfo");
#     infoContainer.addClass("removeElements");
#   }
# }
#
# function setup() {
#   infoBox.style("transition",".5s");
#   infoContainer.style("transition",".5s");
# }
#
# function reduceInfo() {
#   infoBox.addClass("closedInfo");
#   infoContainer.addClass("removeElements");
#   if (getItem("firstEcosystemLoad")===null) {
#     storeItem("firstEcosystemLoad", false);
#   }
# }
#
# function enlargeInfo() {
#   infoBox.removeClass("closedInfo");
#   infoContainer.removeClass("removeElements");
# }
#
# ...

# %% [markdown]
# ## Sample 30
#
# **File path:**
#
# `amonieb/project-48/SHOOTING-RANGE-II-template-main/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('amonieb/project-48/SHOOTING-RANGE-II-template-main/sketch.js')
# Out:
# ```javascript
# var score =0;
# var gun,bluebubble,redbubble, bullet, backBoard;
#
# var gunImg,bubbleImg, bulletImg, blastImg, backBoardImg;
#
# var redBubbleGroup, redBubbleGroup, bulletGroup;
#
#
# var life =3;
# var score=0;
# var gameState=1
#
# function preload(){
#   gunImg = loadImage("gun1.png")
#   blastImg = loadImage("blast.png")
#   bulletImg = loadImage("bullet1.png")
#   blueBubbleImg = loadImage("waterBubble.png")
#   redBubbleImg = loadImage("redbubble.png")
#   backBoardImg= loadImage("back.jpg")
# }
# function setup() {
#   createCanvas(800, 600);
#
#   backBoard= createSprite(50, width/2, 100,height);
#   backBoard.addImage(backBoardImg)
#
#   gun= createSprite(100, height/2, 50,50);
#   gun.addImage(gunImg)
#   gun.scale=0.2
#
#   bulletGroup = createGroup();
#   blueBubbleGroup = createGroup();
#   redBubbleGroup = createGroup();
#
#   heading= createElement("h1");
#   scoreboard= createElement("h1");
# }
#
# function draw() {
#   background("#BDA297");
#
# ...
