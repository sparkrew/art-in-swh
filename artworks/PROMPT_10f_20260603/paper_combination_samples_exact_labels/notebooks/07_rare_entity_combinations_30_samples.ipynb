# %%
from pathlib import Path
from IPython.display import Markdown, display
import json

SRC_ROOT_DIR = Path('/home/rpinter/links/projects/def-baudry/shared/data/artworks/src')

def print_code_file(relative_file_path, language="javascript"):
    file_path = SRC_ROOT_DIR / relative_file_path
    code = file_path.read_text(encoding="utf-8", errors="ignore")

    display(Markdown(f"```{language}\n{code}\n```"))

# %% [markdown]
# # Rare combinations of entities
#
# Samples from entity combinations whose total count is less than or equal to 10.
#
# Prompt folder: `PROMPT_10f_20260603`
#
# Matching files after filtering: `87`
#
# Samples in this notebook: `30`
#
# Excluded source-code terms: `Coding Train, Daniel Shiffman`
#
# Excluded path terms: `Tutorials, Coursera, CodingChallenges, Rainbow-Code, Courses, p5.js, week`
#
# ## Extra metadata
#
# ```json
# {
#   "rare_entity_combo_max_count": 10,
#   "number_of_rare_entity_combinations": 34,
#   "rare_entity_combo_counts": {
#     "none": 7,
#     "processed_audio": 4,
#     "processed_audio + processed_image": 2,
#     "processed_audio + processed_image + randomness + synthesized_image + synthesized_sound + synthesized_text": 2,
#     "processed_audio + processed_image + randomness + synthesized_image + synthesized_text": 1,
#     "processed_audio + processed_image + randomness + synthesized_sound + synthesized_text": 2,
#     "processed_audio + processed_image + synthesized_image": 3,
#     "processed_audio + processed_image + synthesized_image + synthesized_sound + synthesized_text": 1,
#     "processed_audio + processed_image + synthesized_image + synthesized_text": 1,
#     "processed_audio + processed_image + synthesized_text": 1,
#     "processed_audio + randomness + synthesized_image + synthesized_sound": 1,
#     "processed_audio + randomness + synthesized_image + synthesized_text": 8,
#     "processed_audio + randomness + synthesized_text": 1,
#     "processed_audio + synthesized_image + synthesized_sound": 1,
#     "processed_audio + synthesized_image + synthesized_text": 4,
#     "processed_audio + synthesized_sound": 1,
#     "processed_audio + synthesized_text": 5,
#     "processed_image + processed_text": 1,
#     "processed_image + processed_text + randomness + synthesized_image": 3,
#     "processed_image + processed_text + randomness + synthesized_text": 2,
#     "processed_image + processed_text + synthesized_image": 6,
#     "processed_image + processed_text + synthesized_image + synthesized_text": 3,
#     "processed_image + processed_text + synthesized_text": 1,
#     "processed_image + randomness + synthesized_text": 1,
#     "processed_image + synthesized_image + synthesized_sound": 5,
#     "processed_image + synthesized_image + synthesized_sound + synthesized_text": 1,
#     "processed_image + synthesized_text": 1,
#     "processed_text": 1,
#     "processed_text + randomness + synthesized_image + synthesized_text": 4,
#     "randomness + synthesized_image + synthesized_sound": 5,
#     "randomness + synthesized_sound + synthesized_text": 1,
#     "synthesized_image + synthesized_sound": 3,
#     "synthesized_image + synthesized_sound + synthesized_text": 1,
#     "synthesized_text": 3
#   }
# }
# ```

# %% [markdown]
# ## Sample paths
#
# 1. `localcrafts101/ATK302/p5/googledata/sketch.js`
# 2. `LadyK/CC_midterm_LadyK/midterm_cc/sketch.js`
# 3. `adi1088/the-warrior-test/sketch.js`
# 4. `imdcrazy1/ME_menu/mass effect/sketch.js`
# 5. `Robert-FA/HealthCareDataSets/C-19/envc19/C19/sketch.js`
# 6. `mateotis/find-bae/find-bae.js`
# 7. `luquisinger/aBruxa/sketch.js`
# 8. `ValeriVoev/p5ml5/sketch.js`
# 9. `hbcbh1999/ml4a.github.io/examples/classification-guitar/sketch.js`
# 10. `jtallison/LSU-PDM-Spring-2021/SerialTop5_Setup/sketch.js`
# 11. `veitkal/draftSystem_UI/public/ui.js`
# 12. `Timgerr321/Coding/GIS Maar beter/sketch.js`
# 13. `ronavt/Calculator/sketch.js`
# 14. `patrickdolloso/CM1005/Game Project/FinalGameProject_PatrickDolloso/sketch.js`
# 15. `patrickdolloso/CM1005/Sleuth_Pro/701/701-2-34949270-1382801/sketch.js`
# 16. `saurabhsindhu96/ml4a.github.io/examples/facetrack-knn-sound/sketch.js`
# 17. `jcharry/ITP/artistComparator/sketch.js`
# 18. `patrickdolloso/CM1005/Sleuth_Pro/502/502-1-93379768-1382801/sketch.js`
# 19. `JENkt4k/p5.serialport/examples/makePortMenu/sketch.js`
# 20. `Aaron033/NodeListapp/website/empty-example/sketch.js`
# 21. `PazosAndrew/meme/p5/addons/p5.serialport-master/examples/echo/sketch.js`
# 22. `saurabhsindhu96/ml4a.github.io/examples/classification-guitar/sketch.js`
# 23. `Dev102a/Class13/Pro-c13-TA1_template-main/Pro-c13-TA1_template-main/sketch.js`
# 24. `magilla121/magilla121.github.io/sketch.js`
# 25. `gaovicky/CupcakeMaker/p5/midterm/sketch.js`
# 26. `FOUTRE14/GAY/sketch.js`
# 27. `brhui/Challenge2_Wang_Hui/Challenge2/sketch.js`
# 28. `zachkrall/mfadt-5in5/01/sketch.js`
# 29. `localcrafts101/ATK302/p5/joke1/sketch.js`
# 30. `patrickdolloso/CM1005/Game Project/sound_template/sound_template/sketch.js`

# %% [markdown]
# ## Sample 1
#
# **File path:**
#
# `localcrafts101/ATK302/p5/googledata/sketch.js`
#
# **Label combination:**
#
# `processed_text + randomness + synthesized_image + synthesized_text | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_text + randomness + synthesized_image + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('localcrafts101/ATK302/p5/googledata/sketch.js')
# Out:
# ```javascript
# var namesArray = [];
#
# function setup() {
#
#   // Tabletop stuff, for getting google spreadsheet data in.
#   let url = '1GtE3eoYVWBv9zMPoyettXzDCEv6qdNGKio_hgEh5duM'; // this is KEY of the URL from the sheet
#   let settings = {
#     key: url, // The url of the published google sheet
#     callback: gotData, // A callback for when the data comes in
#     simpleSheet: true // This makes things simpler for just a single worksheet of rows
#   };
#
#   Tabletop.init(settings); // Grab the data from the spreadsheet!
#   // End Tabletop initialization stuff
#
#
#   // Regular setup code we usually have
#   createCanvas(600, 600);
#   textAlign(CENTER);
#   ellipseMode(CENTER);
#   rectMode(CENTER);
#
# }
#
# // The data comes back as an array of objects
# // Each object contains all the data for one row of the sheet
# function gotData(data) {
#
#   console.log(data); // Print the data in the console
#
# ...

# %% [markdown]
# ## Sample 2
#
# **File path:**
#
# `LadyK/CC_midterm_LadyK/midterm_cc/sketch.js`
#
# **Label combination:**
#
# `none | interaction=no | static + visual`
#
# **Entity combination:**
#
# `none`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('LadyK/CC_midterm_LadyK/midterm_cc/sketch.js')
# Out:
# ```javascript
# let c;
# let m;
# let interval;
# let lastTime;
# let currentTime;
# let scene1;
# let scene2;
# let scene3;
#
#
#
# function setup() {
#   createCanvas(1200, 1200);
#   background(0);
#   lastTime = 0;
#   interval = 10000;
#   scene1 = true;
#   scene2 = false;
#   scene3 = false;
# }
#
# function draw() {
#
#   if(frameCount < 800){  // one trick pony; sketch has to be refreshed to repeat
#     background(0);
#
#   }
#   else if(frameCount > 1000){
#     //background(255);
#     bigBadAssFunction();
#   }
#   //print(frameCount);
#   //print(millis());
#
#
#   if(currentTime - lastTime > interval){
#     background(255, 0, 0);
#     lastTime = currentTime; // record the last time something happened for the next comparison
#   }
#
#   if(scene1 == true){
#     //runScene1();
#   }
#
#   if(scene2 == true){
#     //runScene2();
#   }
#   if(scene3 == true){
#     //runScene2();
#   }
#
#
#
# }
#
# function mousePressed(){
#   //currentTime = millis();
#
# ...

# %% [markdown]
# ## Sample 3
#
# **File path:**
#
# `adi1088/the-warrior-test/sketch.js`
#
# **Label combination:**
#
# `processed_audio + processed_image + synthesized_image | interaction=no | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_audio"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('adi1088/the-warrior-test/sketch.js')
# Out:
# ```javascript
# var form , story;
# var gameState =0;
# var lake, lakeImg;
# var player, playerImg;
# var stage1, stage2 ,stage3;
# var stage1Img, stage2Img, stage3Img;
# var introMusic ;
#
#
# function preload(){
#   // backImage=loadImage("jungle.jpg");
#   stage1Img=loadImage("images/Stage_1.png");
#   stage2Img=loadImage("images/Stage_2.gif");
#   stage3Img=loadImage("images/Stage_3.jpg");
#   playerImg = loadAnimation("images/sprite_0.png","images/sprite_1.png","images/sprite_2.png")
#   introMusic=loadSound("sounds/Intro_Music.mp3");
# }
#
# function setup() {
#   createCanvas(displayWidth,displayHeight-117)
#  game = new Game();
#  game.start();
#  gameState=0;
#
# }
#
# function draw() {
#   background("black")
#
#   if(gameState===1 || gameState===2){
#     clear();
#     game.play();
#     // introMusic.play();
#   }
#
#
#
#   drawSprites();
# }
#
#
#
# ```

# %% [markdown]
# ## Sample 4
#
# **File path:**
#
# `imdcrazy1/ME_menu/mass effect/sketch.js`
#
# **Label combination:**
#
# `processed_audio + processed_image + randomness + synthesized_image + synthesized_text | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + processed_image + randomness + synthesized_image + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "processed_image",
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('imdcrazy1/ME_menu/mass effect/sketch.js')
# Out:
# ```javascript
# var iMax=2000;
# var x = new Array();
# var y = new Array();
# var Size = new Array();
# var Alpha = new Array();
# var Col = new Array();
# var Alpha2=255;
#
# function preload() {
# Menu_song=loadSound('me.mp3');
# myFont=loadFont('me123.ttf');
# logo_me = loadImage("logo_me.png");
# }
#
# function setup(){
# createCanvas(windowWidth,windowHeight);
# frameRate(60);
# var Earth={size:100};
#
# var Logo={x:windowWidth/2,y:windowHeight/2};
#
# for (i=0;i<iMax;i++) {
# var ran= random(1000);
# x[i]=map(ran,0,1000,0,windowWidth);
# }
#
# for (i=0;i<iMax;i++) {
# var ran= random(1000);
# y[i]=map(ran,0,1000,0,windowHeight);
# }
#
# for (i=0;i<iMax;i++) {
# var ran= random(6);
# Size[i]=ran;
# }
#
# for (i=0;i<iMax;i++) {
# var ran= random(50,255);
# Alpha[i]=ran;
# }
#
# for (i=0;i<iMax;i++) {
# var ran= random(200,255);
# Col[i]=ran;
# }
#
# }
#
# function draw() {
# Menu_song.setVolume(0.1);
# if(Menu_song.isPlaying())
#  {
#
#  }
#     else{ Menu_song.play();}
# ...

# %% [markdown]
# ## Sample 5
#
# **File path:**
#
# `Robert-FA/HealthCareDataSets/C-19/envc19/C19/sketch.js`
#
# **Label combination:**
#
# `processed_image + processed_text + synthesized_image | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + processed_text + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "processed_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Robert-FA/HealthCareDataSets/C-19/envc19/C19/sketch.js')
# Out:
# ```javascript
# let covidClassifer
# let canvas
#
# function preload(){
#   positiveImage = loadImage(`image55.png`)
#   negativeImage = loadImage(`CHNCXR_0001_0.png`)
# }
#
# function setup() {
#   canvas = createCanvas(400, 400);
#   image(positiveImage,0,0,canvas.width /2,canvas.height /2)
#   image(negativeImage,0,200,canvas.width /2,canvas.height /2)
#
#   let options = {
#     inputs:[64,64,4],
#     task: 'imageClassification',
#   }
#   const modelData = {
#     model: 'model/model.json',
#     metadata: 'model/model_meta.json',
#     weights: 'model/model.weights.bin'
#   }
#
#   covidClassifer = ml5.neuralNetwork(options)
#   covidClassifer.load(modelData, modelLoaded)
# }
#
# function keyTyped(){
#   if(key == "p"){
#     covidClassifer.classify({image:positiveImage},(err,results) => {
#       if(err) console.log(err)
#       else{
#         console.log()
#         text(results[0].label + ":" + results[0].confidence,220,50)
#       }
#     })
#   }
#   if(key == "n"){
# ...

# %% [markdown]
# ## Sample 6
#
# **File path:**
#
# `mateotis/find-bae/find-bae.js`
#
# **Label combination:**
#
# `processed_audio + randomness + synthesized_image + synthesized_text | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + randomness + synthesized_image + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('mateotis/find-bae/find-bae.js')
# Out:
# ```javascript
# let player;
# let bae;
# let music;
# let wall;
# let borders;
# let cars;
# let fakeBaes;
#
# let timer = 0
# let timeLimit = 4
#
# SCREEN_WIDTH = 600
# SCREEN_HEIGHT = 600
#
# level = 0
# isBaeFound = false
#
# function preload() { // Preloads the song to make sure there are no playing errors
# 	song = loadSound("sounds/music.mp3");
# }
#
# function setup() {
#
# 	createCanvas(SCREEN_WIDTH,SCREEN_HEIGHT);
# 	background(255)
#
# 	mainMenu()
#
# }
#
# function mainMenu() { // Initial screen
# 	fill(0, 0, 0)
# 	textSize(36)
# 	textAlign(CENTER)
# 	text("press space to play", width/2, height/2) // A different key is used here to advance to stop insta-advancing with a single enter
# 	textSize(20)
# 	text("(and enter to progress through levels)", width/1.5, height/1.5)
#
# 	if(keyDown(32)) {
# 		if(song.isPlaying()) // Reloads song at the start of the game
# 			song.stop()
# 		song.play()
# 		level = 1
# 		charSetup()
# 	}
# }
#
# function draw() {
#
# 	background(255)
#
# ...

# %% [markdown]
# ## Sample 7
#
# **File path:**
#
# `luquisinger/aBruxa/sketch.js`
#
# **Label combination:**
#
# `processed_audio + processed_image | interaction=no | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + processed_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "processed_audio"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('luquisinger/aBruxa/sketch.js')
# Out:
# ```javascript
# function preload(){
#   imagemCenario = loadImage('Sprite/cenario/floresta.png');
#   imagemGameOver= loadImage('Sprite/assets/game-over.png');
#   imagemPersonagem = loadImage('Sprite/personagem/run.png');
#   imagemInimigo = loadImage('Sprite/inimigos/gotinha.png');
#   imagemInimigoGrande = loadImage('Sprite/inimigos/troll.png')
#   imagemInimigoVoador = loadImage('Sprite/inimigos/gotinha-voadora.png');
#   imagemTelaInicial = loadImage('Sprite/assets/telaInicial.png');
#   imagemVida = loadImage('Sprite/assets/coracao.png');
#   fonteTelaInicial = loadFont('Sprite/assets/fonteTelaInicial.otf');
#   fita = loadJSON('fita/fita.json');
#   somDoJogo = loadSound('sons/trilha_jogo.mp3');
#   somDoPulo = loadSound('sons/somPulo.mp3');
# }
# function setup() {
#   createCanvas(windowWidth, windowHeight);
#   telaInicial = new TelaInicial()
#   jogo = new Jogo()
#   cenas = {
#     telaInicial,
#     jogo
#   }
#   jogo.setup()
# ...

# %% [markdown]
# ## Sample 8
#
# **File path:**
#
# `ValeriVoev/p5ml5/sketch.js`
#
# **Label combination:**
#
# `processed_image + synthesized_image + synthesized_sound | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_image + synthesized_image + synthesized_sound`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_image",
#     "synthesized_sound"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ValeriVoev/p5ml5/sketch.js')
# Out:
# ```javascript
# // Initialize the Image Classifier method with MobileNet
# let classifier;
# let slider, button, colInput, talk;
# let p, sliderP, colorP;
#
# // When the model is loaded
# function modelLoaded() {
# 	console.log('Model Loaded!');
# }
#
# function gotFile(file) {
# 	let img = createImg(file.data, 'error loading image', function(){
# 		image(img, 0, 0, width, height);
# 	})
# 	img.hide();
# 	return img;
# }
#
# function predictImage(){
# 	let fileData = {
# 		data: c.canvas.toDataURL()
# 	}
# 	let img = gotFile(fileData);
# 	classifier.predict(img, function(err, results) {
# 		if (err) {
# 			console.log(err)
# 		}
# 		let label = results[0].className.split(",");
# 		let prob = round(results[0].probability*100);
# 		let textToDisplay = 'This is ' + label[0]+ '. I am about ' + prob + '% certain.';
# 		p.html(textToDisplay);
# 		talk.speak(textToDisplay);
# 	});
# }
#
# function mouseDragged(){
# 	noStroke();
# 	fill(colInput.value())
# ...

# %% [markdown]
# ## Sample 9
#
# **File path:**
#
# `hbcbh1999/ml4a.github.io/examples/classification-guitar/sketch.js`
#
# **Label combination:**
#
# `processed_audio + processed_image + synthesized_image | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('hbcbh1999/ml4a.github.io/examples/classification-guitar/sketch.js')
# Out:
# ```javascript
# // how many classes
# let numClasses = 6;
#
# let featureExtractor;
# let classifier;
# let video;
# let loss;
# let img;
# let numImages;
# let samples;
# let label;
# let buttons;
#
# function setup() {
#   createCanvas(500, 500);
#
#   img = loadImage("./assets/guitar.png");
#
#   samples = [];
#   samples[0] = loadSound('./assets/C.mp3')
#   samples[1] = loadSound('./assets/F.mp3')
#   samples[2] = loadSound('./assets/G.mp3')
#   samples[3] = loadSound('./assets/Am.mp3')
#   samples[4] = loadSound('./assets/Dm.mp3')
#   samples[5] = loadSound('./assets/Em.mp3')
#
#   label = 0;
#
#   numImages = Array(numClasses).fill(0);
#
#   video = createCapture(VIDEO);
#   video.parent('videoContainer');
#
#   featureExtractor = ml5.featureExtractor('MobileNet', modelReady);
#   featureExtractor.numClasses = numClasses;
#   classifier = featureExtractor.classification(video);
#
#   createButtons();
#
# }
#
# function modelReady() {
# ...

# %% [markdown]
# ## Sample 10
#
# **File path:**
#
# `jtallison/LSU-PDM-Spring-2021/SerialTop5_Setup/sketch.js`
#
# **Label combination:**
#
# `processed_audio + synthesized_image + synthesized_text | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + synthesized_image + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('jtallison/LSU-PDM-Spring-2021/SerialTop5_Setup/sketch.js')
# Out:
# ```javascript
# // Use with the AnalogReadSerial example
#
# // Declare a "SerialPort" object
#
# var serial;
# var latestData = 'waiting for data'; // you'll use this to write incoming data to the canvas
# const portName = '/dev/tty.usbmodem1424201'; // fill in your serial port name here
#
# function setup() {
# 	createCanvas(windowWidth, windowHeight);
#
# 	// Instantiate our SerialPort object
# 	serial = new p5.SerialPort();
#
# 	// Get a list the ports available
# 	// You should have a callback defined to see the results
# 	serial.list();
#
# 	// Assuming our Arduino is connected, let's open the connection to it
# 	// Change this to the name of your arduino's serial port
# 	serial.open(portName);
#
# 	// Here are the callbacks that you can register
#
# 	// When we connect to the underlying server
# 	serial.on('connected', serverConnected);
#
# 	// When we get a list of serial ports that are available
# 	serial.on('list', gotList);
# 	// OR
# 	//serial.onList(gotList);
#
# ...

# %% [markdown]
# ## Sample 11
#
# **File path:**
#
# `veitkal/draftSystem_UI/public/ui.js`
#
# **Label combination:**
#
# `none | interaction=yes | static + visual`
#
# **Entity combination:**
#
# `none`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('veitkal/draftSystem_UI/public/ui.js')
# Out:
# ```javascript
# /*
#  * Simple test p5js sketch sending UI and mouse parameters over websockets
#  * sliders are syncronized between connections
#  */
#
#
# let socket;
# let treadleSin1_slider;
# let treadleSin2_slider;
# let treadleNoise1_slider;
# let threadingSin1_slider;
# let threadingSin2_slider;
# let threadingNoise1_slider;
#
# let updateWarp_toggle = document.getElementById('update-warp_toggle');
# let updateWeft_toggle = document.getElementById('update-weft_toggle');
# // let updateWarp_toggle = select('#update-warp_toggle');
# // let updateWarp_state = 1;
#
# function setup() {
#   createCanvas(400, 40);
#   background(0);
#
#   ////socket on localhost
#   // socket = io.connect('http://localhost:3000');
#   // use 'io()' instead and it will automatically find connection
#   socket = io();
#
#   //WAVE ui
#   treadleSin1_slider = createSlider(0.0, 10.0, 3.3, 0.1);
#   treadleSin2_slider = createSlider(0.0, 100.0, 0.0, 0.1);
# ...

# %% [markdown]
# ## Sample 12
#
# **File path:**
#
# `Timgerr321/Coding/GIS Maar beter/sketch.js`
#
# **Label combination:**
#
# `processed_image + processed_text + synthesized_image | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_image + processed_text + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "processed_text",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Timgerr321/Coding/GIS Maar beter/sketch.js')
# Out:
# ```javascript
# let myMap;
# let row;
# // Create a variable to hold our canvas
# let canvas;
# // Create a new Mappa instance using Leaflet.
# const mappa = new Mappa('Leaflet');
#
# const options = {
#   lat: 52.126972,
#   lng: 6.229233,
#   zoom: 4,
#   style: "http://{s}.tile.osm.org/{z}/{x}/{y}.png"
# }
#
# // p5.js setup
# function setup() {
#   // Create a canvas 640x640
#   canvas = createCanvas(1000, 1000);
#   // Add a grey background
#   //background(100);
#
#   myMap = mappa.tileMap(options);
#   myMap.overlay(canvas);
#   myMap.onChange(drawPoint);
#   Subscribers = loadTable('country-capitals.csv', 'csv', 'header');
#   //console.log(Subscribers);
#     fill(70, 203, 31);
#   newtable = loadTable('add.csv', 'csv', 'header');
# }
# function add(){
#   //var xx = document.getElementById("frm1").value;
#   //var yy = document.getElementById("frm2").value;
#   //console.log(xx);
#   //console.log(yy);
#
#
# //  var newRow = newtable.addRow();
# ...

# %% [markdown]
# ## Sample 13
#
# **File path:**
#
# `ronavt/Calculator/sketch.js`
#
# **Label combination:**
#
# `none | interaction=yes | static + visual`
#
# **Entity combination:**
#
# `none`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('ronavt/Calculator/sketch.js')
# Out:
# ```javascript
# var input1
# var input2
# var data1,  data2
# var button
# var num1, num2
# var button2
# function setup() {
#   createCanvas(400, 400);
#   input1 = createInput()
#   input1.position(50,200);
#   input2 = createInput()
#   input2.position(100,300);
#   button = createButton("Add");
#   button.mousePressed(addition)
#   button.position(50,50)
#   button2 = createButton("Subtract");
#   button2.mousePressed(subtraction)
#   button2.position(150,50);
# }
#
# function draw() {
#   background(220);
#   data1 = input1.value()
#   data2 = input2.value()
#   num1 = parseInt(data1)
#   num2 = parseInt(data2)
# }
# function addition() {
#   console.log(num1+num2);
# }
# function subtraction() {
#   console.log(num1-num2);
# }
# ```

# %% [markdown]
# ## Sample 14
#
# **File path:**
#
# `patrickdolloso/CM1005/Game Project/FinalGameProject_PatrickDolloso/sketch.js`
#
# **Label combination:**
#
# `processed_audio + synthesized_image + synthesized_sound | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + synthesized_image + synthesized_sound`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_sound",
#     "synthesized_image",
#     "processed_audio"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/Game Project/FinalGameProject_PatrickDolloso/sketch.js')
# Out:
# ```javascript
# /* Final Game Project Submission
# University of London B.Sc. Computer Science (AI & ML)
# CM1005 Introduction to Programming I
# Date: Sep 9 2019
# Name: Patrick Dolloso
#
# ------------------------------------------
# Extensions
# ------------------------------------------
#
# --------------------
# 1. Add sound
# --------------------
# * your extension: the jump sound extension from game project 7 was added. The sound is triggered whenever the player hits the spacebar, but not when restarting the game
# * the bits you found difficult: placing the sound code in the correct line to trigger the sound correctly, and creading code that outputs once instead of a constant output, causing the sound to be triggered at 60x/second.
# * the skills you learnt/practised by implementing it: learned how to use assets and presets to load files such as sounds, images, etc. into a p5.js project.
#
# --------------------
# 2. Add Platforms
# --------------------
# ...

# %% [markdown]
# ## Sample 15
#
# **File path:**
#
# `patrickdolloso/CM1005/Sleuth_Pro/701/701-2-34949270-1382801/sketch.js`
#
# **Label combination:**
#
# `processed_image + randomness + synthesized_text | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + randomness + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/Sleuth_Pro/701/701-2-34949270-1382801/sketch.js')
# Out:
# ```javascript
# /*
#
# Officer: 1382801
# CaseNum: 701-2-34949270-1382801
#
# Case 701 - Recognisable robber - stage 3
#
# Kid you’re becoming a victim of your own success.
# I just had a call from DI Max down at the precinct. He specifically requested your services.
# They finally have a reliable witness for a robber who has been causing mayhem for some months.
# Luckily they have a witness statement from bridget zetland. You know what to do kid.
#
# Please create a function that takes a suspect object as parameter from the data structure below.
# Your function should return a number value indicating how many of their properties match the witness statement.
# You should use conditional statements to compare the suspect's properties to the statement.
#
# The function is already being called in draw() but it is your job to implement it.
#
# There are many possible ways of carrying out your duties,
# but you should complete this task using ONLY the following
# commands:
#
# ...

# %% [markdown]
# ## Sample 16
#
# **File path:**
#
# `saurabhsindhu96/ml4a.github.io/examples/facetrack-knn-sound/sketch.js`
#
# **Label combination:**
#
# `processed_audio + processed_image + randomness + synthesized_sound + synthesized_text | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + processed_image + randomness + synthesized_sound + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_image",
#     "processed_audio",
#     "synthesized_sound",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('saurabhsindhu96/ml4a.github.io/examples/facetrack-knn-sound/sketch.js')
# Out:
# ```javascript
# var k = 5; //k can be any integer
# var machine = new kNear(k);
#
# var currentClass = 0;
# var lastClass = 0;
#
# var capture;
# var tracker
# var w = 640;
#   h = 480;
#
# var test;
#
# var nSamples = 0;
#
# var normalized = [];
#
# var samples =[];
#
# var timeOut = false;
# var timeOutTimer = 0;
#
# function setup() {
#   capture = createCapture(VIDEO);
#   createCanvas(w, h);
#   capture.size(w, h);
#   capture.hide();
#
#   tracker = new clm.tracker();
#   tracker.init(pModel);
#   tracker.start(capture.elt);
#
# /*   for (var i = 0; i<=3; i++) {
#     samples [i] = loadSound('assets/' + i + '.wav')
#   }*/
#
#   samples [0] = loadSound('assets/C.mp3')
#   samples [1] = loadSound('assets/F.mp3')
#   samples [2] = loadSound('assets/G.mp3')
#   samples [3] = loadSound('assets/Am.mp3')
#   samples [4] = loadSound('assets/Dm.mp3')
#   samples [5] = loadSound('assets/Em.mp3')
#
#
#
# }
#
# function draw() {
#   //background(0);
#   image(capture, 0, 0, w, h);
# ...

# %% [markdown]
# ## Sample 17
#
# **File path:**
#
# `jcharry/ITP/artistComparator/sketch.js`
#
# **Label combination:**
#
# `processed_audio + randomness + synthesized_image + synthesized_text | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + randomness + synthesized_image + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('jcharry/ITP/artistComparator/sketch.js')
# Out:
# ```javascript
# // How diverse is this artist?
#
# // var apiKey = '0UXDG57YDSQ89NUEK';
# var baseURI = 'http://developer.echonest.com/api/v4/artist/search?api_key=0UXDG57YDSQ89NUEK';
#
# var response;
# var input;
# var mappedAudioParams = [];
# var bs = [];
# var currentData;
# var songs = [];
#
# var c;
#
# var legendButton;
# var shouldShowLegend = false;
# var legendCloseButton;
#
# var artists = [];
#
# function setup() {
#   angleMode(DEGREES);
#
#   lastSearch = {
#     name: '',
#     values: []
#   }
#   currentSearch = {
#     name: '',
#     values: []
#   }
#
#   // Canvas used for drawing visualization
#   c = createCanvas(windowWidth, windowHeight);
#   // print(windowHeight);
#   c.translate(windowWidth / 2, windowHeight / 2);
#   // c.position(220, 0);
#
#   var p = createP("Search for an artist");
#   p.position(11, 3);
#   p.style('margin', '0px 0px 0px 0px');
#   p.style('color', 'white');
#   p.style('font-family', 'Futura');
#   p.style('font-size', '16pt');
# ...

# %% [markdown]
# ## Sample 18
#
# **File path:**
#
# `patrickdolloso/CM1005/Sleuth_Pro/502/502-1-93379768-1382801/sketch.js`
#
# **Label combination:**
#
# `processed_image + processed_text + synthesized_text | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_image + processed_text + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "processed_image"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/Sleuth_Pro/502/502-1-93379768-1382801/sketch.js')
# Out:
# ```javascript
# /*
#
# Officer: 1382801
# CaseNum: 502-1-93379768-1382801
#
# Case 502 - A delicate matter - stage 2
#
# We’re hot on the trail kid, and another document has come my way.
# It’s a little more tricky to decipher but I know you can do it.
#
# In setup, fill in the redactedText String variable by replacing the redacted words
# with references to the two arrays containing the missing pieces.
# you can do this by indexing the appropriate items from the respective arrays.
#
# There are many possible ways of completing this task,
# but you should ONLY use the following commands:
#
# " + Array[index].property + "
#
# */
#
# // you dont need to change these
# var missingWords;
# var redactedText;
#
# // arrays containing the names needed to fill in the paragraph
# var A_Excerpt = [
# 	{Fragment_0: "stuff", Fragment_1: "radiate", Fragment_2: "mend"},
# 	{Fragment_0: "smile", Fragment_1: "smile", Fragment_2: "protect"},
# ...

# %% [markdown]
# ## Sample 19
#
# **File path:**
#
# `JENkt4k/p5.serialport/examples/makePortMenu/sketch.js`
#
# **Label combination:**
#
# `processed_audio | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_audio`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('JENkt4k/p5.serialport/examples/makePortMenu/sketch.js')
# Out:
# ```javascript
# /*
#
# Serial list ports
#
# Lists serial ports in an options menu. When you choose one, opens the port
# and displays any incoming strings as text onscreen.
#
# Works with P5 editor as the serial server, version 0.5.5 or later.
#
# created 2 Oct 2015
# by Tom Igoe
# */
#
# let serial; // Declare a "SerialPort" object
# let menu;
# let result = '';
#
# function setup() {
#   createCanvas(400, 300); // window size
#   serial = new p5.SerialPort();
#   serial.list();
#   serial.on('list', printList);
#   serial.on('data', printData);
# }
#
#
# function draw() {
#   background(255);
#   fill(0);
#   text(result, 10, 60);
# }
#
# function openPort() {
#   portName = menu.elt.value;
#   serial.open(portName);
# }
#
# function printData() {
#   let inString = serial.readStringUntil('\r\n');
#   trim(inString);
#   if (!inString) return;
#   result = inString;
# }
#
# // Got the list of ports
# function printList(serialList) {
#   menu = createSelect();
# ...

# %% [markdown]
# ## Sample 20
#
# **File path:**
#
# `Aaron033/NodeListapp/website/empty-example/sketch.js`
#
# **Label combination:**
#
# `processed_text | interaction=no | static + visual`
#
# **Entity combination:**
#
# `processed_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text"
#   ],
#   "interaction": [
#     "no"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Aaron033/NodeListapp/website/empty-example/sketch.js')
# Out:
# ```javascript
# function setup() {
#  createCanvas(400, 400);
#     background(51);
#     loadJSON('../all', gotData);
#     console.log('Running');
# }
#
# function gotData(data){
#     console.log(data);
# }
#
#
#
# ```

# %% [markdown]
# ## Sample 21
#
# **File path:**
#
# `PazosAndrew/meme/p5/addons/p5.serialport-master/examples/echo/sketch.js`
#
# **Label combination:**
#
# `processed_audio | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_audio`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('PazosAndrew/meme/p5/addons/p5.serialport-master/examples/echo/sketch.js')
# Out:
# ```javascript
# var serial; // variable to hold an instance of the serialport library
# var portName = '/dev/cu.usbmodem14131'; // fill in your serial port name here
# var inData; // for incoming serial data
#
# function setup() {
#   createCanvas(400, 300);
#   serial = new p5.SerialPort(); // make a new instance of the serialport library
#   serial.on('data', serialEvent); // callback for when new data arrives
#   serial.on('error', serialError); // callback for errors
#
#   serial.open(portName); // open a serial port
#   serial.clear();
# }
#
# function draw() {
#   // black background, white text:
#   background(0);
#   fill(255);
#   // display the incoming serial data as a string:
#   text("incoming value: " + inData, 30, 30);
# }
#
# function keyTyped() {
#     var outByte = key;
#     console.log("Sending " + outByte);
#     //serial.write(Number(outByte)); // Send as byte value
#     serial.write(outByte); // Send as a string/char/ascii value
# }
#
# ...

# %% [markdown]
# ## Sample 22
#
# **File path:**
#
# `saurabhsindhu96/ml4a.github.io/examples/classification-guitar/sketch.js`
#
# **Label combination:**
#
# `processed_audio + processed_image + synthesized_image | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + processed_image + synthesized_image`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "processed_image",
#     "synthesized_image"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('saurabhsindhu96/ml4a.github.io/examples/classification-guitar/sketch.js')
# Out:
# ```javascript
# // how many classes
# let numClasses = 6;
#
# let featureExtractor;
# let classifier;
# let video;
# let loss;
# let img;
# let numImages;
# let samples;
# let label;
# let buttons;
#
# function setup() {
#   createCanvas(500, 500);
#
#   img = loadImage("./assets/guitar.png");
#
#   samples = [];
#   samples[0] = loadSound('./assets/C.mp3')
#   samples[1] = loadSound('./assets/F.mp3')
#   samples[2] = loadSound('./assets/G.mp3')
#   samples[3] = loadSound('./assets/Am.mp3')
#   samples[4] = loadSound('./assets/Dm.mp3')
#   samples[5] = loadSound('./assets/Em.mp3')
#
#   label = 0;
#
#   numImages = Array(numClasses).fill(0);
#
#   video = createCapture(VIDEO);
#   video.parent('videoContainer');
#
#   featureExtractor = ml5.featureExtractor('MobileNet', modelReady);
#   featureExtractor.numClasses = numClasses;
#   classifier = featureExtractor.classification(video);
#
#   createButtons();
#
# }
#
# function modelReady() {
# ...

# %% [markdown]
# ## Sample 23
#
# **File path:**
#
# `Dev102a/Class13/Pro-c13-TA1_template-main/Pro-c13-TA1_template-main/sketch.js`
#
# **Label combination:**
#
# `synthesized_text | interaction=yes | static + visual`
#
# **Entity combination:**
#
# `synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "static"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('Dev102a/Class13/Pro-c13-TA1_template-main/Pro-c13-TA1_template-main/sketch.js')
# Out:
# ```javascript
# var input,heading;
#
#
# function setup()
# {
#   createCanvas(400, 400);
#   background(178,255,102);
#  input = createInput()
#  input.position(5,60)
#  heading = createElement("h4","enter any alphabet")
#  heading.position(5,20)
#  textAlign (CENTER)
#  textSize(50)
# }
#
# function draw() {
#
#   const ch = input.value()
#   switch(ch){
#     case 'a':
#     console.log("vowel")
#     break;
#
#     case 'e':
#     console.log("vowel")
#     break;
#
#     case 'i':
#     console.log("vowel")
#     break;
#
#     case 'o':
#     console.log("vowel")
#     break;
#
#     case 'u' :
#     console.log("vowel")
#     break;
#
#     default:
#     console.log("not a vowel")
#     break;
#   }
# }
#
#
# ```

# %% [markdown]
# ## Sample 24
#
# **File path:**
#
# `magilla121/magilla121.github.io/sketch.js`
#
# **Label combination:**
#
# `processed_audio + randomness + synthesized_image + synthesized_text | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + randomness + synthesized_image + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('magilla121/magilla121.github.io/sketch.js')
# Out:
# ```javascript
# var gameReady = false;
# var timer = 5;
# var load = 0.5;//adjusts the starting health of the bots and the damage they do each hit
# var startHealth = 600;
# var damage = 30;
# //bot1 properties and functions
# var bot1 = {
#   xPos:50,
#   yPos:50,
#   score:0,
#   barColor:"red",
#   health:startHealth,
#   alive:true,
#   healthBar:function(){
#     if(this.health <= 0){
#       this.alive = false;
#       end("Red Bot");
#     } else {
#       this.alive = true;
#     }
#     if(this.alive == true){
#     fill(this.barColor);
#     rect(this.xPos + 220, this.yPos - 25, this.health, 30);
#   } else{
#     fill("red");
#     text("DEAD", this.xPos + 250, this.yPos);
#   }
#   }
# }
# //bot2 properties and functions
# var bot2 = {
#   xPos:50,
#   yPos:100,
#   score:0,
#   barColor:"red",
#   health:startHealth,
#   alive:true,
#   healthBar:function(){
#     if(this.health <= 0){
#       this.alive = false;
#       end("Blue Bot");
#     } else{
# ...

# %% [markdown]
# ## Sample 25
#
# **File path:**
#
# `gaovicky/CupcakeMaker/p5/midterm/sketch.js`
#
# **Label combination:**
#
# `processed_audio + randomness + synthesized_image + synthesized_text | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + randomness + synthesized_image + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('gaovicky/CupcakeMaker/p5/midterm/sketch.js')
# Out:
# ```javascript
# var ding;
# var button; // button will "bake" a cupcake
# var pos = 0; // starting position
# var frosting = [
#   [255, 155, 220], //strawberry
#   [130, 144, 255], //blueberry
#   [73, 39, 25], // chocolate
#   [247, 241, 226], //vanilla
#   [255, 230, 156] //banana
# ]; // frosting color
# var cakeColor = [
#   [70, 44, 33], // chocolate
#   [242, 222, 198], // vanilla
#   [255, 253, 182], //lemon
#   [254, 191, 149], //carrot
#   [243, 99, 99] //red velvet
# ]; // cake color
# var cupcakeName = [
#   "Strawberry Chocolate",
#   "Blueberry Vanilla",
#   "Chocolate Lemon",
#   "Vanilla Carrot",
#   "Banana Red Velvet"
# ];
# var bakeryText = {
#   message: "Sweet Delights",
#   display: function(x,y) {
#     fill(255, 162, 162); //pink
#     textSize(70);
#     textStyle(BOLD);
#     text(this.message, x, y);
#   }
# }
# var oven = {
#   w: 400,
#   h: 460,
#   display: function() {
#     translate(300,340);
#     stroke(151, 121, 204); // purple
# ...

# %% [markdown]
# ## Sample 26
#
# **File path:**
#
# `FOUTRE14/GAY/sketch.js`
#
# **Label combination:**
#
# `randomness + synthesized_sound + synthesized_text | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `randomness + synthesized_sound + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_sound",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "auditory",
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('FOUTRE14/GAY/sketch.js')
# Out:
# ```javascript
# let gridSpacing = 40
#
# let poly;
# let delay;
# let reverb;
#
# let notes = ["C","D","E","G"]
# // let notes = ["C","D","E","G","A"]
#
# let octave = 4
# let direction = 1
#
# let W = window.innerWidth
# let H = window.innerHeight
# function setup() {
#
#
#   poly = new p5.PolySynth();
#
#   delay = new p5.Delay();
#   reverb = new p5.Reverb();
#
#   reverb.process(poly, 2, 2); //to only add reverb, toggle the others off.
#   // delay.process(poly, 0.50, 0.5, 2300);
#   // reverb.process(delay, 4, 2);
#
# let i = 0;
# let cts = ['u','⬜️', 'a', 'r',' e', '⬜️', 'g','a','y']
# let cases = ['🟥', '🟧', '🟨', '🟩', '🟦', '🟪'];
#
# for (let y = 0; y < H - (gridSpacing * 2); y += gridSpacing) {
#   for (let x = gridSpacing; x < W - gridSpacing; x += gridSpacing) {
#
#
#       let p
#
#       if(window.chrome){
#         if(i > cts.length-1){
#           p = createP(cases[Math.floor(Math.random() * cases.length)]);
#         }else{
#           p = createP(cts[i]);
# ...

# %% [markdown]
# ## Sample 27
#
# **File path:**
#
# `brhui/Challenge2_Wang_Hui/Challenge2/sketch.js`
#
# **Label combination:**
#
# `processed_text + randomness + synthesized_image + synthesized_text | interaction=yes | time_based + visual`
#
# **Entity combination:**
#
# `processed_text + randomness + synthesized_image + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_text",
#     "synthesized_text",
#     "synthesized_image",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('brhui/Challenge2_Wang_Hui/Challenge2/sketch.js')
# Out:
# ```javascript
# var draculaText;
# var joined;
# var story;
# var parsedText;
#
# var begin, end;
#
# var font;
# var fontsize = 20;
#
# var draculaIMG, britain;
#
# var helsinggrow = 0;
# var draculagrow = 0;
#
# function preload() {
#   draculaText = loadStrings('content/dracula.txt');
#   font = loadFont('content/font.ttf');
#   britain = loadImage('content/britain.png');
#   draculaIMG = loadImage('content/dracula.png');
# }
#
# function setup() {
#   createCanvas(1000, 700);
#   background(255);
#   textFont(font, fontsize);
#   noStroke();
# }
#
# function draw() {
#
#   joined = join(draculaText, " ");
#   begin = joined.indexOf("_3 May. Bistritz.");
#   end = joined.lastIndexOf("THE END");
#
#   story = joined.substring(begin, end);
#
#   var dracula = story.search(/Dracula/gi);
#   // console.log(dracula);
#
#   var storystring = story.substr(1231, 11);
#   // console.log(storystring);
#
#   var letter = story.charAt(1941);
#   // console.log(letter);
#
# ...

# %% [markdown]
# ## Sample 28
#
# **File path:**
#
# `zachkrall/mfadt-5in5/01/sketch.js`
#
# **Label combination:**
#
# `processed_audio + synthesized_text | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_text",
#     "processed_audio"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('zachkrall/mfadt-5in5/01/sketch.js')
# Out:
# ```javascript
# var myRec = new p5.SpeechRec();
# myRec.continuous = true;
#
# var myString = '';
# var buffer = 20;
#
# function clr(){
#
# 	myString = '';
# 	console.log( 'clr()' );
#
# }
#
# function setup(){
#
# 	createCanvas(windowWidth, windowHeight);
#
# 	textSize(50);
# 	textFont('Menlo');
#
# 	myRec.onResult = showResult;
# 	myRec.start();
#
# }
#
# function draw(){
#
#     background(0, 0, 255);
#
#     fill(0);
#     text(myString.toUpperCase(), 0+buffer-5, 0+buffer+5, width-buffer*2, height-buffer*2);
#
#     fill(255);
#     noStroke();
#     strokeCap(PROJECT);
#     textStyle(BOLD);
#
#     textAlign(CENTER, CENTER);
#     text(myString.toUpperCase(), 0+buffer, 0+buffer, width-buffer*2, height-buffer*2);
#
# }
#
# function showResult(){
#
#     if(myRec.resultString == 'clear'){
# 	    clr();
#     } else if(myRec.resultValue==true) {
#       myString = myString + ' ' + myRec.resultString;
# 			console.log(myRec.resultString);
# 		}
#
# }
#
# function windowResized(){
# ...

# %% [markdown]
# ## Sample 29
#
# **File path:**
#
# `localcrafts101/ATK302/p5/joke1/sketch.js`
#
# **Label combination:**
#
# `processed_audio + randomness + synthesized_image + synthesized_text | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `processed_audio + randomness + synthesized_image + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "processed_audio",
#     "synthesized_image",
#     "synthesized_text",
#     "randomness"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('localcrafts101/ATK302/p5/joke1/sketch.js')
# Out:
# ```javascript
# var mic;
# var vol;
# var y = 0;
# var myState = 0;
#
# function setup() {
#   createCanvas(1920, 1080);
#
#   mic = new p5.AudioIn();
#   mic.start();
# }
#
# function draw() {
#   console.log("hello");
#   switch (myState) {
#     case 0:
#       background(100);
#
#       ellipse(200, y, 100, 100);
#       vol = mic.getLevel(); // level is between 0 and 1
#       vol = vol * 100; // you may need to change this
#
#       if (vol > 5) {
#         // do something
#         y++;
#       }
#       if (y > 1080) {
#         background(255, 0, 0);
#       }
#
#       textSize(18);
#       text("knock. knock... " + vol, 80, 400);
#       break;
#
#     case 1:
#     background(100);
#
#     ellipse(200, y, 100, 100);
#     vol = mic.getLevel(); // level is between 0 and 1
#     vol = vol * 100; // you may need to change this
#
#     if (vol > 5) {
#       // do something
#       y++;
#     }
#     if (y > 1080) {
#       background(255, 0, 0);
#     }
#
# ...

# %% [markdown]
# ## Sample 30
#
# **File path:**
#
# `patrickdolloso/CM1005/Game Project/sound_template/sound_template/sketch.js`
#
# **Label combination:**
#
# `synthesized_image + synthesized_sound + synthesized_text | interaction=yes | auditory + time_based + visual`
#
# **Entity combination:**
#
# `synthesized_image + synthesized_sound + synthesized_text`
#
# **Predicted labels:**
#
# ```json
# {
#   "entities": [
#     "synthesized_sound",
#     "synthesized_image",
#     "synthesized_text"
#   ],
#   "interaction": [
#     "yes"
#   ],
#   "outcome": [
#     "visual",
#     "auditory",
#     "time_based"
#   ]
# }
# ```
#
# ### Manual notes

# %%
print_code_file('patrickdolloso/CM1005/Game Project/sound_template/sound_template/sketch.js')
# Out:
# ```javascript
# /* Final Game Project Submission
# University of London B.Sc. Computer Science (AI & ML)
# CM1005 Introduction to Programming I
# Date: Sep 9 2019
# Name: Patrick Dolloso
#
# ------------------------------------------
# Extensions
# ------------------------------------------
#
# --------------------
# 1. Add sound
# --------------------
# * your extension: the jump sound extension from game project 7 was added. The sound is triggered whenever the player hits the spacebar, but not when restarting the game
# * the bits you found difficult: placing the sound code in the correct line to trigger the sound correctly, and creading code that outputs once instead of a constant output, causing the sound to be triggered at 60x/second.
# * the skills you learnt/practised by implementing it: learned how to use assets and presets to load files such as sounds, images, etc. into a p5.js project.
#
# --------------------
# 2. Add Platforms
# --------------------
# ...
