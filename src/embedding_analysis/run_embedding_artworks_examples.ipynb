# %% [markdown]
# # Embed artworks

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import numpy as np
from pathlib import Path
from vllm import LLM
from tqdm.auto import tqdm
import json
import re


MODEL_PATH = "../../../links/projects/def-baudry/shared/huggingface/models--Qwen--Qwen3-Embedding-8B/snapshots/1d8ad4ca9b3dd8059ad90a75d4983776a23d44af"
MODEL_PATH = str(Path(MODEL_PATH).resolve())

print("Model exists:", Path(MODEL_PATH).exists())
print("Model path:", MODEL_PATH)

llm = LLM(
    model=MODEL_PATH,
    runner="pooling",
    convert="embed",
    dtype="bfloat16",
    model_impl="transformers",
    max_model_len=8192,
)
# Out:
# INFO 05-16 09:24:23 [importing.py:44] Triton is installed but 0 active driver(s) found (expected 1). Disabling Triton to prevent runtime errors.
# INFO 05-16 09:24:23 [importing.py:68] Triton not installed or not compatible; certain GPU-related functions will not be available.
# Model exists: True
# Model path: /lustre09/project/6097821/shared/huggingface/models--Qwen--Qwen3-Embedding-8B/snapshots/1d8ad4ca9b3dd8059ad90a75d4983776a23d44af
# INFO 05-16 09:24:26 [utils.py:223] non-default args: {'runner': 'pooling', 'convert': 'embed', 'dtype': 'bfloat16', 'max_model_len': 8192, 'disable_log_stats': True, 'model_impl': 'transformers', 'model': '/lustre09/project/6097821/shared/huggingface/models--Qwen--Qwen3-Embedding-8B/snapshots/1d8ad4ca9b3dd8059ad90a75d4983776a23d44af'}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 19
#      16 print("Model exists:", Path(MODEL_PATH).exists())
#      17 print("Model path:", MODEL_PATH)
# ---> 19 llm = LLM(
#      20     model=MODEL_PATH,
#      21     runner="pooling",
#      22     convert="embed",
#      23     dtype="bfloat16",
#      24     model_impl="transformers",
#      25     max_model_len=8192,
#      26 )
#
# File ~/art-in-swh/.venv/lib/python3.11/site-packages/vllm/entrypoints/llm.py:346, in LLM.__init__(self, model, runner, convert, tokenizer, tokenizer_mode, skip_tokenizer_init, trust_remote_code, allowed_local_media_path, allowed_media_domains, tensor_parallel_size, dtype, quantization, revision, tokenizer_revision, seed, gpu_memory_utilization, swap_space, cpu_offload_gb, enforce_eager, enable_return_routed_experts, disable_custom_all_reduce, hf_token, hf_overrides, mm_processor_kwargs, pooler_config, structured_outputs_config, profiler_config, attention_config, kv_cache_memory_bytes, compilation_config, logits_processors, **kwargs)
#     309 engine_args = EngineArgs(
#     310     model=model,
#     311     runner=runner,
#    (...)    341     **kwargs,
#     342 )
#     344 log_non_default_args(engine_args)
# --> 346 self.llm_engine = LLMEngine.from_engine_args(
#     347     engine_args=engine_args, usage_context=UsageContext.LLM_CLASS
#     348 )
#     349 self.engine_class = type(self.llm_engine)
#     351 self.request_counter = Counter()
#
# File ~/art-in-swh/.venv/lib/python3.11/site-packages/vllm/v1/engine/llm_engine.py:166, in LLMEngine.from_engine_args(cls, engine_args, usage_context, stat_loggers, enable_multiprocessing)
#     163 """Creates an LLM engine from the engine arguments."""
#     165 # Create the engine configs.
# --> 166 vllm_config = engine_args.create_engine_config(usage_context)
#     167 executor_class = Executor.get_class(vllm_config)
#     169 if envs.VLLM_ENABLE_V1_MULTIPROCESSING:
#
# File ~/art-in-swh/.venv/lib/python3.11/site-packages/vllm/engine/arg_utils.py:1392, in EngineArgs.create_engine_config(self, usage_context, headless)
#    1385 """
#    1386 Create the VllmConfig.
#    1387
#    1388 NOTE: If VllmConfig is incompatible, we raise an error.
#    1389 """
#    1390 current_platform.pre_register_and_update()
# -> 1392 device_config = DeviceConfig(device=cast(Device, current_platform.device_type))
#    1394 # Check if the model is a speculator and override model/tokenizer/config
#    1395 # BEFORE creating ModelConfig, so the config is created with the target model
#    1396 # Skip speculator detection for cloud storage models (eg: S3, GCS) since
#    1397 # HuggingFace cannot load configs directly from S3 URLs. S3 models can still
#    1398 # use speculators with explicit --speculative-config.
#    1399 if not is_cloud_storage(self.model):
#
#     [... skipping hidden 1 frame]
#
# File ~/art-in-swh/.venv/lib/python3.11/site-packages/vllm/config/device.py:73, in DeviceConfig.__post_init__(self)
#      70     self.device = None
#      71 else:
#      72     # Set device with device type
# ---> 73     self.device = torch.device(self.device_type)
#
# RuntimeError: Device string must not be empty

# %%
with open("../../artworks/prompt_10_20260413/successes.txt") as f:
    artwork_paths = f.read().splitlines()

# %%
embeddings_path = Path("artwork_embeddings.npy")
paths_path = Path("artwork_paths.json")

if embeddings_path.exists() and paths_path.exists():
    embeddings = np.load(embeddings_path)
    print("Loaded embeddings:", embeddings.shape)

else:
    embeddings = []

    for artwork in tqdm(artwork_paths, desc="Embedding artworks"):
        text = Path(artwork).read_text(encoding="utf-8")

        output = llm.embed(
            [text],
            truncate_prompt_tokens=8192,
            use_tqdm=False,
        )[0]

        embeddings.append(output.outputs.embedding)

    embeddings = np.array(embeddings, dtype=np.float32)

    np.save(embeddings_path, embeddings)

    with open(paths_path, "w", encoding="utf-8") as f:
        json.dump([str(path) for path in artwork_paths], f, indent=2)

    print("Saved embeddings:", embeddings.shape)
# Out:
# Loaded embeddings: (19727, 4096)

# %% [markdown]
# ## Find similar embeddings

# %% [markdown]
# Can we use the embeddings to find similar files?

# %%
from pathlib import Path
import json
import numpy as np
import time

class EmbeddingSearch:
    def __init__(
        self,
        embeddings_path="artwork_embeddings.npy",
        paths_path="artwork_paths.json",
    ):
        self.embeddings = np.load(embeddings_path).astype(np.float32)

        with open(paths_path, "r", encoding="utf-8") as f:
            self.paths = json.load(f)

        # Normalize once for cosine similarity
        norms = np.linalg.norm(self.embeddings, axis=1, keepdims=True)
        self.embeddings = self.embeddings / np.maximum(norms, 1e-12)

        # Precompute path -> index lookup
        self.path_to_idx = {
            str(Path(path).resolve()): idx
            for idx, path in enumerate(self.paths)
        }

    def get_all_similarities_by_path(self, query_file_path, include_self=False):
        query_resolved = str(Path(query_file_path).resolve())

        if query_resolved not in self.path_to_idx:
            raise ValueError(f"File not found in index: {query_file_path}")

        query_idx = self.path_to_idx[query_resolved]
        query_embedding = self.embeddings[query_idx]

        # Similarity against every vector
        scores = self.embeddings @ query_embedding

        results = []

        for idx, score in enumerate(scores):
            if not include_self and idx == query_idx:
                continue

            results.append({
                "path": self.paths[idx],
                "score": float(score),
            })

        return results

    @staticmethod
    def top_k(results, k=10):
        return sorted(
            results,
            key=lambda x: x["score"],
            reverse=True,
        )[:k]

# %%
with open("../artworks/prompt_10_20260413/successes.txt") as f:
    artwork_paths = f.read().splitlines()

searcher = EmbeddingSearch(
    embeddings_path="artwork_embeddings.npy",
    paths_path="artwork_paths.json",
)

start = time.perf_counter()
all_results = searcher.get_all_similarities_by_path(
    query_file_path=artwork_paths[0],
    include_self=False,
)

# %%
with open("../../artworks/prompt_10_20260413/successes.txt") as f:
    artwork_paths = f.read().splitlines()

searcher = EmbeddingSearch(
    embeddings_path="artwork_embeddings.npy",
    paths_path="artwork_paths.json",
)

start = time.perf_counter()
all_results = searcher.get_all_similarities_by_path(
    query_file_path=artwork_paths[0],
    include_self=False,
)

topk = 10

top_results = searcher.top_k(all_results, k=topk)

for result in top_results:
    print(f"{result['score']:.4f} - {result['path']}")

elapsed = time.perf_counter() - start

print(f"Total time: {elapsed:.4f}s")
# Out:
# 1.0000 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/usmanCodesjs/project15/sketch.js
# 1.0000 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/ZishannBro/c-19-TreasureHunt/sketch.js
# 1.0000 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/VANSHULABROL/PROJECT15/sketch.js
# 1.0000 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Pencil12/Project_15/sketch.js
# 0.9999 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/RaghavMathur639/Project-15/sketch.js
# 0.9998 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/ZayOnyxLink/Class15Project/sketch.js
# 0.9998 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/jejthenoob/project-15/sketch.js
# 0.9998 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Titanaboa596/COLLECTING-TREASURE-/Project-Template-C15-main/Project-Template-C15-main/sketch.js
# 0.9998 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/zapatron655/proj-15-2-/sketch.js
# 0.9997 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Anant1782009/c15/sketch.js
# Total time: 0.0312s

# %% [markdown]
# So here we see that some files have a score of 1.0000 -> strong signal of duplication

# %% [markdown]
# ### Plot the unique similarity scores

# %% [markdown]
# Now, how similar the other files are to this example? Plotting the unique similarity score.

# %%
import numpy as np
import matplotlib.pyplot as plt

# all_results should be the full list returned by:
# all_results = searcher.get_all_similarities_by_path(...)

scores = np.array([result["score"] for result in all_results], dtype=np.float32)

# Distinct score values
distinct_scores = np.unique(scores)

# Sort for easier visualization
distinct_scores = np.sort(distinct_scores)

plt.figure(figsize=(10, 5))
plt.scatter(
    np.arange(len(distinct_scores)),
    distinct_scores,
    s=8,
)

plt.xlabel("Distinct score index")
plt.ylabel("Cosine similarity score")
plt.title("Distinct similarity scores")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# It looks like there's a "cluster" of similar files

# %%
def top_k_below_threshold(all_results, threshold, k=10):
    filtered = [
        result
        for result in all_results
        if result["score"] < threshold
    ]

    filtered = sorted(
        filtered,
        key=lambda x: x["score"],
        reverse=True,
    )

    return filtered[:k]

threshold = 0.917
k = 10

top_results = top_k_below_threshold(
    all_results=all_results,
    threshold=threshold,
    k=k,
)

for result in top_results:
    print(f"{result['score']:.4f} - {result['path']}")
# Out:
# 0.9160 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/NaeN4e/PRO-C18-JOGO-COMPAT-VEL-COM-DISPOSITIVOS/PRO-V2-C18-Modelo-main/sketch.js
# 0.9159 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Jaime346/89/Recolectar-tesoros-2-plantilla-main/sketch.js
# 0.9146 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Piolivi/Projeto20/sketch.js
# 0.9088 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/aoas2009/Project-C-22/sketch.js
# 0.8599 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/pranathi777/project-48/sketch.js
# 0.8569 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/25Hasini25/car-and-pin/car and pin/Project_Template_C19_Your-Own-Infinite-Runner-Game-main/sketch.js
# 0.8421 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Atulyaskywalker/jaxon-2/sketch.js
# 0.8311 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/ShyamjiGupta2021/Inffinite-game-Runner/sketch.js
# 0.8276 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/mer482006/ACA-33-Iron-Man-Level-3/sketch.js
# 0.8217 - /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Jiya-Shah/copandthief/cop and theif/sketch.js

# %% [markdown]
# ## T-SNE

# %%
from pathlib import Path

import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

tsne_path = Path("artwork_embeddings_tsne_2d.npy")

if tsne_path.exists():
    embeddings_2d = np.load(tsne_path).astype(np.float32)
    print("Loaded existing t-SNE embeddings:", embeddings_2d.shape)

else:
    # Load embeddings
    embeddings = np.load("artwork_embeddings.npy").astype(np.float32)

    # Normalize
    embeddings = embeddings / np.maximum(
        np.linalg.norm(embeddings, axis=1, keepdims=True),
        1e-12,
    )

    # Recommended before t-SNE since embeddings are huge
    pca = PCA(n_components=50, random_state=42)
    embeddings_50d = pca.fit_transform(embeddings)

    # Run t-SNE
    tsne = TSNE(
        n_components=2,
        perplexity=30,
        learning_rate="auto",
        init="pca",
        max_iter=1000,
        random_state=42,
        verbose=1,
    )

    embeddings_2d = tsne.fit_transform(embeddings_50d)

    # Save result
    np.save(tsne_path, embeddings_2d)
    print("Saved t-SNE embeddings:", embeddings_2d.shape)
# Out:
# Loaded existing t-SNE embeddings: (19727, 2)

# %%
# Plot
plt.figure(figsize=(12, 10))
plt.scatter(
    embeddings_2d[:, 0],
    embeddings_2d[:, 1],
    s=5,
    alpha=0.7,
)
###
plt.scatter(
    99.498207,
    20.30489,
    s=150,
    marker="o",
    linewidths=3,
    alpha=0.4,
    label="Custom point",
)

####
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title("t-SNE projection of artwork embeddings")
plt.show()

# %% [markdown]
# Orange circle is the reference file from above

# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
import plotly.express as px


TSNE_PATH = "artwork_embeddings_tsne_2d.npy"
PATHS_PATH = "artwork_paths.json"
PREDICTIONS_PATH = "../artworks/prompt_10_20260413/predictions.json"


def normalize_path(path):
    return str(Path(path).resolve())


def load_predictions(predictions_path):
    with open(predictions_path, "r", encoding="utf-8") as f:
        predictions = json.load(f)

    rows = []

    for item in predictions:
        file_path = item["file_path"]
        labels = item["predicted_labels"]

        entities = labels.get("entities", [])
        interaction = labels.get("interaction", [])
        outcome = labels.get("outcome", [])

        label_combination = (
            f"entities={'+'.join(entities)} | "
            f"interaction={'+'.join(interaction)} | "
            f"outcome={'+'.join(outcome)}"
        )

        rows.append({
            "file_path": file_path,
            "file_path_resolved": normalize_path(file_path),
            "entities": ", ".join(entities),
            "interaction": ", ".join(interaction),
            "outcome": ", ".join(outcome),
            "label_combination": label_combination,
        })

    return pd.DataFrame(rows)


# Load t-SNE coordinates
tsne_2d = np.load(TSNE_PATH)

# Load paths matching the embedding order
with open(PATHS_PATH, "r", encoding="utf-8") as f:
    artwork_paths = json.load(f)

tsne_df = pd.DataFrame({
    "file_path": artwork_paths,
    "file_path_resolved": [normalize_path(path) for path in artwork_paths],
    "tsne_x": tsne_2d[:, 0],
    "tsne_y": tsne_2d[:, 1],
})

# Load predictions
predictions_df = load_predictions(PREDICTIONS_PATH)

# Merge t-SNE with labels
plot_df = tsne_df.merge(
    predictions_df.drop(columns=["file_path"]),
    on="file_path_resolved",
    how="left",
)

# Fill missing predictions
plot_df["label_combination"] = plot_df["label_combination"].fillna("missing_prediction")
plot_df["entities"] = plot_df["entities"].fillna("")
plot_df["interaction"] = plot_df["interaction"].fillna("")
plot_df["outcome"] = plot_df["outcome"].fillna("")

plot_df.head()
# Out:
#                                            file_path  \
# 0  /home/rpinter/links/projects/def-baudry/shared...
# 1  /home/rpinter/links/projects/def-baudry/shared...
# 2  /home/rpinter/links/projects/def-baudry/shared...
# 3  /home/rpinter/links/projects/def-baudry/shared...
# 4  /home/rpinter/links/projects/def-baudry/shared...
#
#                                   file_path_resolved     tsne_x     tsne_y  \
# 0  /lustre09/project/6097821/shared/data/artworks...  99.496223  20.299402
# 1  /lustre09/project/6097821/shared/data/artworks...  67.913330   3.330680
# 2  /lustre09/project/6097821/shared/data/artworks...  85.886154 -18.496237
# 3  /lustre09/project/6097821/shared/data/artworks...  76.783798  24.785658
# 4  /lustre09/project/6097821/shared/data/artworks...  63.717262 -20.759743
#
#                                             entities interaction  \
# 0     processed_image, synthesized_image, randomness         yes
# 1  processed_audio, processed_image, synthesized_...         yes
# 2     processed_image, synthesized_image, randomness         yes
# 3  processed_image, synthesized_image, synthesize...         yes
# 4     processed_image, synthesized_image, randomness         yes
#
#                         outcome  \
# 0            visual, time_based
# 1  visual, auditory, time_based
# 2            visual, time_based
# 3  visual, auditory, time_based
# 4            visual, time_based
#
#                                    label_combination
# 0  entities=processed_image+synthesized_image+ran...
# 1  entities=processed_audio+processed_image+synth...
# 2  entities=processed_image+synthesized_image+ran...
# 3  entities=processed_image+synthesized_image+syn...
# 4  entities=processed_image+synthesized_image+ran...

# %%
top_n_labels = 20

top_labels = (
    plot_df["label_combination"]
    .value_counts()
    .head(top_n_labels)
    .index
)

plot_df["label_group"] = np.where(
    plot_df["label_combination"].isin(top_labels),
    plot_df["label_combination"],
    "other",
)

# label_categories = sorted(plot_df["label_group"].unique())
# label_to_id = {label: i for i, label in enumerate(label_categories)}
label_categories = list(top_labels)
if "other" in plot_df["label_group"].values:
    label_categories.append("other")
label_to_id = {label: i for i, label in enumerate(label_categories)}


plot_df["label_id"] = plot_df["label_group"].map(label_to_id)

plt.figure(figsize=(20, 9))

scatter = plt.scatter(
    plot_df["tsne_x"],
    plot_df["tsne_y"],
    c=plot_df["label_id"],
    s=8,
    alpha=0.75,
    cmap="tab20",
)

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title("t-SNE of artwork embeddings colored by label combination")

# Legend
handles = []

for label, label_id in label_to_id.items():
    handles.append(
        plt.Line2D(
            [],
            [],
            marker="o",
            linestyle="",
            label=label,
            markersize=6,
            markerfacecolor=scatter.cmap(scatter.norm(label_id)),
            markeredgecolor="none",
        )
    )
plt.legend(
    handles=handles,
    title="Label combination",
    bbox_to_anchor=(1.05, 1),
    loc="upper left",
    fontsize=8,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# Now what if we "simplify" the colors scheme by "big groups"

# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


PREDICTIONS_PATH = "../artworks/prompt_10_20260413/predictions.json"
# If needed:
# PREDICTIONS_PATH = "art-in-swh/artworks/prompt_10_20260413/predictions.json"


def normalize_path(path):
    return str(Path(path).resolve())


def get_time_type(labels):
    outcome = set(labels.get("outcome", []))

    if "time_based" in outcome:
        return "time_based"
    if "static" in outcome:
        return "static"

    return "unknown_time"


def get_interaction_type(labels):
    interaction = set(labels.get("interaction", []))

    if "yes" in interaction:
        return "interactive"
    if "no" in interaction:
        return "not_interactive"

    return "unknown_interaction"


def get_content_family(labels):
    entities = set(labels.get("entities", []))
    outcome = set(labels.get("outcome", []))

    has_image = bool(
        {"processed_image", "synthesized_image"} & entities
        or "visual" in outcome
    )

    has_audio = bool(
        {"processed_audio", "synthesized_sound"} & entities
        or "auditory" in outcome
    )

    has_text = bool(
        {"processed_text", "synthesized_text"} & entities
    )

    has_randomness = "randomness" in entities

    n_modalities = sum([has_image, has_audio, has_text])

    if n_modalities >= 2:
        return "multimodal"
    if has_image:
        return "image"
    if has_audio:
        return "audio"
    if has_text:
        return "text"
    if has_randomness:
        return "randomness_only"

    return "unknown"


# Make sure plot_df has resolved paths
if "file_path_resolved" not in plot_df.columns:
    plot_df["file_path_resolved"] = plot_df["file_path"].apply(normalize_path)


# Load predictions
with open(PREDICTIONS_PATH, "r", encoding="utf-8") as f:
    predictions = json.load(f)


pred_rows = []

for item in predictions:
    labels = item["predicted_labels"]

    pred_rows.append({
        "file_path_resolved": normalize_path(item["file_path"]),
        "content_family": get_content_family(labels),
        "time_type": get_time_type(labels),
        "interaction_type": get_interaction_type(labels),
    })


pred_df = pd.DataFrame(pred_rows)


# Merge only the columns we need
plot_df = plot_df.drop(
    columns=["content_family", "time_type", "interaction_type"],
    errors="ignore",
).merge(
    pred_df,
    on="file_path_resolved",
    how="left",
)


plot_df["content_family"] = plot_df["content_family"].fillna("unknown")
plot_df["time_type"] = plot_df["time_type"].fillna("unknown_time")
plot_df["interaction_type"] = plot_df["interaction_type"].fillna("unknown_interaction")

plot_df[["content_family", "time_type", "interaction_type"]].value_counts().head()

color_map = {
    "image": "tab:blue",
    "audio": "tab:orange",
    "text": "tab:green",
    "multimodal": "tab:red",
    "randomness_only": "tab:purple",
    "unknown": "tab:gray",
}

marker_map = {
    "static": "o",
    "time_based": "^",
    "unknown_time": "s",
}

plt.figure(figsize=(13, 10))

for content_family, family_df in plot_df.groupby("content_family"):
    for time_type, time_df in family_df.groupby("time_type"):
        for interaction_type, sub_df in time_df.groupby("interaction_type"):
            color = color_map.get(content_family, "tab:gray")
            marker = marker_map.get(time_type, "s")

            is_interactive = interaction_type == "interactive"

            plt.scatter(
                sub_df["tsne_x"],
                sub_df["tsne_y"],
                marker=marker,
                s=18,
                alpha=0.75,
                facecolors=color if is_interactive else "none",
                edgecolors=color,
                linewidths=0.8,
            )

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title("t-SNE of artwork embeddings")

# Color legend
color_handles = [
    Line2D(
        [], [], marker="o", linestyle="",
        markerfacecolor=color,
        markeredgecolor=color,
        label=label,
        markersize=8,
    )
    for label, color in color_map.items()
]

# Shape legend
shape_handles = [
    Line2D(
        [], [], marker="o", linestyle="",
        color="black",
        markerfacecolor="black",
        label="static",
        markersize=8,
    ),
    Line2D(
        [], [], marker="^", linestyle="",
        color="black",
        markerfacecolor="black",
        label="time_based",
        markersize=8,
    ),
]

# Fill legend
fill_handles = [
    Line2D(
        [], [], marker="o", linestyle="",
        markerfacecolor="black",
        markeredgecolor="black",
        label="interactive",
        markersize=8,
    ),
    Line2D(
        [], [], marker="o", linestyle="",
        markerfacecolor="none",
        markeredgecolor="black",
        label="not interactive",
        markersize=8,
    ),
]

legend1 = plt.legend(
    handles=color_handles,
    title="Content family",
    bbox_to_anchor=(1.02, 1),
    loc="upper left",
)

plt.gca().add_artist(legend1)

plt.legend(
    handles=shape_handles + fill_handles,
    title="Shape / fill",
    bbox_to_anchor=(1.02, 0.55),
    loc="upper left",
)

plt.tight_layout()
plt.show()

# %% [markdown]
# This plot visualizes the 2D t-SNE projection of the artwork embeddings. Each point represents one artwork file.
#
# - The marker shape encodes the temporal behavior of the artwork: circles represent static artworks, while triangles represent time-based artworks.
# - The marker fill encodes interaction: filled markers indicate interactive artworks, while empty markers indicate non-interactive artworks.
# - Colors represent a simplified content family derived from the predicted labels, such as image-based, audio-based, text-based, multimodal, randomness-only, or - unknown.
#
# This encoding allows us to inspect whether artworks with similar embeddings also share similar predicted characteristics.

# %%
paths = plot_df.loc[
    (plot_df["content_family"] == "audio") &
    (plot_df["time_type"] == "time_based"),
    "file_path"
]
for path in paths[:10]:
    print(path)
# Out:
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js_sound/17.2_pauseSong/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Vaayaa/website/Tutorials/P5JS/p5.js_sound/17.2_pauseSong/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/MadeCurler/website/Tutorials/P5JS/p5.js_sound/17.2_pauseSong/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Mitsutaka80/Rainbow-Code/Tutorials/P5JS/p5.js_sound/11.2_pauseSong/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Scream145/Rainbow-Code/p5.js_sound/11.2_pauseSong/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/yogspace/p5.js-sound/examples/recordLoops/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/yogspace/p5.js-sound/examples/envAmpFreq/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/yogspace/p5.js-sound/examples/Reverb_basic/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/yogspace/p5.js-sound/examples/pause_soundfile/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/yogspace/p5.js-sound/examples/removeSketch/sketch.js

# %%
import numpy as np

def get_nearby_points_2d(plot_df, x, y, top_k=10):
    df = plot_df.copy()

    df["tsne_distance"] = np.sqrt(
        (df["tsne_x"] - x) ** 2 +
        (df["tsne_y"] - y) ** 2
    )

    return df.sort_values("tsne_distance").head(top_k)

nearby = get_nearby_points_2d(
    plot_df,
    x=-20,
    y=50,
    top_k=10,
)


for path in nearby["file_path"][:10]:
    print(path)
# Out:
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/cenkt/website/CodingChallenges/CC_030_Phyllotaxis/P5/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Harrybowling/website/CodingChallenges/CC_030_phyllotaxis_p5.js/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/willy-goat/website/CodingChallenges/CC_030_Phyllotaxis/P5/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/BigBelts/Rainbow-Code/CodingChallenges/CC_30_phyllotaxis_p5.js/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/surajjorwekar/website/CodingChallenges/CC_030_Phyllotaxis/P5/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Mitsutaka80/Rainbow-Code/CodingChallenges/CC_30_phyllotaxis_p5.js/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/eve31/website/CodingChallenges/CC_030_Phyllotaxis/P5/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/mrbrettsmith/prog4tw/week13/exerc/main.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/luismunhoz55/Projetos-P5Js/p5/Phyllotaxis/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/BLiTzBaNe/JavaScriptCodes/p5/p5/Phylotaxis/sketch.js

# %% [markdown]
# ### No entities?

# %%
for path in plot_df[plot_df["entities"] == ""]["file_path"][:10]:
    print(path)
# Out:
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/tb-harris/runCharmanderRun/p5/empty-example/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/tb-harris/runCharmanderRun/p5/empty-example/.ipynb_checkpoints/sketch-checkpoint.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Fagner2006/Projetos-2/project_c9_pro_new-main/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js/05/5.3_p5.js_functions_and_return/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js/08/8.09_p5.js_CSS_Selectors/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js/03/3.4_1_p5.js_Boolean_variables/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js/03/3.4_0_p5.js_Boolean_variables/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js/09/9.05_0_p5.js_setInterval/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js/09/9.06_p5.js_Closure/sketch.js
# /home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js/09/9.05_1_p5.js_setInterval/sketch.js

# %% [markdown]
# ### Extra: Daniel Shiffman?

# %%
from pathlib import Path
from tqdm.auto import tqdm

search_string = "daniel shiffman"

matches = []

for path in tqdm(artwork_paths, desc="Scanning files"):
    path = Path(path)

    try:
        text = path.read_text(encoding="utf-8", errors="ignore")

        if search_string in text.lower():
            matches.append(str(path))

    except Exception as e:
        print(f"Could not read {path}: {e}")

print(f"Found {len(matches)} files containing 'Daniel Shiffman'")
# Out:
# Scanning files:   0%|          | 0/19727 [00:00<?, ?it/s]
# Found 8491 files containing 'Daniel Shiffman'

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


def contains_daniel_shiffman(path):
    try:
        text = Path(path).read_text(encoding="utf-8", errors="ignore")
        return "daniel shiffman" in text.lower()
    except Exception:
        return False


# Add boolean column
plot_df["mentions_daniel_shiffman"] = plot_df["file_path"].apply(contains_daniel_shiffman)

# Check counts
print(plot_df["mentions_daniel_shiffman"].value_counts())

color_map = {
    True: "tab:red",
    False: "tab:gray",
}

label_map = {
    True: "Mentions Daniel Shiffman",
    False: "Does not mention Daniel Shiffman",
}

plt.figure(figsize=(12, 9))

for value, sub_df in plot_df.groupby("mentions_daniel_shiffman"):
    plt.scatter(
        sub_df["tsne_x"],
        sub_df["tsne_y"],
        s=8,
        alpha=0.85 if value else 0.25,
        color=color_map[value],
        label=label_map[value],
    )

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title("t-SNE of artwork embeddings\nHighlighting files that mention Daniel Shiffman")

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# mentions_daniel_shiffman
# False    11236
# True      8491
# Name: count, dtype: int64

# %% [markdown]
# ## Distribution of label combination

# %%
combination_counts = (
    plot_df["label_combination"]
    .value_counts()
    .reset_index()
)

combination_counts.columns = ["label_combination", "count"]

# Optional: plot only top N combinations
# top_n = 100
# combination_counts_top = combination_counts.head(top_n)
combination_counts_top = combination_counts

plt.figure(figsize=(25, 45))

plt.barh(
    combination_counts_top["label_combination"][::-1],
    combination_counts_top["count"][::-1],
)

plt.xlabel("Count")
plt.ylabel("Label combination")
# plt.title(f"Top {top_n} label combinations")
plt.title(f"All label combinations")

plt.tight_layout()
plt.show()

# %%
label_lists = (
    plot_df["label_combination"]
    .fillna("")
    .str.split(r"\s*\+\s*|,\s*", regex=True)
    .apply(lambda labels: [label.strip() for label in labels if label.strip()])
)

label_matrix = (
    label_lists
    .str.join("|")
    .str.get_dummies(sep="|")
)

top_label_names = label_matrix.sum().sort_values(ascending=False).head(20).index

cooccurrence = label_matrix[top_label_names].T @ label_matrix[top_label_names]

plt.figure(figsize=(12, 10))

plt.imshow(cooccurrence)

plt.xticks(
    range(len(top_label_names)),
    top_label_names,
    rotation=90,
)

plt.yticks(
    range(len(top_label_names)),
    top_label_names,
)

plt.colorbar(label="Number of artworks")

plt.title("Label co-occurrence matrix")
plt.tight_layout()
plt.show()

# %%
def split_labels(value):
    if pd.isna(value):
        return []
    return [
        label.strip()
        for label in re.split(r"\s*\+\s*|,\s*", value)
        if label.strip()
    ]

label_lists = plot_df["label_combination"].apply(split_labels)

label_matrix = (
    label_lists
    .str.join("|")
    .str.get_dummies(sep="|")
)

label_counts = label_matrix.sum().sort_values(ascending=False)

# %%
top_n = 30

top_label_counts = label_counts.head(top_n)

plt.figure(figsize=(14, 10))

plt.barh(
    top_label_counts.index[::-1],
    top_label_counts.values[::-1],
)

plt.xlabel("Number of artworks")
plt.ylabel("Label")
plt.title(f"Top {top_n} individual labels")

plt.tight_layout()
plt.show()

# %%
plot_df["n_labels"] = label_lists.apply(len)

plt.figure(figsize=(10, 6))

plt.hist(
    plot_df["n_labels"],
    bins=range(plot_df["n_labels"].min(), plot_df["n_labels"].max() + 2),
    align="left",
)

plt.xlabel("Number of labels")
plt.ylabel("Number of artworks")
plt.title("Distribution of number of labels per artwork")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## More T-SNE plots

# %%
combination_frequency = plot_df["label_combination"].value_counts()

plot_df["label_combination_count"] = plot_df["label_combination"].map(
    combination_frequency
)

plt.figure(figsize=(14, 10))

scatter = plt.scatter(
    plot_df["tsne_x"],
    plot_df["tsne_y"],
    c=np.log1p(plot_df["label_combination_count"]),
    s=8,
    alpha=0.75,
)

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title("t-SNE colored by label combination frequency")

plt.colorbar(scatter, label="log(1 + combination count)")

plt.tight_layout()
plt.show()

# %% [markdown]
# This plot colors each artwork by how frequent its label combination is in the dataset. Higher values indicate common label combinations, while lower values indicate rare ones. This helps verify whether the t-SNE structure is driven by frequent taxonomy patterns or whether rare combinations also form meaningful clusters.

# %%
from sklearn.neighbors import NearestNeighbors

k = 15

coords = plot_df[["tsne_x", "tsne_y"]].values

neighbors = NearestNeighbors(n_neighbors=k + 1)
neighbors.fit(coords)

_, indices = neighbors.kneighbors(coords)

local_purity = []

for i, neighbor_ids in enumerate(indices):
    neighbor_ids = neighbor_ids[1:]
    same_label_share = (
        plot_df.iloc[neighbor_ids]["label_combination"]
        == plot_df.iloc[i]["label_combination"]
    ).mean()
    local_purity.append(same_label_share)

plot_df["local_label_purity"] = local_purity

plt.figure(figsize=(14, 10))

scatter = plt.scatter(
    plot_df["tsne_x"],
    plot_df["tsne_y"],
    c=plot_df["local_label_purity"],
    s=8,
    alpha=0.75,
)

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title("Local label purity in t-SNE space")

plt.colorbar(scatter, label=f"Share of {k} nearest neighbors with same label")

plt.tight_layout()
plt.show()

# %% [markdown]
# This plot shows whether nearby artworks share the same label combination. Higher values indicate regions where the embedding space is locally consistent with the taxonomy, while lower values indicate mixed or ambiguous regions.

# %%
top_n = 9

top_labels = (
    plot_df["label_combination"]
    .value_counts()
    .head(top_n)
    .index
)

label_to_number = {
    label: i + 1
    for i, label in enumerate(top_labels)
}

print("Label mapping:")
for label, number in label_to_number.items():
    print(f"{number}. {label}")

fig, axes = plt.subplots(3, 3, figsize=(18, 18))
axes = axes.flatten()

for ax, label in zip(axes, top_labels):
    label_number = label_to_number[label]
    is_label = plot_df["label_combination"] == label

    ax.scatter(
        plot_df.loc[~is_label, "tsne_x"],
        plot_df.loc[~is_label, "tsne_y"],
        s=4,
        alpha=0.08,
    )

    ax.scatter(
        plot_df.loc[is_label, "tsne_x"],
        plot_df.loc[is_label, "tsne_y"],
        s=10,
        alpha=0.85,
    )

    ax.set_title(f"Label {label_number}")
    ax.set_xlabel("t-SNE 1")
    ax.set_ylabel("t-SNE 2")

plt.tight_layout()
plt.show()
# Out:
# Label mapping:
# 1. entities=synthesized_image+randomness | interaction=no | outcome=visual+time_based
# 2. entities=processed_image+synthesized_image+randomness | interaction=yes | outcome=visual+time_based
# 3. entities=processed_image+synthesized_image | interaction=yes | outcome=visual+time_based
# 4. entities=synthesized_image | interaction=no | outcome=visual+time_based
# 5. entities=processed_text+synthesized_text | interaction=yes | outcome=visual+static
# 6. entities=synthesized_image+randomness | interaction=yes | outcome=visual+time_based
# 7. entities=synthesized_image | interaction=no | outcome=visual+static
# 8. entities=synthesized_image | interaction=yes | outcome=visual+time_based
# 9. entities=processed_text+synthesized_text+randomness | interaction=yes | outcome=visual+time_based
