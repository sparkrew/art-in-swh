# %%
from pathlib import Path
from IPython.display import Markdown, display

def print_code_file(file_path, language="javascript"):
    file_path = Path(file_path)
    code = file_path.read_text(encoding="utf-8")

    display(Markdown(f"### `{file_path}`\n\n```{language}\n{code}\n```"))

print_code_file(
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/usmanCodesjs/project15/sketch.js" # 1.000
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/ZishannBro/c-19-TreasureHunt/sketch.js" # 1.000
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/RaghavMathur639/Project-15/sketch.js" # 0.999
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Anant1782009/c15/sketch.js" # 0.997
    "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Kumarshilu/Trex-Game.T/sketch.js" # 0.800
    
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/SahithP/P18/sketch.js"
    
)
# Out:
# ### `/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/Kumarshilu/Trex-Game.T/sketch.js`
#
# ```javascript
# var PLAY = 1;
# var END = 0;
# var gameState = PLAY;
#
# var trex, trex_running, trex_collided;
# var ground, invisibleGround, groundImage;
#
# var cloudsGroup, cloudImage;
# var obstaclesGroup, obstacle1, obstacle2, obstacle3, obstacle4, obstacle5, obstacle6;
#
# var score = 0;
#
# var gameOver, restart;
#
#
#
# function preload() {
#   trex_running = loadAnimation("trex1.png", "trex3.png", "trex4.png");
#   trex_collided = loadAnimation("trex_collided.png");
#
#   groundImage = loadImage("ground2.png");
#
#   cloudImage = loadImage("cloud.png");
#
#   obstacle1 = loadImage("obstacle1.png");
#   obstacle2 = loadImage("obstacle2.png");
#   obstacle3 = loadImage("obstacle3.png");
#   obstacle4 = loadImage("obstacle4.png");
#   obstacle5 = loadImage("obstacle5.png");
#   obstacle6 = loadImage("obstacle6.png");
#
#   gameOverImg = loadImage("gameOver.png");
# ...
