# %% [markdown]
# File viewer

# %%
from pathlib import Path
from IPython.display import Markdown, display

def print_code_file(file_path, language="javascript"):
    file_path = Path(file_path)
    code = file_path.read_text(encoding="utf-8")

    display(Markdown(f"### `{file_path}`\n\n```{language}\n{code}\n```"))

print_code_file(
# "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/LouaneGodfroid01/20_21_AN1_clipWeb/clips/hamadet_julie/sketch.js"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       6     code = file_path.read_text(encoding="utf-8")
#       8     display(Markdown(f"### `{file_path}`\n\n```{language}\n{code}\n```"))
# ---> 10 print_code_file(
#      11 # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/LouaneGodfroid01/20_21_AN1_clipWeb/clips/hamadet_julie/sketch.js"
#      12     "ionescugeorge/website/Tutorials/P5JS/p5.js/08/8.08_p5.js_events_changed_input/sketch.js"
#      13 )
#
# Cell In[1], line 6, in print_code_file(file_path, language)
#       4 def print_code_file(file_path, language="javascript"):
#       5     file_path = Path(file_path)
# ----> 6     code = file_path.read_text(encoding="utf-8")
#       8     display(Markdown(f"### `{file_path}`\n\n```{language}\n{code}\n```"))
#
# ...
