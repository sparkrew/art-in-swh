# %% [markdown]
# File viewer

# %%
from pathlib import Path
from IPython.display import Markdown, display

def print_code_file(file_path, language="javascript"):
    file_path = Path(file_path)
    code = file_path.read_text(encoding="utf-8")

    display(Markdown(f"### `{file_path}`\n\n```{language}\n{code}\n```"))

print_code_file(
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/usmanCodesjs/project15/sketch.js"
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/ZishannBro/c-19-TreasureHunt/sketch.js"
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/SahithP/P18/sketch.js"
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/pranathi777/project-48/sketch.js" # 0.8599
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/aoas2009/Project-C-22/sketch.js"  # 0.908

    
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js_sound/17.2_pauseSong/sketch.js"
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/eve31/website/CodingChallenges/CC_030_Phyllotaxis/P5/sketch.js"
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js/08/8.09_p5.js_CSS_Selectors/sketch.js" # Empty - no entities
    # "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/carran085/Rainbow-Code/Tutorials/P5JS/p5.js/09/9.05_1_p5.js_setInterval/sketch.js" # No entities - has code
)
# Out:
# ### `/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/NaeN4e/PRO-C18-JOGO-COMPAT-VEL-COM-DISPOSITIVOS/PRO-V2-C18-Modelo-main/sketch.js`
#
# ```javascript
# var path,boy,cash,diamonds,jwellery,sword;
# var pathImg,boyImg,cashImg,diamondsImg,jwelleryImg,swordImg;
# var treasureCollection = 0;
# var cashG,diamondsG,jwelleryG,swordGroup;
#
# //Esttados de Jogo
# var PLAY=1;
# var END=0;
# var gameState=1;
#
# function preload(){
#   pathImg = loadImage("Road.png");
#   boyImg = loadAnimation("Runner-1.png","Runner-2.png");
#   cashImg = loadImage("cash.png");
#   diamondsImg = loadImage("diamonds.png");
#   jwelleryImg = loadImage("jwell.png");
#   swordImg = loadImage("sword.png");
#   endImg =loadAnimation("fimdeJogo.png");
# }
#
# function setup(){
#
# //crie uma tela
#
# // createCanvas(window,window);
# createCanvas(windowWidth,windowHeight);
# //createCanvas(width,height);
# //createCanvas(200,200);
#
# //plano de fundo se movendo
#
# ...

# %%
from pathlib import Path
from IPython.display import Markdown, display

def print_code_file(file_path, language="javascript"):
    file_path = Path(file_path)
    code = file_path.read_text(encoding="utf-8")

    display(Markdown(f"### `{file_path}`\n\n```{language}\n{code}\n```"))

print_code_file(
    "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/cenkt/website/beginners/p5js/3.1-conditional-statements/P5/sketch.js"
)
# Out:
# ### `/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/cenkt/website/beginners/p5js/3.1-conditional-statements/P5/sketch.js`
#
# ```javascript
# // Introduction to Conditional Statements
# // Code! Programming with p5.js
# // The Coding Train / Daniel Shiffman
# // https://thecodingtrain.com/beginners/p5js/3.1-conditional-statements.html
# // https://youtu.be/1Osb_iGDdjk
# // https://editor.p5js.org/codingtrain/sketches/z_yjYIha
#
# function setup() {
#   createCanvas(600, 400);
# }
#
# function draw() {
#   background(0);
#
#   stroke(255);
#   strokeWeight(4);
#   noFill();
#
#   if (mouseX > 300) {
#     fill(255, 0, 200);
#   }
#
#   ellipse(300, 200, 100, 100);
# }
#
# ```
