# %%
from pathlib import Path
from IPython.display import Markdown, display

def print_code_file(file_path, language="javascript"):
    file_path = Path(file_path)
    code = file_path.read_text(encoding="utf-8")

    display(Markdown(f"```{language}\n{code}\n```"))

src = "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/"
file = "carran085/Rainbow-Code/Q_and_A/Q_6_p5_background/sketch.js"

print_code_file(src + file)
# Out:
# ```javascript
# var canvas;
# var mic;
#
# function windowResized() {
#   //console.log('resized');
#   resizeCanvas(windowWidth, windowHeight);
# }
#
# function setup() {
#   canvas = createCanvas(windowWidth, windowHeight);
#   canvas.position(0, 0);
#   //canvas.style('z-index', '-1');
#   // mic = new p5.AudioIn();
#   // mic.start();
#   //background(175);
# }
#
# function keyPressed() {
#   clear();
# }
#
# function draw() {
#   if (mouseIsPressed) {
#     line(pmouseX, pmouseY, mouseX, mouseY);
#   }
#   // var vol = mic.getLevel();
#   // ellipse(width / 2, height / 2, vol * width);
# }
#
# ```

# %% [markdown]
# wrong label
#
# * it is interactive: uses `mouseispressed`, `keypressed`, and `windowresized`
# * it is time_based only because the mouse can draw lines over time
# * commented mic code should not count

# %%
src = "/home/rpinter/links/projects/def-baudry/shared/data/artworks/src/"
file = "carran085/Rainbow-Code/Tutorials/P5JS/18_p5.js_webgl/18.03_p5.js_Materials_and_Lights/sketch.js"

print_code_file(src + file)
# Out:
# ```javascript
# // Daniel Shiffman
# // http://codingtra.in
# // http://patreon.com/codingtrain
#
# // Video: https://youtu.be/k2FguXvqp60
#
# let angle = 0;
#
# function setup() {
#   createCanvas(400, 300, WEBGL);
# }
#
# function draw() {
#   let dx = mouseX - width / 2;
#   let dy = mouseY - height / 2;
#   let v = createVector(dx, dy, 0);
#   v.div(100);
#
#   ambientLight(0, 0, 255);
#   directionalLight(255, 0, 0, v);
#   //pointLight(255, 0, 0, 200, 0, 0);
#
#   background(175);
#
#   rotateX(angle);
#   rotateY(angle * 0.3);
#   rotateZ(angle * 1.2);
#
#   noStroke();
#   ambientMaterial(255);
#   //fill(0, 0, 255);
#   torus(100, 25);
#
#   angle += 0.03;
# }
#
# ```

# %% [markdown]
# wrong label
#
# * it is interactive: light direction depends on `mousex` and `mousey`
# * it is time_based: `angle += 0.03` rotates the torus every frame
# * no randomness needed: deterministic variable update creates motion

# %%
file = "carran085/Rainbow-Code/Tutorials/P5JS/p5.js/03/3.2_p5.js_The_Bouncing_Ball/sketch.js"

print_code_file(src + file)
# Out:
# ```javascript
# /*
# https://vimeo.com/channels/learningp5js/138935675
# */
#
# var x = 0;
# var speed = 3;
#
# function setup() {
#   createCanvas(600, 400);
# }
#
# function draw() {
#   background(0);
#   stroke(255);
#   strokeWeight(4);
#   noFill();
#   ellipse(x, 200, 100, 100);
#
#   if (x > width) {
#     speed = -3;
#   }
#
#  x = x + speed;
# }
# ```

# %% [markdown]
# correct label
#
# * no interaction
# * time_based because `x = x + speed` moves the ellipse every frame
# * no randomness: deterministic motion creates change over time

# %%
file = "Scream145/Rainbow-Code/p5.js/2.3_1_p5.js_JavaScript_with_objects /sketch.js"

print_code_file(src + file)
# Out:
# ```javascript
# /*
# https://vimeo.com/channels/learningp5js/138327558
# */
# var circle = {
#   x: 0,
#   y: 200,
#   diameter: 50
# };
#
#
# var r = 218;
# var g = 160;
# var b = 221;
#
# function setup() {
#   createCanvas(600, 400);
# }
#
# function draw() {
#   // background
#   background(r, g, b);
#   // ellipse
#   fill(250, 200, 200);
#   ellipse(circle.x, circle.y, circle.diameter, circle.diameter);
#
#   circle.x = circle.x + 1;
# }
# ```

# %% [markdown]
# correct label
#
# * no interaction
# * time_based because `circle.x = circle.x + 1` moves the circle every frame
# * no randomness needed: deterministic motion creates change over time

# %%
file = "ionescugeorge/website/beginners/p5js/2.2_make_your_own/P5/sketch.js"

print_code_file(src + file)
# Out:
# ```javascript
# // Variables in p5.js (Make Your Own)
# // Code! Programming with p5.js
# // The Coding Train / Daniel Shiffman
# // https://thecodingtrain.com/beginners/p5js/2.2-make-your-own.html
# // https://youtu.be/Bn_B3T_Vbxs
# // https://editor.p5js.org/codingtrain/sketches/n8Og60lq
#
# var circleX = 0;
#
# function setup() {
#   createCanvas(600, 400);
# }
#
# function draw() {
#   // background
#   background(250, 250, 100);
#   // ellipse
#   fill(250, 200, 200);
#   ellipse(circleX, 200, 80, 80);
#
#   circleX = circleX + 10;
# }
#
# ```

# %% [markdown]
# correct label
#
# * no interaction
# * time_based because `circlex = circlex + 10` moves the circle every frame
# * no randomness needed: deterministic motion creates change over time

# %%
file = "abhijit-dhar/website/learning/nature-of-code/3.5-simple-harmonic-motion/2-axes-exercise/sketch.js"

print_code_file(src + file)
# Out:
# ```javascript
# // Simple Harmonic Motion (2-axes Exercise)
# // The Nature of Code
# // The Coding Train / Daniel Shiffman
# // https://youtu.be/oXwCVDXS2Lg
# // https://thecodingtrain.com/learning/nature-of-code/3.3-angles-and-vectors.html
#
# // Basic: https://editor.p5js.org/codingtrain/sketches/Fn1feR81W
# // Approximate Time: https://editor.p5js.org/codingtrain/sketches/uGCYH4-PN
# // Exact Time Exercise: https://editor.p5js.org/codingtrain/sketches/jp2B-0Wkg
# // Main: https://editor.p5js.org/codingtrain/sketches/MfvyVULHT
# // Yoyo: https://editor.p5js.org/codingtrain/sketches/qBhVjZ0pn
# // 2-axes Exercise: https://editor.p5js.org/codingtrain/sketches/_ir7-suNG
#
# let angle1 = 0;
# let angle2 = 0;
# let angleV1 = 0.07;
# let angleV2 = 0.03;
#
# function setup() {
#   createCanvas(windowWidth, windowHeight);
#   background(0);
# }
#
# function draw() {
#   background(0, 5);
#   translate(width / 2, height / 2);
#   fill(252, 238, 33, 255);
#   stroke(252, 238, 33, 200);
# ...

# %% [markdown]
# correct label
#
# * no interaction
# * time_based because `angle1` and `angle2` update every frame
# * no randomness needed: `sin()` and `cos()` create deterministic motion over time

# %%
file = "msyem2014/website/learning/nature-of-code/1.5_unit_vector/P5/sketch.js"

print_code_file(src + file)
# Out:
# ```javascript
# // Unit Vector (Normalize)
# // The Nature of Code
# // The Coding Train / Daniel Shiffman
# // https://youtu.be/ttz05d8DSOs
# // https://thecodingtrain.com/learning/nature-of-code/1.2-vector-math.html
# // https://editor.p5js.org/codingtrain/sketches/U4ezFLIZ
#
# function setup() {
#   createCanvas(400, 400);
# }
#
# function draw() {
#   background(0);
#
#   let pos = createVector(200, 200);
#   let mouse = createVector(mouseX, mouseY);
#
#   let v = p5.Vector.sub(mouse, pos);
#
#   // let m = v.mag();
#   // v.div(m);
#
#   // v.normalize();
#   // v.mult(50);
#
#   v.normalize().mult(50);
#
#   // v.setMag(50);
#
#   translate(width / 2, height / 2);
#   strokeWeight(4);
#   stroke(255);
#   line(0, 0, v.x, v.y);
# }
#
# ```

# %% [markdown]
# wrong label
#
# * it is interactive: the line direction depends on mousex and mousey

# %%
file = "rhedhs/website/Tutorials/P5JS/p5.js/09/9.03_p5.js_Transformation_Pt.3/sketch.js"

print_code_file(src + file)
# Out:
# ```javascript
# let angle = 0;
#
# function setup() {
#   createCanvas(400, 400);
#   angleMode(DEGREES);
#   // rectMode(CENTER);
# }
#
# function draw() {
#   background(0);
#   push();
#   translate(200, 200);
#   // scale(mouseX / 100, mouseY / 100);
#   scale(1, -1);
#   rotate(angle);
#   stroke(255);
#   fill(100);
#   rect(0, 0, 100, 50);
#   pop();
#
#   angle = angle + 2;
# }
#
# ```

# %% [markdown]
# correct label
#
# * no interaction
# * time_based because angle = angle + 2 rotates the rectangle every frame
# * commented mouse code should not count

# %%
file = "zal96/website/CodingChallenges/CC_014_FractalTree/P5/sketch.js"

print_code_file(src + file)
# Out:
# ```javascript
# // Coding Rainbow
# // Daniel Shiffman
# // http://patreon.com/codingtrain
# // Code for: https://youtu.be/0jjeOYMjmDU
#
# var angle = 0;
# var slider;
#
# function setup() {
#   createCanvas(400, 400);
#   slider = createSlider(0, TWO_PI, PI / 4, 0.01);
# }
#
# function draw() {
#   background(51);
#   angle = slider.value();
#   stroke(255);
#   translate(200, height);
#   branch(100);
# }
#
# function branch(len) {
#   line(0, 0, 0, -len);
#   translate(0, -len);
#   if (len > 4) {
#     push();
#     rotate(angle);
#     branch(len * 0.67);
#     pop();
#     push();
#     rotate(-angle);
#     branch(len * 0.67);
#     pop();
#   }
#
#   //line(0, 0, 0, -len * 0.67);
# }
#
# ```

# %% [markdown]
# wrong label
#
# * it is interactive: the slider controls angle

# %%
file = "cenkt/website/CodingChallenges/CC_023_SuperShape2D/P5/sketch.js"

print_code_file(src + file)
# Out:
# ```javascript
# // Daniel Shiffman
# // http://codingtra.in
# // http://patreon.com/codingtrain
# // Code for: https://youtu.be/ksRoh-10lak
#
# var slider;
#
# var n1 = 0.3;
# var n2 = 0.3;
# var n3 = 0.3;
# var m = 5;
# var a = 1;
# var b = 1;
#
# var osc = 0;
#
# function setup() {
#   createCanvas(400, 400);
#   slider = createSlider(0, 10, 5, 1);
# }
#
# function supershape(theta) {
#   var part1 = (1 / a) * cos((theta * m) / 4);
#   part1 = abs(part1);
#   part1 = pow(part1, n2);
#
#   var part2 = (1 / b) * sin((theta * m) / 4);
#   part2 = abs(part2);
#   part2 = pow(part2, n3);
#
#   var part3 = pow(part1 + part2, 1 / n1);
#
#   if (part3 === 0) {
#     return 0;
#   }
#
#   return 1 / part3;
# }
#
# function draw() {
#   m = map(sin(osc), -1, 1, 0, 10); //slider.value();
#   osc += 0.02;
#
#   background(51);
#   translate(width / 2, height / 2);
#
#   stroke(255);
#   noFill();
#
#   var radius = 100;
#
#   var total = 200;
#   var increment = TWO_PI / total;
#
# ...

# %% [markdown]
# mostly correct
#
# * time_based because `osc += 0.02` changes `m` every frame
# * no randomness needed: `sin(osc)` creates deterministic animation
# * note: `slider` is created but not used, so it does not drive the visual change
